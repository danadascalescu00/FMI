# %% [markdown]
# # Word Sense Disambiguation using Supervised Learning
# ## The Naive Bayes Model

# %% [markdown]
# ## The Senseval dataset

# %% [markdown]
# The Senseval 2 corpus is a word sense disambiguation corpus. Each item in the corpus corresponds to a single ambiguous word. For each of these words, the corpus contains a list of instances, corresponding to occurrences of that word. Each instance provides the word; a list of word senses that apply to the word occurrence; and the word’s context.
# https://www.nltk.org/howto/corpus.html#senseval
#
# Detailed description of dataset creation in publication here: https://aclanthology.org/S01-1001/

# %%
import nltk
nltk.download('senseval')
from nltk.corpus import senseval
# Out:
# [nltk_data] Downloading package senseval to /root/nltk_data...
# [nltk_data]   Package senseval is already up-to-date!

# %%
inst = senseval.instances('interest.pos')
inst[0]
# Out:
# SensevalInstance(word='interest-n', position=18, context=[('yields', 'NNS'), ('on', 'IN'), ('money-market', 'JJ'), ('mutual', 'JJ'), ('funds', 'NNS'), ('continued', 'VBD'), ('to', 'TO'), ('slide', 'VB'), (',', ','), ('amid', 'IN'), ('signs', 'VBZ'), ('that', 'IN'), ('portfolio', 'NN'), ('managers', 'NNS'), ('expect', 'VBP'), ('further', 'JJ'), ('declines', 'NNS'), ('in', 'IN'), ('interest', 'NN'), ('rates', 'NNS'), ('.', '.')], senses=('interest_6',))

# %%
len(inst)
# Out:
# 2368

# %%
for inst in senseval.instances('interest.pos')[:100]:
  p = inst.position
  left = ' '.join(w for (w,t) in inst.context[p-3:p])
  word = ' '.join(w for (w,t) in inst.context[p:p+1])
  right = ' '.join(w for (w,t) in inst.context[p+1:p+4])
  senses = ' '.join(inst.senses)
  print('%24s |%10s | %-15s -> %s' % (left, word, right, senses))
# Out:
#      further declines in |  interest | rates .         -> interest_6
#    to indicate declining |  interest | rates because they -> interest_6
#      rises in short-term |  interest | rates .         -> interest_6
#                    . 4 % |  interest | in this energy-services -> interest_5
#     holding company with | interests | in the mechanical -> interest_5
#          refunded , plus |  interest | .               -> interest_6
#            curry set the |  interest | rate on the     -> interest_6
#           country 's own |  interest | , prompted the  -> interest_4
#         of principal and |  interest | is the only     -> interest_6
#          to increase its |  interest | to 70 %         -> interest_5
#          show the strong |  interest | of japanese investors -> interest_1
#         retired early if |  interest | rates decline , -> interest_6
#              the drop in |  interest | rates since the -> interest_6
#              the drop in |  interest | rates eventually will -> interest_6
#         par plus accrued |  interest | to the date     -> interest_6
#  dramatic fluctuation in |  interest | rates , the     -> interest_6
# by growing international |  interest | in japanese behavior -> interest_1
#                    . s . |  interest | rates has spurred -> interest_6
#      again showed little |  interest | in further evidence -> interest_1
#        to cut short-term |  interest | rates , but     -> interest_6
#        key federal funds |  interest | rate by about   -> interest_6
#      resulting in higher |  interest | costs to the    -> interest_6
#  those japanese business | interests | { in the        -> interest_3
#                          |  interest | in american small -> interest_1
#     , bought controlling |  interest | in the glass    -> interest_5
#             have a great |  interest | in making investments -> interest_1
#               holds 35 % |  interest | or more and     -> interest_5
#       primarily with the |  interest | rates they pay  -> interest_6
#       and foreign annual |  interest | rates below are -> interest_6
#    64 million semiannual |  interest | payment due yesterday -> interest_6
#             a variety of |  interest | rate swap transactions -> interest_6
#       sterling market in |  interest | rate swap dealings -> interest_6
#             engage in an |  interest | rate swap ,     -> interest_6
#       to make fixed-rate |  interest | payments on debt -> interest_6
#                          |  interest | rates rose ,    -> interest_6
#         , noting growing |  interest | in use of       -> interest_1
#        them dealing with |  interest | rates and the   -> interest_6
#              bonds , the |  interest | on which is     -> interest_6
#  fielded every important |  interest | on their team   -> interest_4
#  protecting the national |  interest | in encouraging new -> interest_4
# of uncertainty regarding |  interest | rates and the   -> interest_6
#      currency , investor |  interest | was directed toward -> interest_1
#       said most investor |  interest | was focused on  -> interest_1
#        price changes and |  interest | income .        -> interest_6
#      clothing company 's |  interest | expense exceeds operating -> interest_6
#         could signal his |  interest | in helping revive -> interest_1
#                  to 20 % |  interest | in the chain    -> interest_5
#    to pursue unspecified | interests | , a move        -> interest_3
#       company also cited |  interest | costs and amortization -> interest_6
#             a decline in |  interest | rates .         -> interest_6
#      the mcalpine family | interests | , for $         -> interest_5
#  dramatic fluctuation in |  interest | rates , the     -> interest_6
#        to cut short-term |  interest | rates due to    -> interest_6
#       and foreign annual |  interest | rates below are -> interest_6
#           jaguar 's best | interests | `` for the      -> interest_4
#      announcement of its |  interest | in a minority   -> interest_1
#         buffeted by high |  interest | rates and a     -> interest_6
#          to pursue other | interests | , '' mr         -> interest_3
#      to attract investor |  interest | and remained sluggish -> interest_1
#          said , domestic |  interest | rates are likely -> interest_6
#  direction of short-term |  interest | rates at the    -> interest_6
#          but when market |  interest | rates move up   -> interest_6
#           which also has | interests | in packaging ,  -> interest_5
#            low levels of |  interest | coverage and internal -> interest_6
#           call for lower |  interest | rates , 60      -> interest_6
#      inflation and bring |  interest | rates down .    -> interest_6
#                          |  interest | rate rose to    -> interest_6
#  initially showed little |  interest | , and he        -> interest_1
#             took a quick |  interest | in mr .         -> interest_1
#                          |  interest | rates paid on   -> interest_6
#          of other timber | interests | , would result  -> interest_5
#            banks it owed |  interest | to in october   -> interest_6
#        in healthvest and |  interest | in certain facilities -> interest_5
#       secret and illegal |  interest | in a beer       -> interest_5
# plotted hidden ownership | interests | in real estate  -> interest_5
#            , lowered its |  interest | rate and accepted -> interest_6
#        complain that the |  interest | he was paying   -> interest_6
#              0826 % true |  interest | cost .          -> interest_6
#              0808 % true |  interest | cost .          -> interest_6
#                          |  interest | on the bonds    -> interest_6
#          big downturn in |  interest | rates a few     -> interest_6
#         drum up investor |  interest | in mortgage securities -> interest_1
#                          |  interest | is a great      -> interest_1
#            to drive down |  interest | rates on mortgage -> interest_6
#  mortgage securities pay |  interest | monthly , since -> interest_6
#     pursue the long-term | interests | of the corporation -> interest_4
#     holding company with | interests | in manufacturing concerns -> interest_5
#     ends despite growing |  interest | in the environment -> interest_1
#            't shown much |  interest | in refillable packages -> interest_1
#                          |  interest | only for 115    -> interest_6
#    federal reserve eases |  interest | rates .         -> interest_6
#           a narrowing of |  interest | rate differentials between -> interest_6
# reserve relaxed short-term |  interest | rates , knocking -> interest_6
#                    . s . |  interest | rates and signs -> interest_6
#         value rises when |  interest | rates decline . -> interest_6
#                    . s . |  interest | rates to decline -> interest_6
#                          |  interest | rates , he      -> interest_6
#                    . s . |  interest | rates , a       -> interest_6
#                corp . 's |  interest | rate options group -> interest_6
#      including swaps and |  interest | rate options .  -> interest_6

# %%
senseval.fileids()
# Out:
# ['hard.pos', 'interest.pos', 'line.pos', 'serve.pos']

# %%
def senses(word):
    """
    This takes a target word from senseval-2 (find out what the possible
    are by running senseval.fileides()), and it returns the list of possible 
    senses for the word
    """
    return list(set(i.senses[0] for i in senseval.instances(word)))

senses('interest.pos')
# Out:
# ['interest_1',
#  'interest_5',
#  'interest_3',
#  'interest_2',
#  'interest_6',
#  'interest_4']

# %%
[i for i in senseval.instances('interest.pos') if i.senses[0]=='interest_1']
# Out:
# [SensevalInstance(word='interest-n', position=5, context=[('the', 'DT'), ('purchases', 'NNS'), ('show', 'VBP'), ('the', 'DT'), ('strong', 'JJ'), ('interest', 'NN'), ('of', 'IN'), ('japanese', 'NN'), ('investors', 'NNS'), ('in', 'IN'), ('u', 'PRP'), ('.', '.'), ('s', 'PRP'), ('.', '.'), ('mortgage-based', 'JJ'), ('instruments', 'NNS'), (',', ','), ('fannie', 'NN'), ('mae', 'NN'), ("'s", 'POS'), ('chairman', 'NN'), (',', ','), ('david', 'JJ'), ('o', 'IN'), ('.', '.'), ('maxwell', 'NN'), (',', ','), ('said', 'VBD'), ('at', 'IN'), ('a', 'DT'), ('news', 'NN'), ('conference', 'NN'), ('.', '.')], senses=('interest_1',)),
#  SensevalInstance(word='interest-n', position=8, context=[('the', 'DT'), ('fire', 'NN'), ('is', 'VBZ'), ('also', 'RB'), ('fueled', 'VBN'), ('by', 'IN'), ('growing', 'VBG'), ('international', 'JJ'), ('interest', 'NN'), ('in', 'IN'), ('japanese', 'NN'), ('behavior', 'NN'), ('.', '.')], senses=('interest_1',)),
#  SensevalInstance(word='interest-n', position=5, context=[('the', 'DT'), ('market', 'NN'), ('again', 'RB'), ('showed', 'VBD'), ('little', 'JJ'), ('interest', 'NN'), ('in', 'IN'), ('further', 'JJ'), ('evidence', 'NN'), ('of', 'IN'), ('a', 'DT'), ('slowing', 'VBG'), ('u', 'PRP'), ('.', '.'), ('s', 'PRP'), ('.', '.'), ('economy', 'NN'), (',', ','), ('and', 'CC'), ('traders', 'NNS'), ('note', 'VBP'), ('that', 'IN'), ('the', 'DT'), ('market', 'NN'), ('in', 'IN'), ('recent', 'JJ'), ('weeks', 'NNS'), ('has', 'VBZ'), ('taken', 'VBN'), ('its', 'PRP$'), ('cues', 'NNS'), ('more', 'JJR'), ('from', 'IN'), ('wall', 'NN'), ('street', 'NN'), ('than', 'IN'), ('u', 'PRP'), ('.', '.'), ('s', 'PRP'), ('.', '.'), ('economic', 'JJ'), ('indicators', 'NNS'), ('.', '.')], senses=('interest_1',)),
#  SensevalInstance(word='interest-n', position=2, context=[('heightened', 'VBN'), ('japanese', 'NN'), ('interest', 'NN'), ('in', 'IN'), ('american', 'NN'), ('small', 'JJ'), ('business', 'NN'), ('parallels', 'VBZ'), ('an', 'DT'), ('acceleration', 'NN'), ('of', 'IN'), ('investments', 'NNS'), ('giving', 'VBG'), ('japanese', 'NN'), ('companies', 'NNS'), ('control', 'VBP'), ('of', 'IN'), ('large', 'JJ'), (',', ','), ('highly', 'RB'), ('visible', 'JJ'), ('u', 'PRP'), ('.', '.'), ('s', 'PRP'), ('.', '.'), ('corporations', 'NNS'), (',', ','), ('such', 'JJ'), ('as', 'IN'), ('columbia', 'NN'), ('pictures', 'NNS'), ('entertainment', 'NN'), ('inc', 'JJ'), ('.', '.')], senses=('interest_1',)),
#  SensevalInstance(word='interest-n', position
 'NN'), ('.', '.')], senses=('interest_1',)),
#  SensevalInstance(word='interest-n', position=34, context=[('for', 'IN'), ('his', 'PRP$'), ('part', 'NN'), (',', ','), ('the', 'DT'), ('rev', 'NN'), ('.', '.'), ('ronald', 'NN'), ('p', 'NN'), ('.', '.'), ('lengwin', 'NN'), (',', ','), ('a', 'DT'), ('spokesman', 'NN'), ('for', 'IN'), ('the', 'DT'), ('catholic', 'JJ'), ('diocese', 'NN'), ('of', 'IN'), ('pittsburgh', 'NN'), (',', ','), ('worries', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('show', 'NN'), ("'s", 'POS'), ('pilgrimage', 'NN'), ('to', 'TO'), ('the', 'DT'), ('parish', 'NN'), ('will', 'MD'), ('stir', 'VB'), ('up', 'IN'), ('unwanted', 'JJ'), ('interest', 'NN'), ('in', 'IN'), ('the', 'DT'), ('crucifix', 'NN'), ('again', 'RB'), ('.', '.')], senses=('interest_1',)),
#  SensevalInstance(word='interest-n', position=21, context=[('ruth', 'NN'), ('may', 'MD'), (',', ','), ('an', 'DT'), ('administrative', 'JJ'), ('assistant', 'NN'), ('in', 'IN'), ('city', 'NN'), ('hall', 'NN'), ('who', 'WP'), ('moved', 'VBD'), ('here', 'RB'), ('in', 'IN'), ('1948', 'CD'), (',', ','), ('laughs', 'VBZ'), ('when', 'WRB'), ('asked', 'VBN'), ('about', 'IN'), ('television', 'NN'), ("'s", 'POS'), ('interest', 'NN'), ('in', 'IN'), ('the', 'DT'), ('alien', 'JJ'), ('landing', 'NN'), ('.', '.')], senses=('interest_1',)),
#  SensevalInstance(word='interest-n', position=43, context=[('earlier', 'RBR'), ('this', 'DT'), ('month', 'NN'), (',', ','), ('van', 'NNP'), ('kampen', 'VBD'), ('merritt', 'NN'), (',', ','), ('an', 'DT'), ('investment', 'NN'), ('banking', 'NN'), ('unit', 'NN'), ('of', 'IN'), ('xerox', 'NN'), ('corp', 'NN'), ('.', '.'), (',', ','), ('announced', 'VBD'), ('a', 'DT'), ('bid', 'NN'), ('to', 'TO'), ('buy', 'VB'), ('syncor', 'NN'), ("'s", 'POS'), ('for', 'IN'), ('about', 'RB'), ('$', '$'), ('81', 'CD'), ('.', '.'), ('8', 'CD'), ('million', 'CD'), (',', ','), ('but', 'CC'), ('it', 'PRP'), ('dropped', 'VBD'), ('the', 'DT'), ('bid', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('syncor', 'VB'), ("'s", 'POS'), ('lack', 'NN'), ('of', 'IN'), ('interest', 'NN'), ('.', '.')], senses=('interest_1',))]

# %%
senses('line.pos')
# Out:
# ['formation', 'cord', 'text', 'division', 'product', 'phone']

# %%
senses('serve.pos')
# Out:
# ['SERVE6', 'SERVE2', 'SERVE10', 'SERVE12']

# %%
for inst in senseval.instances('hard.pos')[0:30]:
  p = inst.position
  left = ' '.join(w for (w,t) in inst.context[p-5:p])
  word = ' '.join(w for (w,t) in inst.context[p:p+1])
  right = ' '.join(w for (w,t) in inst.context[p+1:p+6])
  senses = ' '.join(inst.senses)
  print('%20s |%10s | %-15s -> %s' % (left, word, right, senses))

for inst in senseval.instances('hard.pos')[-30:]:
  p = inst.position
  left = ' '.join(w for (w,t) in inst.context[p-5:p])
  word = ' '.join(w for (w,t) in inst.context[p:p+1])
  right = ' '.join(w for (w,t) in inst.context[p+1:p+6])
  senses = ' '.join(inst.senses)
  print('%20s |%10s | %-15s -> %s' % (left, word, right, senses))
# Out:
# defeat him and that 's |      hard | to do . ''      -> HARD1
# doctors '' are having a |      hard | time helping president bush explain -> HARD1
#                      |      hard | to believe that the sacramento -> HARD1
# with another person , the |      hard | part in correcting the mistake -> HARD1
# bookkeeper ; 'our life is |    harder | now , yes , but -> HARD1
# shows , which have become |      hard | to sell in the rerun -> HARD1
#  we have to face the |      hard | facts of life . -> HARD1
#                      |      hard | to make the columns even -> HARD1
#                      |      hard | just to finish these remarks -> HARD1
#     has died , is it |      hard | portraying matt dillon without miss -> HARD1
# predecessors , and it 's |    harder | to drum up big crowds -> HARD1
#                      |      hard | to put into words , -> HARD1
#                      |      hard | to believe i 'm seeing -> HARD1
# a vehicle to attract the |      hard | to-reach 12-34-year-old demographic . '' -> HARD1
#                      |      hard | for him , " said -> HARD1
#       i do , but the |      hard | part is i 'll make -> HARD1
# lisa is going through the |      hard | part , but it was -> HARD1
#                      |      hard | to ignore a voodoo-like bent -> HARD1
# it also makes the job |      hard | .               -> HARD1
#                      |      hard | to understand how anyone seeking -> HARD1
# crunch '' have been especially |      hard | on owners of these high-yielding -> HARD1
# phoenix stadium that it 's |      hard | to decide where to fit -> HARD1
# or something , it becomes |      hard | for any dog . '' -> HARD1
# old ladies are crotchety and |      hard | to please .     -> HARD1
#   it 's ( becoming ) |    harder | to steal a car , -> HARD1
#  by yourself , it 's |      hard | to get motivated . '' -> HARD1
#  check ) it 's often |      hard | to tell if a can -> HARD1
# rhetoric , it is truly |      hard | to make a case that -> HARD1
#                      |    harder | to bear . ''    -> HARD1
#         , it is n 't |      hard | to get a sense of -> HARD1
# sandpaper laid flat on a |      hard | work surface .  -> HARD3
# a planted walkway on a |      hard | surface to save water . -> HARD3
#    't think i have a |      hard | nose , " he says -> HARD3
# stub your boot on something |      hard | : a frog !      -> HARD3
#    a bed that was so |      hard | and so flat that i -> HARD3
# tortillas as above but leave |      hard | and flat .      -> HARD3
# between a rock and a |      hard | place .         -> HARD3
#     a decade ago , a |      hard | cover fiction best seller sold -> HARD3
# metal , glass and other |      hard | materials are stored in the -> HARD3
# if you 're driving a |      hard | topped car , stay with -> HARD3
# the fruit before the first |      hard | freeze .        -> HARD3
# when the rind starts getting |      hard | .               -> HARD3
#                      |      hard | and soften as they mature -> HARD3
# net , frolicking on the |      hard | court as if it were -> HARD3
# done with bean curd -- |      hard | and soft , fried and -> HARD3
# have to work a little |    harder | to keep the relationship going -> HARD3
# to market was to pick |      hard | , unripe ones and gas -> HARD3
# riding down a steep , |      hard | packed dirt hill do most -> HARD3
#   the hyper pad is a |      hard | surface mousepad that contains the -> HARD3
# 't adjusted to the medium-fast |      hard | courts at the national tennis -> HARD3
# thometz may also weed out |      hard | cover classics that are readily -> HARD3
#   tie a cushion on a |      hard | headboard for comfortable sitting in -> HARD3
#    brick on a rock - |      hard | field against the wind . -> HARD3
# of washing either fabrics or |      hard | surfaces .      -> HARD3
# so-called vegetable ivory is the |      hard | endosperm of the egg-sized seed -> HARD3
# the state capitol was its |      hard | floors , the tiled , -> HARD3
#                      |      hard | outer shell of the acorn -> HARD3
#                      |    harder | skin will allow the fruit -> HARD3
# mile of highway through this |      hard | scrabble state . -> HARD3
#                      |      hard | stick of the timpanist virtually -> HARD3

# %%
senseval.instances('hard.pos')
# Out:
# [SensevalInstance(word='hard-a', position=20, context=[('``', '``'), ('he', 'PRP'), ('may', 'MD'), ('lose', 'VB'), ('all', 'DT'), ('popular', 'JJ'), ('support', 'NN'), (',', ','), ('but', 'CC'), ('someone', 'NN'), ('has', 'VBZ'), ('to', 'TO'), ('kill', 'VB'), ('him', 'PRP'), ('to', 'TO'), ('defeat', 'VB'), ('him', 'PRP'), ('and', 'CC'), ('that', 'DT'), ("'s", 'VBZ'), ('hard', 'JJ'), ('to', 'TO'), ('do', 'VB'), ('.', '.'), ("''", "''")], senses=('HARD1',)), SensevalInstance(word='hard-a', position=10, context=[('clever', 'NNP'), ('white', 'NNP'), ('house', 'NNP'), ('``', '``'), ('spin', 'VB'), ('doctors', 'NNS'), ("''", "''"), ('are', 'VBP'), ('having', 'VBG'), ('a', 'DT'), ('hard', 'JJ'), ('time', 'NN'), ('helping', 'VBG'), ('president', 'NNP'), ('bush', 'NNP'), ('explain', 'VB'), ('away', 'RB'), ('the', 'DT'), ('economic', 'JJ'), ('bashing', 'NN'), ('that', 'IN'), ('low-and', 'JJ'), ('middle-income', 'JJ'), ('workers', 'NNS'), ('are', 'VBP'), ('taking', 'VBG'), ('these', 'DT'), ('days', 'NNS'), ('.', '.')], senses=('HARD1',)), ...]

# %% [markdown]
# ## The Naive Bayes model

# %% [markdown]
# We use Bayes's classifier in order to label (classify) the words with a certain WordNet sense. For this we need a context window surrounding the target word (the word for which we search the sense). The context window should contain only "content words" (words with important meaning, that bring information, like nouns, verbs etc)
#
# We note P(s|c) the probability for sense s in the context c. For each such sense of the target word the probability is computed and we take the sense with the highest probability compared to the others.
#
# In order to compute the probability `P(s|c)`, we use the formula:
#
# `P(s|c)=P(c|s)*P(s)/P(c)`.
#
# `P(s)` is the probability of a sense without any context. For computing `P(c|s)` we need a training set (with texts that contain the target word, already labeled with its correct sense).

# %% [markdown]
# NLTK already has the classifier implemented. In this laboratory we will use the NLTK NaiveBayesClassifier:https://www.nltk.org/_modules/nltk/classify/naivebayes.html
#
# The Naive Bayes classifier will first compute the prior probability for the senses (or, generally speaking, for the class labels) - this is determined by the label's frequency in the training set. The features are used to see the likelyhood of having that label in a given context.

# %%
import nltk
import random
from nltk.classify import accuracy, NaiveBayesClassifier, MaxentClassifier
from collections import defaultdict

# %%
# NaiveBayesClassifier.train(train_set)

# %% [markdown]
# where `train_set` must contain a list with the classes and features for each class. The train_set list will contain tuples of two elements. First element is a dictionary with the features (name and value of each feature). The second element is the class label.

# %%
def sense_instances(instances, sense):
    """
    This returns the list of instances in instances that have the sense `sense`
    """
    return [instance for instance in instances if instance.senses[0]==sense]

# %%
sense2 = sense_instances(senseval.instances('hard.pos'), 'HARD2')

# %%
sense2[:5]
# Out:
# [SensevalInstance(word='hard-a', position=15, context=[('keep', 'VB'), ('this', 'DT'), ('one', 'CD'), ('in', 'IN'), ('your', 'PRP$'), ('drawer', 'NN'), ('for', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('time', 'NN'), ('the', 'DT'), ('boss', 'NN'), ('gives', 'VBZ'), ('you', 'PRP'), ('a', 'DT'), ('hard', 'JJ'), ('time', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=11, context=[('she', 'PRP'), ('recommends', 'VBZ'), ('continuing', 'VBG'), ('education', 'NN'), ('courses', 'NNS'), (',', ','), ('developing', 'VBG'), ('effective', 'JJ'), ('people', 'NNS'), ('skills', 'NNS'), ('and', 'CC'), ('hard', 'JJ'), ('work', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=10, context=[('the', 'DT'), ('phrase', 'NN'), ('``', '``'), ('consent', 'NN'), ('of', 'IN'), ('the', 'DT'), ('governed', 'VBN'), ("''", "''"), ('needs', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=9, context=[('he', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('good', 'JJ'), ('friend', 'NN'), (',', ','), ('and', 'CC'), ('hopefully', 'RB'), ('the', 'DT'), ('hard', 'JJ'), ('work', 'NN'), ('he', 'PRP'), ('has', 'VBZ'), ('done', 'VBN'), ('on', 'IN'), ('his', 'PRP$'), ('swing', 'NN'), ('is', 'VBZ'), ('going', 'VBG'), ('to', 'TO'), ('pay', 'VB'), ('dividends', 'NNS'), ('for', 'IN'), ('him', 'PRP'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=39, context=[('``', '``'), ('what', 'WP'), ('we', 'PRP'), ('do', 'VBP'), ('is', 'VBZ'), ('really', 'RB'), ('show', 'VBP'), ('the', 'DT'), ('slapstick', 'NN'), ('side', 'NN'), ('that', 'WDT'), ('still', 'RB'), ('works', 'VBZ'), ('with', 'IN'), ('the', 'DT'), ('interpretation', 'NN'), ('(', '('), ('of', 'IN'), ('the', 'DT'), ('play', 'NN'), (')', 'SYM'), (',', ','), ('so', 'RB'), ('kids', 'NNS'), ('see', 'VBP'), ('how', 'WRB'), ('much', 'JJ'), ('fun', 'NN'), ('shakespeare', 'NNP'), ('is', 'VBZ'), ('--', ':'), ('because', 'IN'), ('he', 'PRP'), ("'s", 'VBZ'), ('(', '('), ('often', 'RB'), (')', 'SYM'), ('associated', 'VBN'), ('with', 'IN'), ('hard', 'JJ'), ('academic', 'JJ'), ('disciplines', 'NNS'), (',', ','), ('"', '"'), ('orlando', 'NNP'), ('said', 'VBD'), ('.', '.')], senses=('HARD2',))]

# %%
nltk.download('stopwords')
STOPWORDS_SET = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Some helper functions we'll need to train our model

def extract_vocab_frequency(instances, stopwords=STOPWORDS_SET, n=300):
    """
      Given a list of senseval instances, return a list of the n most frequent words that
      appears in its context (i.e., the sentence with the target word in), output is in order
      of frequency and includes also the number of instances in which that key appears in the
      context of instances.
    """
    fd = nltk.FreqDist()
    for i in instances:
        (target, suffix) = i.word.split('-')
        words = (c[0] for c in i.context if not c[0] == target)
        for word in set(words) - set(stopwords):
            fd[word] += 1
    return fd.most_common()[:n+1]

# %%
def extract_vocab(instances, stopwords=STOPWORDS_SET, n=300):
    return [w for w,f in extract_vocab_frequency(instances,stopwords,n)]

# %%
extract_vocab(senseval.instances('interest.pos'), stopwords=STOPWORDS_SET, n=1000)[:20]
# Out:
# ['.',
#  ',',
#  'rates',
#  "'s",
#  'said',
#  '%',
#  'interests',
#  '``',
#  "''",
#  '$',
#  'million',
#  'n',
#  "'t",
#  'mr',
#  'company',
#  'u',
#  'rate',
#  'would',
#  'market',
#  'bonds']

# %%
# Feature extraction

def wsd_context_features(instance, vocab, dist=3):
    features = {}
    ind = instance.position
    con = instance.context
    for i in range(max(0, ind-dist), ind):
        j = ind-i
        features['left-context-word-%s(%s)' % (j, con[i][0])] = True

    for i in range(ind+1, min(ind+dist+1, len(con))):
        j = i-ind
        features['right-context-word-%s(%s)' % (j, con[i][0])] = True

 
    features['word'] = instance.word
    features['pos'] = con[1][1]
    return features

# %% [markdown]
# This feature set represents the context of a word w as the sequence of m pairs (word,tag) that occur before w and the sequence of m pairs (word, tag) that occur after w. As we'll see shortly, you can specify the value of m (e.g., m=1 means the context consists of just the immediately prior and immediately subsequent word-tag pairs); otherwise, m defaults to 3.

# %%
senseval.instances('interest.pos')[4]
# Out:
# SensevalInstance(word='interest-n', position=8, context=[('finmeccanica', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('italian', 'NN'), ('state-owned', 'JJ'), ('holding', 'NN'), ('company', 'NN'), ('with', 'IN'), ('interests', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('mechanical', 'JJ'), ('engineering', 'NN'), ('industry', 'NN'), ('.', '.')], senses=('interest_5',))

# %%
vocab_interest = extract_vocab(senseval.instances('interest.pos'), stopwords=[], n=300)
wsd_context_features(senseval.instances('interest.pos')[4], vocab=vocab_interest)
# Out:
# {'left-context-word-1(with)': True,
#  'left-context-word-2(company)': True,
#  'left-context-word-3(holding)': True,
#  'pos': 'VBZ',
#  'right-context-word-1(in)': True,
#  'right-context-word-2(the)': True,
#  'right-context-word-3(mechanical)': True,
#  'word': 'interest-n'}

# %%
def wsd_word_features(instance, vocab, dist=3):
    """
    Create a feature set where every key returns False unless it occurs in the
    instance's context
    """
    features = defaultdict(lambda:False)
    features['alwayson'] = True
    #cur_words = [w for (w, pos) in i.context]
    try:
      # 
        for(w, pos) in instance.context:
            if w in vocab:
                features[w] = True
    except ValueError:
        pass
    return features

# %% [markdown]
# This feature set is based on the set S of the n most frequent words that occur in the same sentence as the target word w across the entire training corpus (as you'll see later, you can specify the value of n, but if you don't specify it then it defaults to 300). For each occurrence of w, wsd_word_features represents its context as the subset of those words from S that occur in the w's sentence.

# %%
senseval.instances('interest.pos')[4]
# Out:
# SensevalInstance(word='interest-n', position=8, context=[('finmeccanica', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('italian', 'NN'), ('state-owned', 'JJ'), ('holding', 'NN'), ('company', 'NN'), ('with', 'IN'), ('interests', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('mechanical', 'JJ'), ('engineering', 'NN'), ('industry', 'NN'), ('.', '.')], senses=('interest_5',))

# %%
wsd_word_features(senseval.instances('interest.pos')[4], vocab=vocab_interest)
# Out:
# defaultdict(<function __main__.wsd_word_features.<locals>.<lambda>>,
#             {'.': True,
#              'alwayson': True,
#              'an': True,
#              'company': True,
#              'holding': True,
#              'in': True,
#              'industry': True,
#              'interests': True,
#              'is': True,
#              'the': True,
#              'with': True})

# %%
_inst_cache = {}

# %%
def wsd_classifier(trainer, word, features, stopwords_list = STOPWORDS_SET, number=300, distance=3, confusion_matrix=False):
    """
    This function takes as arguments:
        a trainer (e.g., NaiveBayesClassifier.train);
        a target word from senseval2
        a feature set (this can be wsd_context_features or wsd_word_features);
        a number (defaults to 300), which determines for wsd_word_features the number of
            most frequent words within the context of a given sense that you use to classify examples;
        a distance (defaults to 3) which determines the size of the window for wsd_context_features (if distance=3, then
            wsd_context_features gives 3 words and tags to the left and 3 words and tags to
            the right of the target word);
        confusion_matrix (defaults to False), which if set to True prints a confusion matrix.

    Calling this function splits the senseval data for the word into a training set and a test set (the way it does
    this is the same for each call of this function, because the argument to random.seed is specified,
    but removing this argument would make the training and testing sets different each time you build a classifier).

    It then trains the trainer on the training set to create a classifier that performs WSD on the word,
    using features (with number or distance where relevant).

    It then tests the classifier on the test set, and prints its accuracy on that set.


    If confusion_matrix==True, then calling this function prints out a confusion matrix, where each cell [i,j]
    indicates how often label j was predicted when the correct label was i (so the diagonal entries indicate labels
    that were correctly predicted).
    """
    print("Reading data...")
    global _inst_cache
    if word not in _inst_cache:
        _inst_cache[word] = [(i, i.senses[0]) for i in senseval.instances(word)]
    events = _inst_cache[word][:]
    senses = list(set(l for (i, l) in events))
    instances = [i for (i, l) in events]
    vocab = extract_vocab(instances, stopwords=stopwords_list, n=number)
    print(' Senses: ' + ' '.join(senses))

    # Split the instances into a training and test set,
    #if n > len(events): n = len(events)
    n = len(events)
    random.seed(334)
    random.shuffle(events)
    training_data = events[:int(0.8 * n)]
    test_data = events[int(0.8 * n):n]

    # Train classifier
    print('Training classifier...')
    classifier = trainer([(features(i, vocab, distance), label) for (i, label) in training_data])
    # Test classifier
    print('Testing classifier...')
    acc = accuracy(classifier, [(features(i, vocab, distance), label) for (i, label) in test_data] )
    print('Accuracy: %6.4f' % acc)
    
    if confusion_matrix==True:
        gold = [label for (i, label) in test_data]
        derived = [classifier.classify(features(i, vocab)) for (i, label) in test_data]
        cm = nltk.ConfusionMatrix(gold, derived)
        print(cm)

    return classifier

# %%
# Training the classifier:
# NB, with features based on 300 most frequent context words
wsd_classifier(NaiveBayesClassifier.train, 'hard.pos', wsd_word_features)

# Pseudocode, general training steps:
# featureset = [extract_features[i] for i in instances]
# classifier = NaiveBayesClassifier.train((feature, label) for feature in featureset)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8547

# %%
# NB, with features based word + pos in 6 word window
wsd_classifier(NaiveBayesClassifier.train, 'hard.pos', wsd_context_features)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8927

# %%
wsd_classifier(NaiveBayesClassifier.train, 'hard.pos', wsd_context_features, confusion_matrix=True) # 0.33
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8927
#       |   H   H   H |
#       |   A   A   A |
#       |   R   R   R |
#       |   D   D   D |
#       |   1   2   3 |
# ------+-------------+
# HARD1 |<650> 35  16 |
# HARD2 |  12 <76>  5 |
# HARD3 |   7  18 <48>|
# ------+-------------+
# (row = reference; col = test)

# %%
wsd_classifier(NaiveBayesClassifier.train, 'interest.pos', wsd_context_features, confusion_matrix=True) # 1/6
# Out:
# Reading data...
#  Senses: interest_1 interest_5 interest_3 interest_2 interest_6 interest_4
# Training classifier...
# Testing classifier...
# Accuracy: 0.4219
#            |   i   i   i   i   i   i |
#            |   n   n   n   n   n   n |
#            |   t   t   t   t   t   t |
#            |   e   e   e   e   e   e |
#            |   r   r   r   r   r   r |
#            |   e   e   e   e   e   e |
#            |   s   s   s   s   s   s |
#            |   t   t   t   t   t   t |
#            |   _   _   _   _   _   _ |
#            |   1   2   3   4   5   6 |
# -----------+-------------------------+
# interest_1 | <24> 33   4   4   5   1 |
# interest_2 |   .  <3>  .   1   .   . |
# interest_3 |   2   2  <4>  .   .   . |
# interest_4 |   1  22   2 <14>  .   2 |
# interest_5 |   5  45   1   6 <61>  2 |
# interest_6 |   . 133   2   1   . <94>|
# -----------+-------------------------+
# (row = reference; col = test)

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='interest.pos', 
               features=wsd_context_features) # 1/6 ~ 0.16
# Out:
# Reading data...
#  Senses: interest_1 interest_5 interest_3 interest_2 interest_6 interest_4
# Training classifier...
# Testing classifier...
# Accuracy: 0.4219

# %% [markdown]
# Why is the accuracy lower for "interest"...?

# %% [markdown]
# **Baseline**: How could we guess the sense of a word without any additional information?

# %%
# Frequency Baseline
hard_sense_fd = nltk.FreqDist([i.senses[0] for i in senseval.instances('hard.pos')])
most_frequent_hard_sense = list(hard_sense_fd.keys())[0]
frequency_hard_sense_baseline = hard_sense_fd.freq(list(hard_sense_fd.keys())[0])

# %%
frequency_hard_sense_baseline
# Out:
# 0.797369028386799

# %%
interest_sense_fd = nltk.FreqDist([i.senses[0] for i in senseval.instances('interest.pos')])
most_frequent_interest_sense= list(interest_sense_fd.keys())[0]
frequency_interest_sense_baseline = interest_sense_fd.freq(list(interest_sense_fd.keys())[0])

# %%
frequency_interest_sense_baseline
# Out:
# 0.5287162162162162

# %% [markdown]
# You can also use Naive Bayes classifier from sklearn (https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes
# %% [markdown]
# 1. Load the text in the selected file and disambiguate every instance of the word `hard` and `line`. Try different approaches, using both knowledge-based and corpus-based methods:
#
# - use the trained Naive Bayes classifier above
# - use Lesk algorithm's implementation in NLTK (see previous lab)
# - use Banerjee & Pedersen's extended Lesk algoritm (see previous lab, you can use the implementation there)

# %% [markdown]
# **Naive Bayes classifier**

# %%
import re
import nltk
nltk.download("punkt")

from nltk import tokenize

sentences = tokenize.sent_tokenize(input_text)
text = [re.sub(r"[a-z]*\d+\/*|\\n|<h>|<p>|@|&amp;| -- ", " ", sentence) for sentence in sentences]
text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['\n         Types of Squash Grips   Your racket will come with a stock factory grip .',
#  'You can put an overgrip on top of that , to help with sweat absorption , or to increase the size of the grip and make the racket feel more comfortable in your freakishly large hands .',
#  '  You can also buy a replacement grip .',
#  'In this case you remove the factory grip and put on the replacement grip instead .',
#  '  I generally only use overgrips .',
#  'My favorite has always been Tourna Grip .',
#  "here 's a video review I did of Tourna Grip , along with a brief tutorial on how to grip a squash racket .",
#  "  I do n't  use replacement grips too often but I 'd have to guess the #  brand of replacement squash grips is Karakal PU Super Grip .",
#  'Tons of pros use Karakal .',
#  '  Picking a grip is a very personal matter .',
#  'Obviously , you need your squash racket to feel comfortable in your hands .',
#  'So experiment with different squash grips and see what works best for you and your freakishly                     Want to see the grip Ramy Ashour used to win the World Championships ?',
#  'Sure you do .',
#  'Here it is :   Comments   Here are some thoughts on grips .',
#  'I have gone from replacement grips to overgrips .',
#  'Overgrips are faster to change , cheaper , just as good tack and usually you can use both sides .',
#  'These points mean that you can change it more often than replacement grips for the same money .',
#  'I only buy thin overgrips so they will not effect the grip size much .',
#  '  Karakal PU Supergrip .',
#  "I used to grip my rackets with this , but honestly I do n't  get the huge love people have for it .",
#  'In my experience it initially has great tack , but it loses this great tackiness after the first matches and becomes just average quite fast .',
#  '  Technifibre Absolut Squash replacement grip .',
#  'Good initial tackiness and feel but looses its best feel and tackiness quite fast .',
#  'Okay for sweaty hands , but not great .',
#  'I would call it overall an " okay " product but                     El Shorbagy .',
#  '  Tourna Grip overgrip .',
#  'The initial tackiness is good , not great .',
#  'Has a dry " sandpaper-like " feel and great durability .',
#  'The best grip for sweaty hands , where the tackiness actually increases with a little moisture and does not get slippery from sweat .',
#  'As a bonus you can use both sides of the grip like Wilson and Yonex .',
#  'One of the best overgrips on the market .',
#  '  Rab Reflex Dry Overgrip .',
#  'Tries to emulate the Tourna grip but succeeds poorly .',
#  'Low initial tackiness which gets just a little better with sweat/moisture .',
#  'I can not recommend this product .',
#  '  Wilson Pro overgrip .',
#  'One of the best overgrips .',
#  'Has a silky smooth feel , which is difficult to explain , with good tack .',
#  'The smooth feel of this grip is probably its best trait .',
#  'Okay for sweaty hands but not as good as Tourna .',
#  'Average durability but you can use both sides , so a  -pack actually becomes a  -pack .',
#  'Highly recommended   Yonex Super Grap overgrip .',
#  'Quite similar to                     not as good for sweaty hands .',
#  'Maybe looses its tackiness slightly faster than wilson , but overall a good overgrip .',
#  'Average durability but you can use both sides .',
#  '  Head Xtreme soft .',
#  'Great initial tackiness .',
#  'Has a nice rubbery feel and the neon yellow looks cool .',
#  'Tackiness outlasts the Yonex and Wilson and has good durability .',
#  'Slightly thicker than Yonex and Wilson .',
#  'If you have sweaty hands it initially feels like it has good adsorbtion , but depending how much you sweat it will suddenly become very slippery .',
#  'Only one-sided so you cant use it twice , but overall a good tacky grip but not for those who sweat alot from their hands .',
#  '  Salming Extreme Sticky replacement grip and overgrip .',
#  'Both the replacement- and overgrip feel quite similar except for the thickness .',
#  'Very good tackiness and has a rubbery feel like the Head .',
#  'Nice feel and looks cool and with average durability .',
#  'Not the best choice for sweaty hands .',
#  'Overall good products .',
#  '  These are just how i myself feel about these grips                     and tested a bunch of other grips aswell but ill get to them another time .',
#  '  I have tried , but not for long .',
#  'To heavy ( maybe   grams , so changes racket specks totally , but will work if having superlite headhavy ( harrow   strung , balance   ) ending up with headlight heavy racket    .',
#  '  Kimono grip is the lightest http : ** ; ;TOOLONG .',
#  'I have tried this also , but leather grip is not so forgiving/dampened so I find it to hard on the hand , returned to regular karakal pu .',
#  '  Tor , I have both leather grips ( Fairway and Kimony ) here in Norway if you still want to try/buy .',
#  'Ole   OVERVIEW : High levels of tackiness , sweat absorption , comfort and with incredible durability , the PU Supergrip sets the standard that all other grips aspire to .',
#  "The grip is available in different colours , which all appear to have slightly different properties ( green seems less tacky after extended use for example ) , but we found the yellow grip to                     As you 've probably guessed by now , I am an Eye rackets fan .",
#  'I think you should include other grips such as Eye X tacky grip .',
#  'You can find reviews and information about other grips as well on the squashxtra app .',
#  'The latest issue talks about grips .',
#  'For example it says this about the Eye grip :   OVERVIEW : Super soft and extremely comfortable in hand , the X.Tacky offers a high level of sweat absorption and maintains its properties even after prolonged usage and heavy sweat exposure .',
#  'The tackiness level is incredibly high , leading to a secure and comfortable feel , however this does mean that on-the-ny grip changes can feel clumsy and awkward especially when starting out and tackiness is at its highest   Whilst for karakal it says this :   OVERVIEW : Super soft and extremely comfortable in hand , the X.Tacky offers a high level of sweat absorption and maintains its properties even after prolonged usage and heavy sweat exposure .',
#  'The tackiness level is incredibly high , leading to a secure and comfortable feel , however this                     awkward especially when starting out and tackiness is at its highest   I have used both and I am a Eye Rackets fan too , but I have to say that Karakal are better than Eye grips .',
#  'The duration is quite longer in Karakal , the feeling is similar , but I prefer thiker grips .',
#  'So personally I prefer Karakal grips .',
#  'And you can costumize your racket with the different colours of the grips !',
#  '!',
#  '  I like to add that Eye grips are better than I expected , is a soft , thick and dry grip .',
#  'I a good starting point for this brand , if they improve some little aspects , they will have a grip at the same level of their unbelievable rackets .',
#  '  I have extreme grip problems due to very , very sweaty hands .',
#  'Do you have any grip recommendations or advice ?',
#  'I have tried just about any and every grip that has been recommended to me .',
#  'The grip either becomes immediately too slippery due to sweat ( happens with most PU/tacky grips ) or I                     grips ) .',
#  'I have to resort to Tacky-Towel but this is far from ideal as I sacrifice being able to move up and down the grip and changing my grip positions ever so slightly .',
#  'If anyone has any advice , that would be greatly appreciated .',
#  "  I find the Wilson overgrips to be best , Tournagrip is definitely the best if you 're hands sweat a lot , but I hate the way it feels , and I hate the fact that there 's no glue at the beginning and its not cut at an angle , plus they give you so little that I barely ever have enough to finish up my grip .",
#  "  Thanks B+rd , I have n't tried Eye grips .",
#  'I actually have an Eye racket on hand but I put a Tourna Grip over it .',
#  'Will take that off and see how it plays .',
#  'Its been sitting under the Tourna Grip for several months so it may not be " fresh " but well see .',
#  '  In my book , the only grip to use is the Karakal PU in                     , especially the green , which tends to slip around for some reason .',
#  'I would love to use green , as its a cool color to have on your squash racquet , but the yellow grips perform best and most consistently , and you can get them by the box .',
#  '  My racquet gripping technique is to start with the raw racquet handle , and then use wraps of head protection tape ( the clear stuff by Gamma usually for tennis , but good for squash too ) and overwraps to get to the desired base thickness .',
#  'The top layer before putting on the final grip should be a layer of the head protection tape , which provides a smooth surface for the grip to adhere to , while also allowing for a clean removal of the top grip when it becomes worn .',
#  '  Almost all Ukraine players using Karakal grip its #  grip in our country and its really good grip .',
#  'But now i found for my self new grip its Ashaway , not popular in our country , nobody sell , but i                     So who like to try i will advice to buy next time .',
#  'But i cannout undesrtand why offical website of Ashaway not provide this producst ?',
#  'can see only strings \n         Harrow Vapor Squash Racket   This is the Harrow Vapor .',
#  'Why is this called the Vapor ?',
#  'Its because when you slice this racket through the air , it leaves behind a trail of water vapor .',
#  'Not from the racket itself , but from the eyes of your opponent , as they weep , softly .',
#  "  Sponsored Links product i 'd :     Its time to get irie with the newest design of Harrows best selling racquet around the world .",
#  'With the same performance and playability that you have come to expect from the Vapor , this jammin makeover is sure to improve your game and style , mon .',
#  '  Maybe this is the racket Bob Marley would have played squash with .',
#  'Speaking of Bob Marley , did you ever watch the documentary called Marley ?',
#  'At one point , his son Ziggy Marley tells this story of how Bob used to challenge his kids to running races , but instead of letting his kids win , Bob would run as FAST as he possibly could .',
#  'You should watch the documentary                     Ion Psx Element ( the black non Selby version ) .',
#  'A tremendous blend of power , feel and durability .',
#  'Ive been rotating through   of these rackets for the last   years and havent suffered any breakage or cracks .',
#  '  Similar in terms of head shape and size but probably a fraction heavier .',
#  '  On my scales the new white vapor is   grams lighter and has more of its weight in the head .',
#  'The vapor is very " smooth " on contact with the ball , and going back to the XT feels really stiff ( but easier to generate pace with ) .',
#  '  Just picked up a new Vapor and put it on my scale in stock configuration.barrage pro strings , and their PU gripcame in at  g .',
#  'Perhaps they added a bit more material to strengthen the newer mold to deal with some of the past breakage issues .. or I just got an outlier .',
#  '  Yes , its made of graphite .',
#  'Almost all squash rackets are made from graphite , except for a few heavy beginner rackets                     use in their branding , but those rackets are also made of graphite .',
#  'The Harrow Vapor is a high-end racket and I love it , but since this is to be your first racket , I recommend you find something less expensive to start with , something around US$  .',
#  '  Hi Pierre , thanks for the great squash website .',
#  'The original Vapor also came in a pink and lime green version that they called The Prep , which has a paint scheme that the Ultralite Retro may be in homage towards .',
#  "Its funny to think of   as being retro , but hey , I guess in terms of rackets that 's a long time .",
#  'Here are some links that I found in trying to learn more about The Prep which I recently bought a gently used version of on eBay for less than what it costs to have my rackets restrung .',
#  'They are right when they call the Vapor " extremely playable " in the last paragraph of the article about Harrows Mark Hayden .',
#  '  I know that the cosmetics have changed over                     if the frame ( balance , weight , head-size , string pattern ) itself has remained primarily the same otherwise ?',
#  "If so , I 'd get another one , probably not for less than   dollars this time , but also probably not in pink either .",
#  '  Thanks Dan , that was an interesting article on the Harrow founder .',
#  "I 've only played with the red and black Vapor I do n't  know whether the models have changed much over the years .",
#  'I understand that changing the paint job can have a subtle effect .',
#  '  Hey , there is no difference between the new Misfit , and the previous red/black one .',
#  '  I can also say that there was no difference between the red/ black one and the older model with the green at the top of the head ( I asked Harrow by email a few years ago ) .',
#  '  Ive been playing with the Misfit one with the skull for over a year now .',
#  'It apparently started as a custom paint job for a squash club .',
#  'When Harrow had extras ,                     they quickly sold out and more shipments were ordered .',
#  "I 'm guessing more than one club bought these , and they were so popular Harrow decided to make them standard .",
#  '  I have both black/blue Misfit and black/red and play with them interchangeably .',
#  '  I was told by the agent in the UK that the Red/Black Vapor had an improved balance and weight when compared to the lime/black model .',
#  '  Thanks for clarifying the situation with the Misfit .',
#  'It seems there is a premium for this racket over the red black Vapor so i wanted to make sure .',
#  '  I have been using the Harrow Vapor since the dread model .',
#  'All I noticed was the move from a gloss paint job to a mat finish with the racket remaining the same .',
#  '  If I have one complaint they are rather fragile .',
#  'Otherwise absolutely love them .',
#  'Only other racket that cam close was the Dunlop Elite that let me down when the introduced the lime green version ( the one after the bronze version ) that was a very different racket .',
#  '                    sold my Head Rackets and now I \'m " heading " to Harrow Rackets .',
#  'I got impressed by the Harrow Spark Kasey Brown , my first choice , and choose the vapor as a second racket because its very similar to the Spark .',
#  '         Head Squash Rackets Roundup   Head squash rackets are quite popular and have been used by many pros including Laura Massaro , Joelle King , Nour El Tayeb , Jenny Duncalf , and Karim " The Dark Prince " Darwish .',
#  "I 've updated this page with the    models , which came out recently .",
#  '  Head Cyano     The Head Graphene XT Cyano   is new for   .',
#  'Its a teardrop-style racket .',
#  'Jenny Duncalf , Nour El Tayeb and Line Hansen used the prior version , the Head Graphene Cyano   .',
#  'Looks like Head have taken   grams out of the head for this season will keep an eye out for whether it remains popular .',
#  '  Hey Pierre , I was wondering if you could do a review of the HEAD Graphene XT Cyano   .',
#  'I found it on amazon and sportchek.ca , and I could not find a single review .',
#  'If anyone else knows anything about this racket , could you let me know .',
#  '  I currently use this racquet ( got it from Sport Chek ) and                     compared to my last racquet ( Prince Airstick   ) but is a lot more durable after a number of wall hits .',
#  'I would imagine that this is very similar to the Cyano   , which Pierre did a review of .',
#  "  I did not like the factory strings and tension as I was n't getting much power or any cut on the ball .",
#  'Changing them to Ashaway Supernick XL Micro did a world of difference in both respects .',
#  "  I 'm thinking of trying a new racquet .",
#  'Either the Suprem   , Carboflex   S or Xamsa PXT-  .',
#  'If anyone could offer advice on these , it would be greatly appreciated .',
#  '  noticed the Head IG Extreme   Squash Racket recently on the PDH Sports website which has been reduced to -  from -  .',
#  'Also checked the head website and cant see it on there when it was only released this year .',
#  '  Hi , I have to decide which racket to buy .',
#  'I would like to buy a head one , and I saw the cyano-s and the xenon-s .',
#  '                    balance between power and control .',
#  'I play once a week more or less .',
#  'I am not at all an expert but I would say that I am a bit more than intermidiate .',
#  "I would very much apreciate your opinion , Andre   I 've tried the Cyano   and the Xenon   and I think both have a good balance of power and control .",
#  'If you like a head-heavy feeling I would go with the Xenon ; if you like your racket to feel lighter and more maneuverable I would suggest the Cyano .',
#  '  Light not   beginners snare broke in   weeks (   t.a.w . )',
#  '.',
#  'With Ashaway Ultra Nick ( green ) at  ,  ,  kg.',
#  'marvellous trampoline and smashing drives .',
#  "In other words ; I do n't  have to work for my   km/ph ( like I have   do with each Dunlop under   pounds ) .",
#  "When questions , then send m. \n         Mizuno Squash Shoes   Mizuno do n't  specifically make squash shoes , they make non-marking court shoes for other sports ( volleyball , handball ) and they are appropriate for squash courts .",
#  '  Mizuno are sometimes labeled as unisex , i.e.',
#  'for either men or women , but I have tried to separate them into mens and women shoes .',
#  'Not sure what the differences between all these shoes are , just trying to collect them all in one place .',
#  '  Why is it not many Pros wear Mizuno ?',
#  'The ones I know are Daryl Selby , Low Wee Wern , Misaki Kobayashi .',
#  'Mizuno shoes are comparable to Asics in terms of their origin ( Japan ) , a sheer number of models , striking colours , volleyball shoes and high quality .',
#  '  hello , i am a beginner .',
#  "i 'm  . m and  kg with slim feet , which shoes do you recommend ?",
#  'can you explain the benefits of each make eg.',
#  'stealth etc ?',
#  "i 'll be using them for badminton , not squash so i think lateral support should be considered \n              Comments   First of let me start by saying thanks to for a great site ..",
#  'I have been an adidas stabil fan for years and have probably owned atleast one of every generation of stabil with the exception of the generation one boost .',
#  'My first impression of the newer stabil boost   or stabil boost ii is a solid   .',
#  'i have only had the shoes for a   weeks now and only played   times in them however a few noteable differences in construction are quite pronounced .',
#  '  First off the touge gap is quite large much larger then older stabil models i assume this is because adidas shoes tend to be tight fitting and not great for the wide footed players .',
#  'Perhaps adidas thought that shortening the shoe sidewalls and increasing the size of the tounge gap would accomidate a larger foot ?',
#  'What it has done is increase the span of the lace across the top of the shoe resulting in more lace and less shoe coming across the tounge .',
#  'This is the biggest problem with the shoe                     regarding laceeyeletts rippling out .',
#  'You really have to pull on the laces to get the shoe snug and there is allot of pressure on the lace during play that is not absorbed well by the shoe which was likely the cause of the eyelett damage cited above .',
#  '  On top of that vs the prior generation stabil the shoe wall construction looks and feels a bit thin specifically around the lace eyelets which the have attempted to reinforce with a think rubber peice which looks more to me like fashion vs function .',
#  '  Adidas has to done a great job reinforcing the shoe from the outside .',
#  'Heel support is amazing and side wall is very good .. Toe box is quite snug yet still comfortable .',
#  'The redesigned toe box vs old stabils and gen   boosts is much better and seems to eliminate the wrinkles that occurred across the top of the toe box in other models .',
#  '  The new sole grips well and the shoe weight seems inline ( or a bit lighter ) then other stabil models .',
#  "While I 'm not really                     .",
#  'The shoe feels comfortable and supportive and responds well on court .',
#  '  For me they felt a little bit to spongy .',
#  'Furthermore the grip of the asics is better .',
#  'The worst part is , that the holes for the laces tore off after just   weeks ( http : ** ; ;TOOLONG I hope this is working ) .',
#  'I returned them and try now salming .',
#  '  Couple of guys on the club own these shoes .',
#  'They seem to enjoy them and told me the fit was a little tighter around the foot .',
#  'They compared it with the infamous Adipower Stabil   and seem to be content .',
#  "( Do n't  take my word for it ) \n              Comments   Hi Pierre , I have been using the Progressive       for the last few years , I love them as a shoe .",
#  'They seem to of been discontinued , do you know if they are bringing out a replacement ?',
#  "i have tried the new Asics upcourt and gel-rocket but they have a lot less cushioning and do n't  feel anywhere near as good .",
#  'Getting desperate now as my progressives are on their last legs !',
#  "kind regards , Paul   Hi Paul , I have n't heard about a new version of the Progressive .",
#  'Some other shoes in the Asics lineup that have the " I.G.S. "',
#  'technology are the Gel Blade , Gel Blast , Cyber Sensei , and Volley Elite .',
#  "I have n't tried these myself , just trying to give you a thread to follow in terms of shoes that may have a similar construction .",
#  'Hope that helps a little .',
#  '  Hi Pierre , thanks for the great info , its such a trial and error with shoes , expensive mistakes when I choose                     a pair of Salmings , I will let you know how I get on with the brand change , kind regards Paul   Was looking for a new shoe to accommodate my inserts and having tried lots of brands , I was only looking at Asics .',
#  'Was between progressive   and elite volley   .',
#  'Definitely this over the elite volley for lateral movement .',
#  'As all asics , very comfy , good support across , but the typical issue that may throw some off : when stepping on the court , you feel as if the heel is going to come out .',
#  "While distracting to new asics users , you forget it quickly and does n't  hinder movement at all \n         Adidas Squash Shoes   Adidas squash shoes are quite popular amongst professionals as well as club players .",
#  'Here are the     Adidas shoes that are appropriate for indoor courts .',
#  'Adidas actually do not make a squash-specific shoe .',
#  'They make handball and volleyball shoes , which are appropriate for the squash court .',
#  '  Adidas Team Spezial   The Adidas Team Spezial is a new model for   .',
#  'Its marketed as a handball shoe ( like the Stabil / Court Stabil / Essence above ) .',
#  "I have n't seen any squash players using it yet , but it looks similar to some of the Stabil models from several years ago , so I wonder if itll catch on .",
#  'Price : -  .',
#  '  Adidas Counterblast   The Adidas Counterblast are all non-marking court shoes for the indoor market , just like the Adipower Stabil , Court Stabil and Essence above , except the Counterblast are generally lighter and have less padding .',
#  '         Why Wear Squash Goggles ?',
#  '  You should wear squash goggles every time you play or practice squash .',
#  "  Squash is played in close quarters and you do n't  want a flying ball or racket to make contact with your eyes and potentially damage your eyesight .",
#  '  Personally , I know two guys who have permanent eye damage from squash .',
#  'So I wear goggles , because one of my favorite things to do is use my eyes to look at stuff .',
#  "  The pros do n't  wear goggles , but I think that 's a mistake , because even the pros get whacked in the face on occasion .",
#  '  In any case , many squash facilities , squash leagues , and squash tournaments require you to wear protective eyewear on the court .',
#  '  Best Squash Goggles   To get sufficient eye protection , - you need goggles with polycarbonate lenses .',
#  'In the US , eyewear must meet something called the ASTM-F  standard .',
#  'Its OK to wear contact lenses as long as you wear polycarbonate lenses over them .',
#  '  Regular eyeglasses                     safe enough to play squash with .',
#  "If you wear prescription lenses , you 'll need to purchase prescription squash glasses .",
#  'Talk to your optician about ordering a pair of these .',
#  '  Read More   Comments   " two guys who have permanent eye damage from squash .. " This is something i really worry about .',
#  'I am not a regular squash player or like not an active or frequent player .',
#  'Sometimes , i do not know , maybe the influence of professional player on live TV that did not wear any eye protection make me want to do the same .',
#  'But there is a reason why they are pro .',
#  'Next time i would purchase one to protect myself .',
#  '  My friend Peter here in Philadelphia says he bought the Rec Specs Maxx-  ( MX-  ) by Liberty Sports from FramesDirect.com about   years ago and had the prescription lenses added here locally .',
#  'He says he really likes them .',
#  '         After searching and searching and reviewing bags , I finally ordered the genuine   racquet squash bag from Karakal .',
#  'This is over the shoulder style bag that can be used with one or two straps over the shoulders .',
#  '  It has one good sized center compartment , a multi-racquet compartment on each side , two smaller side pockets , a soft lined eyeglass pocket and a dedicated shoe or sweaty gear pocket .',
#  'Plus the two racquet and the shoes pockets have small mesh vent screens   The bag is lightweight yet well made and very sturdy .',
#  'I LOVE the bag and very pleased with my final decision .',
#  'I found a guy in Canada ( where I live ) who stocks the Karakal line of Squash gear , he shipped the bag to me for a reasonable shipping fear ( live in Vancouver area ) and he gave great customer service .',
#  '( He included no charge with the bag three replacement Karakal grip strips as a bonus for ordering the bag )   I have surfed this blog site lots , in fact                     them here first , but you seem not to have any Karakal gear on your site .',
#  'Wonder if you have any feedback on the rest of their Sqaush gear Cheers TC   The Wilson backpack models are quite spacious .',
#  'Highly recommended !',
#  'The main compartment is very spacious , and the more cube-like shape makes it easier to keep packing stuff in there .',
#  'The shoulder bags , even with backpack straps on them , have long , slender compartments for your non-racquet gear , which is much more difficult to pack .',
#  '         In order to facilitate agility and stability but still maintain the lightweight characteristics , we have designed the midsole rear end with higher side walls that wraps around the heel area .',
#  'In combination with the LMS Plus  - and the new fully integrated ExoSkeleton construction , it ensures an excellent stability and perfect fit .',
#  '  ExoSkeleton- fully integrated   Kobras ExoSkeleton design is totally integrated with the lacing construction in order to facilitate the best possible wrap-around effect of the foot .',
#  'This keeps the foot it in the right position during lateral movements and high performance activities .',
#  '  I like the idea of a fully integrated exoskeleton now that you mention it .',
#  '  Here were some teasers from Salming back when the shoe was launching in summer   :        Comments   How has your wear been on the balls of your foot on the inside of both your Kobra and your R s ?',
#  'So on the inside underneath the balls of your feet .',
#  'This is where my shoes wear away the most and often cause holes through the inner                     I cant make up my mind between the Kobras and the Wilson Xaos .',
#  'Regards Barry-Lee   This seems to be the case with most salming shoes .',
#  'I am on my  th pair , most recently I was looking at getting the Kobras but due to the - + price tag here in the UK I was put off , but managed to pick up the orange vipers for cheap so went with those .',
#  'Theses arrived   month ago , and already showing significant wear on the toe and in step of the shoe .',
#  "However , my previous vipers ( green ) went through the similar process , wear appears quickly on the upper but then does n't  get too much worse .",
#  'The problem I had was the sole , the in step wore down so much there was barely any rubber sole underneath my big toe ( these were bought in Jan   and I had to ditch them by August ) .',
#  '  However , I must say they are comfy and light and flexible .',
#  'By far the best shoes Ive played in ,                     of their durability .',
#  '  The Salming Vipers have a fatal flaw in that the sole is not one piece .',
#  "I 'm on my free replacement from Salming and the sole on my non-lead leg is ripping off again after   week .",
#  'Granted I play hard and scramble , but if you look at most court shoes the sole is molded as   piece .',
#  'The Viper has a piece overlaid and glued ?',
#  'onto the bottom .',
#  'BAD design .',
#  "  Looking forward to the reviews , as I 'm really curious whether Salming has finally managed to make these more durable .",
#  "I 'm on my  rd pair of Race R s within   months , which I think is pretty poor for the price   I 've used the R  , R  and Viper .",
#  'I completely agree with Piere , the Viper has a really low profile and therefore very little padding in the heel and ankle area .',
#  'R  shoes were incredibly comfortable .',
#  "I 'm currently using the R  just had a season in them and I 'm very pleased .",
#  "They are similar to the Prince shoes with                     I 'm very interested in the padding situation of the Kobra too .",
#  "If they are like the R  or R  I 'll be getting them for next season as they look great !",
#  "  I must say as a person that 's actively looking at Salming shoes for something with padding/comfort ( continually get heal bruising in my cheap mizunos ) , i find their lineup , naming and number system quite confusing .",
#  'I \'ve seen elsewhere on here and the net that the " race " models are considered some of best for padding/comfort/support , but then there are i think  -  different versions , and then there \'s the other models like viper , kobra etc   Anyone know the actual difference when it comes to comfort/padding , and why i would buy an R   .  ,  .  ,  .  over an R   .  or R   .  ,  .  ,  .  etc .',
#  '  It seems the R   .  would be the current choice as its the latest version of the R  , and based on pricing with R s a bit higher than R s , it suggests the R  lineup is                     its a bit confusing I have to agree .',
#  "I do n't  know about the Kobra and Adder as they are not out yet .",
#  "I 've personally worn R  , R  and Viper .",
#  "I feel Viper has the least padding so I 'd rule that out for you .",
#  "I could n't detect a padding difference between R  and R  but I 've heard some say R  is a little better .",
#  "Then within R R  they have version numbers but I do n't  believe there 's a big difference between the recent versions ( i.e.",
#  "between  .  and  .  ) , so I 'd just get whatevers available and looks coolest to you .",
#  'Lastly the R  is similar to R R  but has more ankle support if you want that .',
#  'Hope that helps .',
#  '         Pulled the trigger and bought this one .',
#  "Really loved the dunlop aerogel  d elitebut i hopped in the ring w/ a big brute of a guy two days agoas nice a guy you 'll meet but he s about   ft   and  lbs .",
#  'every swing was a sledgehammer shot .',
#  'nice guy .',
#  'not the best to play but heyi remember starting out and trying to get games.anyways , his mighty swing took out my dunlop .',
#  '  getting this precision pro .',
#  '  Pierre , i was gon na use the squashgear linked here but i was able to get a new one on ebay for   bucks less than what squash gear offered .',
#  'so , i did try but in the end i had to save some $$$   Does anybody have more info on this one ?',
#  "I was looking at the Head Graphene Xenon   , but I 'm starting to like the Precision Pro   more .",
#  'I love the cosmetics and it seems to me like it has really great control with being more head light balanced than just head                     my price range .',
#  "I just ca n't seem to find more information on it or reviews on it .",
#  'Can anybody help me please ?',
#  '  Hi Guido , my old favorite is the Dunlop Pro GTS   .',
#  "Now that I 'm doing this site I keep changing rackets all the time .",
#  'My current go-to is the Head Graphene Xenon   .',
#  'Generally , I like traditional head shapes with a medium weight .',
#  '  The Head is a really good choice Pierre , I had one the last year and I miss the feeling of this racket when I try to find the nick .',
#  'A problem with grommets made me change to Eye and its   Control .',
#  'Both are so similar rackets , despite the difference of weight , a little bit more powerful the Eye , more control in the Head .',
#  '         The Mizuno Wave Bolt   .',
#  'This replaces the Mizuno Wave Bolt   .',
#  'This is a volleyball court shoe from Mizuno .',
#  "The heel area does n't appear to have much grip .",
#  "MK confirmed this in a comment about a prior model , the Mizuno Wave Bolt   : AVOID : heel does n't have the right rubber for adequate Read more ...   The Wilson Pro Staff Countervail , spotted July   and available for pre-order here .",
#  'Similar head shape to the Wilson Pro Staff Ultra Light , and based on the Wilson Tour   BLX .',
#  'Priced at $  , so I guess this is the high-end frame in the   Wilson squash rackets range .',
#  'Price : Read more ...   This is the Dunlop Hyperfibre+ Revelation JNR squash racket for juniors .',
#  "It 's part of the Dunlop Hyperfibre range that 's come out for    .",
#  'The cosmetics on this are similar to the Dunlop Hyperfibre+ Revelation   .',
#  "I 'm not sure what length this racket is junior squash rackets are often Read more ... \n         Asics Gel Upcourt   I first saw the Asics Gel Upcourt on the feet of my regular playing partner Jeremy .",
#  'He liked them so much he got them in another color .',
#  'They are good-looking and he said they were comfortable right out of the box .',
#  'Another guy I play with , Peter , plays with these .',
#  'I think he said they were a little bit small , but " the price is right " ( under $  right now ) .',
#  'I was later able to review these myself and you can check out my video review below .',
#  '       Comments   Hi you forgot to mention that these shoes are built with Gel cushion both in the heel and forefoot , this makes landing and take off very comfortable .',
#  'All shoes do not have Gel in both zones.This cushions foot impact and is good for the knees .',
#  'Also these shoes are one of the lightest available and this helps quick movement on the court .',
#  '  I am using these for about a year ,   to   hours                     or giving up !',
#  'I weigh   kilos .',
#  '         Asics Gel Blast     The Asics Gel Blast   started to come out in August   .',
#  'These are the successors to the Asics Gel Blast   and have been given a ( nice ) facelift .',
#  '  The story so far : Asics Gel Blast   and prior were very popular with squash players .',
#  'When Asics came out with the Gel Blast   , they made significant changes , and a lot of squash players were sad .',
#  'Many Blast fans switched to the Asics Gel Fastball .',
#  '  This long awaited shoe is worth waiting for , for those who loved their blast   ?',
#  's and blast  s the new   will surpass your expectations , Asics has gone back to the traditional styling of the previous models will providing superior durability and quicker cuts arouind the court .',
#  "  Sponsored Links product i 'd :     This ones called blue jewel , white and flash coral .",
#  'Its listed as a mens shoe as Zalando but on other sites as a womens model .',
#  'Based on the colors and other shoes from                          Comments   Really liked these shoeswhile they lasted .',
#  'Not sure if they called them the Gel-Blast   because they only last   weeks , but it seems that way .',
#  'Very bizarre considering that my last pair of Gel Rockets lasted me close to   years .',
#  "I 'm not exactly sure what compound they used for their rubber sole , but there 's no grip left on the front , inside portion of either shoe , and my left shoe has an obvious hole where there 's no longer any rubber .",
#  "  I 'm just happy that I got these on sale because I 'd be pretty upset if I had paid more money for them .",
#  "I guess they 're just going to be my backup pair and I 'll be switching companies if this is the best that Asics can do .",
#  "  I should point out that I 'm a runner , but I still expect a pair of shoes that retails for close to $  Canadian with tax to last a bit longer than   months .",
#  'A more traditional player would definitely have these last longer considering that                     they still look brand new .',
#  'They just clearly werent designed to have a player that pushes off of their toes , laterally .',
#  '  I bought a red pair of these in October .',
#  "They 're stable , and I do like the feel of them even if they are a little heavy and warm .",
#  'But , I play about   times a week and these shoes are basically destroyed by the end of January .',
#  "Factor that I was gone for three weeks in November and did n't  play for a week over Christmas and I would give these an F in durability .",
#  'Both shoelaces broke within two months , both soles are worn through , the rubber on the front of my shoe is gone , and the front stitching is coming lose .',
#  "I do n't  play extremely competitively and these shouldve held up much longer .",
#  'My previous Mizunos lasted   years and showed little wear .',
#  'I even had a pair of Adidas running shoes last longer when I first started playing .',
#  "With two months left in the season I 'm ready to                     failed is the yellow outsole .",
#  'The hexagon rubber stuff in the vamp held up great for me .',
#  "I 'd understand if just one thing wore out on them but the fact that laces and insoles cant last half the life of a shoe is a sign of poor quality control or extreme cost cutting measures .",
#  '  I got the Gel Blast  s back in June before the official release in most countries .',
#  "They were for an uncle of mine who trusted I 'd get him a good shoe .",
#  'Seeing the pros coming out with GelBlast  s at recent tournaments reassures me that I made a good decision .',
#  '  Hi guys , bought the new blast  s last week , will be trying them out this morning .',
#  "For reference , I 've previously used ( in order ) Asics Rocket , Progressive   , Fastball ( current ) .",
#  'Ill report back later with a quick review .',
#  '  I just bought a pair of these .',
#  'they seem to look a little weird to me.',
#  'the front tip of the shoe is not exactly in the                     example , the middle tip is a little to the left and vise versa for the left shoe .',
#  'is this on purpose ?',
#  '  A squash pro friend of mine says these are not squash shoes .',
#  "There 's not much info in the Gel Blast   , most refer to it as a court shoe .",
#  "Are you ( or anyone ) able to she 'd some light or share the experience playing with these ?",
#  '  Its technically true Asics do not make squash shoes , they make shoes for handball , volleyball , and badminton .',
#  'According to Asics , the Gel Blast range is supposed to a handball shoe , but they are appropriate for squash courts , meaning they are non-marking .',
#  'Squash players have used them before ( e.g.',
#  'Mathieu Castagnet has worn the Asics Gel Blast   ) .',
#  "I have n't seen anybody wearing the Gel Blast   yet , but its pretty new still , so hopefully well see some feedback in due course !",
#  '         Old School Prince Extender OS Squash Rackets   Remember the Prince Extender ?',
#  'This was the bomb racket in the late  s .',
#  "I think I mightve used the BIGBOY but I 'm sure there was another model I used to roll with that Im forgetting the name of that had a red color scheme ( update : Jon reminds me it was called the Featherlite ) .",
#  '  Incidentally , I am the proud owner , and CURRENT user of the Prince Extender OS Thunder .',
#  'I purchased it circa  - . cant really remember to be honest.patent still pending at the time of purchase !',
#  '  In any case , it has served me well over the years .',
#  'Used it againts pros .',
#  'back in the day , and now its taking down " grandpas " at the club !',
#  ':   I have a Prince Extender OS featherlite in a maroon color , not red ; and yes I did find it in my closet .',
#  'My squash days are over due to nerve problems in my feet .',
#  '  It was a great piece of                     post it on Ebay .',
#  "There 's not a scratch on it ( it still has that holographic sticker in place ) so I 'll see if I can get a few bucks for it .",
#  'I will send you a pic as well .',
#  "  As a bit of a novice , I 've started playing with my dads olds racket , an extended os destroyer .",
#  'My question is , will playing with an older model like this be hampering my game ?',
#  'Might I see an improvement if I use a more modern racket ?',
#  '  No , if anything using an older ( usually heavier ) racquet will help your progression .',
#  'The added weight helps guide the racquet through the swing , plus I always found a heavier racquet helps you remember proper pre-swing preperation .',
#  'Not to mention older racquets seem to be alot less fragile .',
#  "  I 'm a beginner but I just bought a prince extender outrage for -  from a charity shop .",
#  'Played tonight and I beat my partner fir the first time in a few months .',
#  "I 'd say its the best                     Frenchie you are thinking of the Featherlite .",
#  'That was the lightest model they made at the time and had the red color scheme .',
#  'I broke all of mine and then switched over Princes new Power Ring line by senior year .',
#  '              In some of the pictures and videos , these shoes come out looking very red .',
#  "In real life , they 're red , but with a dash of orange .",
#  'I have been advised by my fellow players that in a pinch , my shoes can double as traffic cones .',
#  '       Comments   Hi Pierre , I have been using the Salming     and was pretty happy with them apart from the sole has peeled off from the side on both pairs .',
#  'They were close to the great Asic progressive   ; s I used to wear , apart from the footbed gets really hot as there are no ventilation holes on the Salmings .',
#  '  Unfortunately , I cant get hold of them any more , seem to be replaced .',
#  'Thinking of the Kobra but they are so expensive , I wonder how they compare .',
#  '  I did a video comparing the Kobra vs the Race , you can check it out above or here .',
#  'There are some slight differences but I liked them both .',
#  "Another                     only been using it for a few weeks so I do n't  know about the longevity .",
#  'But in terms of how they feel on my feet , the Adder are a little closer to the Race .',
#  "And they 're not exactly cheap but they 're less expensive than the Kobras .",
#  'Might be worth a look .',
#  'Thanks   Thanks Pierre , I have watched both your videos now , great information in them .',
#  'Slightly worried about the silly string loop design on the Kobra , so may go for the Adders this time and see how I get on .',
#  'Many thanks for the great site .',
#  '  Hi Pierre , a quick uodate , I ended up buying the Salming R  mids and to me they feel super similar to the R s , I cant even feel the difference .',
#  'I am really pleased with them and have bought a spare pair as well.The extra height is minimal when I am playing .',
#  "I did n't  want to take a chance on the crazy expensive Race X , that has just been released .",
#  'Thanks for the                     , tried size   in the Salming R  and had heel pain .',
#  "( I 'm guessing it must have been from friction ) I tried another pair of the most recent R  in size  .  , and they fit me perfectly with no heel pain .",
#  'For me they seem to run about a half size big .',
#  'I love the grip they have on the floor .',
#  '  I bought womens R  which are almost same as these R  .',
#  'I found out that they were smaller than my other squash shoes (      , others   ) .',
#  'Shoes were very comfortable and light but I wore them out after a month , I train  -  times in week and had two tournaments .',
#  'I have been using also adidas adipower stabil   ( also womens model ) and they have been lasted almost over year !',
#  'I hope salming could develop more sustainable shoes !',
#  "  I have seen many comments regarding the size of the shoes , I want to buy them online because i cant find them in my country , so I need                     of Adidas adipower stabil   , size  .  US , can anyone tell me if the size of the Salming is similar to Adidas or should i buy a different size , otherwise I 'll buy again Adidas .",
#  'Thank you   I wore the Adidas Adipower Stabil  .  in size  .  US , and now wear the Salming Race R  also in  .  .',
#  'I am happy with the  .  size .',
#  'The Race R  feels a little wider than the Adipower to me .',
#  'I think I probably could have been equally happy with size   Salmings ( which I never tried onlike you , I ordered them from another country ) .',
#  'Hope that helps .',
#  "  now , after   month playsing Squash with the Salming , I have no grip anymore on my Salming R   .  , but the shoe is very very durable , I 've played  -  times a week (  -  h ) , here you could see some picture of my shoes now :   My Ascics Gel Blade   was wonderful , great shoe and very wonderful , but after  -  month                     , the upper shoe components , a lot of holes : - ( ( (   Now I 've bought the Asics Gel Blade   for   EUR ( in Germany ) , the Salming R .",
#  ' .  was sold out in my shop , if the shoe is similar durable as the Gel Blade   I would like to post the relevant infos .',
#  'Probably I will order then online another pair of the Salming R   .  , we will see .',
#  '  I bought the R   .  (   EUR in Germany ) six month ago , and I am very pleased about this shoe .',
#  '  Why : The shoe is very comfortable , light and the durability is unbelievable , I play  -  times a week (  -  h / a week ) and my old Asics Gel Blade   lasts only   month , same procedure at my asics Gel Rocket   .',
#  '  Based on some reviews ive ordered a half size smaller us size  .  of the R   .  blue ( usually   ) .',
#  'And to my surprise both  .  and   are smaller                     .',
#  "So i went to a store near by and got me Viper size  .  ( yes there 's a small gap between my fingers and the forefront ) but the shoes are perfect from the sides now .",
#  'This is maybe due to having having a slightly wider feet than people who wear Adidas which is " known of having shoes for narrow feet " .',
#  "Anyway , Since i have a history of ankle and knees injuries and was in store I 've started trying different models R  cushioning was the kind of shoe that perfect for my history but these were higher than the average squash shoes .",
#  'Viper on the other foot ( bun intended ) were very low and you would be surprise of how low they are .',
#  'But they have the widest gum rubber sole which is a plus for me in terms of stability on the court .',
#  '    .',
#  "ive had them for a good while nowover   months and i play  -  nights a week and i 'm no slouchi abuse the heck out of these and i only wear them on                     starbucks    . i ordered a half-size smaller on these and its perfect .",
#  '   .',
#  '  months later these puppies are holding their form and feel wonderful .',
#  'in fact , ive ordered another pair just so i can have them at the ready and use them back and forth to save on wear and tear .',
# ...
#  'I can not play in standard goggles any more .',
#  'The vision is great .',
#  'I suggest placing the lens portion in a tube sock in                     scratches .',
#  '  I usually wear a bandana or sweat band , which extends to life of the iMask sweatband .',
#  "  I 'm on my second iMask .",
#  'The first one reached a point with a few too many nicks and was aged (   or six years of being bent while on ) .',
#  'The new versions headband is an improvement , the old one was just a sponge like thing ( but you got three of them ) .',
#  '  One benefit that your video did not mention is that ( if ) when you get hit with a racquet or an elbow , the iMask takes the blow and flies off .',
#  "I 've had a few of these encounters and walked away unbruised .",
#  '  You learn to push the iMask up when you grab a water bottle .',
#  '  Also , the space between the plastic bridge and the curved lens is smaller than a squash ball .',
#  'I know this since I once lost a ball in the lights and it hit that exact point and got stuck between the bridge and the lens .',
#  '                    point because we could not stop laughing .',
#  '  I happened to have a look at some squash doubles clips earlier today and Nick Matthew and Adrian Grant seemed to be using these during the   Commonwealth games , if not the same at least something very similar : https : //www.youtube.com/watch ?',
#  'v=uR xA    I love the i-mask .',
#  "I wear glasses , and I 've found the i-mask to be far superior to Rx goggles .",
#  "It also does n't  fog at all and , even though it looks awkward , is really very comfortable and light to the point where I 'm not aware that I 'm wearing it .",
#  "Im surprised it is n't more popular , for both glasses and non-glasses wearers .",
#  "         Prince Pro and Prince Team Squash Rackets   here 's a sneak peek at the Prince Pro and Prince Team range of Prince squash rackets- that are coming out in   .",
#  'Word on the street is these are the same frame shapes as last years models , but Prince moved production to a new factory .',
#  '  The Prince range is now split into " Pro " and " Team " models .',
#  'My guess is the Pro models will be the high-end rackets and the Team models will be the mid-range rackets .',
#  '  In terms of design , the Pro models have a color on the outside part of the frame , and black on the inside of the frame .',
#  'The Team models have black on the outside of the frame and a color on the inside .',
#  '  Prince Pro Models   These models appear to include the newer TeXtreme material .',
#  'I believe the names are :        Comments   I have read the specs of the new racquets at my local shop who got the advance brochure a few weeks                         .',
#  'The Pro Phantom is a " replacement " for the Pro Rebel ( previously the EXO  Rebel ) .',
#  '  .',
#  'As noted above , the " Pro " models are the largely the same as the " Team " models except for the addition of the lighter , stiffer , higher quality TexTreme carbon .',
#  'This makes them much lighter but also considerably more expensive !',
#  '  .',
#  'The TexTreme now wraps around the whole top part of the frame ( from around   oclock right over the top and round to around to   oclock ) .',
#  'The previous   TexTreme racquets only had a small patch at   oclock and   oclock points .',
#  '  .',
#  "The new Pro Beast is the only racquet in the range to use the Powerbite string pattern and is slightly heavier than its predecessor at  g unstrung ; the previous ones were  g ( I should know , I 've had four of them ! )",
#  '.',
#  '  .',
#  'Spec-wise , I do n\'t  think the other " new " racquets have changed a great deal from their earlier                     the entire range by about  % .',
#  'This might just be for me being in the UK and the - being weaker in comparison to the G/$ last year but could also be due to the extra TexTreme used in their construction .',
#  '  So , Looks like the Pro rackets feature Textreme , and the team rackets do not .',
#  '  Other than that , the four in each range are the same spec in terms of weight and power and string pattern ?',
#  'Looks like the Phantom take the ** ; ;TOOLONG head shape , whereas the other three are the Airsick/Warrior/Beast and look like the airsick headship , probably mimic the previous models and weights that these ranges have always followed .',
#  '  The beast definitely has the    string pattern , whereas the airsick and the warrior have the    .',
#  '  Nice to see them simplify their range at last , but a shame theyve not gone with putting some speed/  ports in the other headshape style of racket I always wondered how that would play as my favourites of all time were the speed port black                     strange to not see a team or rebel among those .',
#  'I think it is a shame the way there is so little information to find about Prince Squash gear nowadays , I cant even find an official website of them anymore .. \n         Asics Gel Fireblast   The Asics Gel Fireblast has been around for a couple years now .',
#  'World #  Mohamed El Shorbagy uses these shoes , as does top French player Gregoire Marche .',
#  'Some readers felt these shoes gouged their ankles though .',
#  'Read on for more details .',
#  '       Three members at our club , including me , bought these shoes two weeks ago .',
#  'All   of us now regularly finish games with blooded socks with  cm wounds just below the inside ankles .',
#  'Skin removed at the same spot .',
#  'All of us are regular Asics wearers but it appears this new brand has a design fault .',
#  '  On the other side of the coin , turns out Mohamed El Shorbagy wears these now .',
#  'In fact he won the Qatar Classic in them .',
#  'Here he is :        Comments   So i got this shoe like a month ago and thought i would give some feedback .',
#  'A little heads up before , so you know what i am comparing it to , i had these before                     asics rocket ( pro:great for narrow feet , light , low price , good grip and cushioning/ con:weak support ankle hurt after intense sessions ) -adidas court stabil   ( pro:great for narrow feet , light , good support/con : needed to buy insole for better cushioning ) -adidas counterblast ( pro:light , good grip and cushioning/con : price , not supportive enough for my ankle ) -adidas adipower stabil   ( pro:great for wide feet , great support and cushioning/con : price , heavy-bulky ) -mizuno wave stealth   ( pro:great for wide feet , great support and cushioning , good grip/con : price , feels to high from the ground ) And now the fireblast .',
#  'I have narrow feet so its perfect for me .',
#  'Someone with wide feet might find it to snug .',
#  'Great grip and great cushioning , but the best thing that i just love is the " side wing " it just gives you the best stability and push off , that i have ever experienced .',
#  'It is pricey , but being an older model you can find good discounts online                     it , it feels restrictive and akward .',
#  'After the break in period it just molds after your feet and becomes supper comfortable .',
#  'Has a low feeling to it on the court but still has great cushioning .',
#  'So my final verdict : best shoe i have ever played in ( but i have narrow feet ) .',
#  "A bit pricey if you do n't  find a discount and needs a break-in period .",
#  'Asside from this I highly recommend it = Cheers , Zsolt   Each of them is great , and distinctive in their own way .',
#  'Rockets made up in price and affordability what it lacked in cushioning or design .',
#  'Blades were a little low , but comfortable , maneuverable and great grip .',
#  'But the best so far are the Blasts .',
#  '  I am due to switch my shoes again .',
#  'Wondering if the Fireblasts are the next logical progression for me .',
#  'The first thing that strikes me is the price .',
#  'At $  they are by far , in my opinion , the costliest squash shoes in the market .',
#  '                      .',
#  'If not , then what other pair would you recommend from the Asics stable .',
#  "Perhaps because of the price , I 've not seen many people wear this in the East Coast .",
#  'The Yellow-Black ones look killer , but seem to be really hard to find , like what Gregoire Marche wears .',
#  '  Any advice from Pierre on any other reader , before I take the rather expensive plunge into this pair .',
#  'There must be something special for it to be priced so high .',
#  'I am guessing this is even costlier than a top-end Asics Running Shoe !',
#  '  Hello .',
#  "I 've asked Brian this morning about the shoes cutting into the ankles .",
#  'He has had no such problems .',
#  'Says there are very light and manoverable .',
#  'Having been World no.',
#  "  a few years ago I 'll take his review with more confidence than the others .",
#  'Although everyone of course is different .',
#  "But I still think I 'm going to buy a pair .",
#  'Looking at the black and yellow model .',
#  "Thanks \n         Sponsored Links product i 'd :          Apparently this racket is made with basalt fibers .",
#  "That 's right , basalt , which is just cooled-off lava , straight from a volcano .",
#  'Which is exactly what people are going to say about you , if you play with this racket .',
#  '  Spotted   Check out Peter Barker using the racket against Nick Matthew in this crazy rally from the finals of the   Case Swedish Open .',
#  'Peters moving so well .',
#  'You might even say he s flowing like lava .',
#  '  Hiya all , greetings   salutations .',
#  'I managed to buy two (   used and   brand new ) at USD  which I thought was a pretty sweet deal .',
#  'I am currently using the carboflex   which I feel is a so-so racket albeit its immense popularity among the professional players .',
#  'My all-time fave is still the dunlop aerogel  d elite .',
#  'First off , this head-heavy blx tour is a very very powerful racket .',
#  'I played   sets using solely this racket and my buddies simply will                     in last night .',
#  'It was so easy with the head-heavy frame to execute a cross-court nick .',
#  "Regardless of the will power within , I simply can not defy Mother Nature ( I 'm   this year ) , as the games dragged on , the racket really started to feel like Thors hammer .",
#  'In the  th    th game , practically all my forehand volley drops went down ringing the tin like a jackpot machine .',
#  'I had to change my tactics to down-the-wall attrition squash but it was simply no-go .',
#  'The weight distribution is very obvious .',
#  'Overall , it was sheer pleasure playing with this racket but ONLY when the player is fresh .',
#  'Will update on its durability in due course .',
#  'Thank you all .',
#  '  Hope this mail find you well .',
#  'We are professional sporting equipment supplier , tennis , badminton rackets are on sell , and we can also customize racket for you , more info pls referred to http : //www.hm-trade.com/ If any need , pls let us know freely .',
#  'Looking forward to your repy .',
#  '  I                     ) rackets with a  % discount .',
#  'Strung and regripped with a Karakal grip , this racket weighs just under the   grams .',
#  "The Wilson site mentions a balancepoint of  ,  cm ; I 've measured about  ,  cm which I would call slightly head-heavy .",
#  '  Immediately at the first balls I hit with it , it felt good .',
#  'Great control and feel , with plenty of power " under the hood " .',
#  'What I like most about these Wilson Tour BLX rackets is their simple , straight and decent design .',
#  "         Sponsored Links product i 'd :               Marwan has been using the Harrow Silk for years .",
#  'This new racket , the Harrow Response , is also teardrop-shaped but from the picture appears to be a slightly different frame .',
#  '  Harrow says the racket has a " new trap door end cap " .',
#  "I guess that means if there 's a bit of graphite rattling around inside the frame ( which is rare but super annoying ) you can open the trap door and shake it out .",
#  '  Comments   I am wondering if this is an entirely new racquet or a rebranded Harrow Renegade as the specs are the same .',
#  "I question why he did n't  utilize a silk for a signature edition , however the string tension is high for a Harrow at  lbs tension .",
#  "  I 'd like to overlay this racquet to a Silk and Renegade to see how the frames line up .",
#  "         Christian asked this question about compression socks for squash :  squashsource If you 're  USOpenSquash can you review calf compression sleeves you see ?",
#  'Tough to see brands , etc .',
#  'Seem very popular - thx Christian A. Sidor (  ChristianSidor ) October   ,   I was down at the US Read more ...   I was recently looking for some white squash clothing to wear at one of the country clubs here in Philly where they have a white clothing policy .',
#  "It took me a while to find the right stuff , so I thought I 'd share with you what I ended up purchasing .",
#  "Here 's a video overview : And below are Read more ...   Thought I 'd create a page for squash socks so people can ask questions / leave suggestions on what they use .",
#  'For the longest time I just wore regular white athletic crew socks .',
#  'These were cheap and fine , but after a while , the elastic started to wear away and they got sort of droopy , so I was in Read more ...                     via ebay.com Affiliate Links Buy ( US ) : amazon.com ebay.com I got this as a gift for Christmas and am really liking it for squash .',
#  "It 's a little difficult to find this exact item , but thought I would let everyone know about this brand Read more ...   Creating a page for Salming shirts .",
#  "I like this Salming polo shirt : I have n't posted too much in the squash clothing category , but I think this shirt is pretty cool , and I remember Amr Shabana looking dapper in it : Read more ...   Here 's another one of the Adidas Adizero Tee shirts .",
#  'I like this one and this it might go pretty well with my new shoes , which are in transit .',
#  'I might get this shirt but I will wait until I get the shoes to make any moves , though .',
#  "Photos via holabirdsports.com Buy ( US ) : holabirdsports.com Read more ...   Here 's James Willstrop ( left ) and Ramy Ashour from the semifinals of the   North American Open .",
#  'I like Willstrop                     be confused with his orange look , which goes better with his shoes .',
#  "Photo by Dan Bogosh for naosquash.com Anyhow I tracked down this Read more ... \n         Asics Gel Rocket     here 's the Asics Gel Rocket   .",
#  'Asics Gel Rockets are relatively low-priced and usually have pretty cool styles , making them one of the most popular squash shoes around .',
#  '  I tested out this shoe and my video review is here :   This shoe comes in lots of different color schemes , some of which are no longer available .',
#  'Please see below for the different variations .',
#  'Where possible , Ive provided affiliate links .',
#  'If you buy through one of these affiliate links , I will receive a small commission thanks !',
#  '  The weight of these shoes is   grams per shoe ( based on a mens US size  .  pair that I own ) .',
#  '  Comments   Hi Jo , I have a pair here .',
#  'The insole is glued down , but it looks like it can be peeled up and removed .',
#  "I was able to peel it off partway , though I did n't  pull it all the way up because I did n't  want to risk wrecking them .",
#  'In a                     remained stuck to the bottom of the shoe ) as I peeled it back , but I suspect this is because I have been using these shoes for a while and all the pounding has probably fused them together , especially at the heel where I tried to unpeel them .',
#  "I ca n't be  % sure but my guess is you 'll be able to remove it no problem .",
#  '  Ive been wearing Rockets since around new year .',
#  'I agree they do all you need at a pretty low price and look OK as well .',
#  'I previously wore Blasts which although more cushioned felt significantly heavier .',
#  'I still have a pair of Upcourts from the Xmas sales in the cupboard   Just picked these up this week " the white/blue/lime version .',
#  "I 'm really enjoying them .",
#  ...]

# %%
sentences = [tokenize.word_tokenize(sentence) for sentence in text]
sentences = [[word.lower() for word in sentence] for sentence in sentences]

# %%
# trained Naive Bayes classifier for the target word 'hard'
classifier = wsd_classifier(NaiveBayesClassifier.train, 'hard.pos', wsd_context_features)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8927

# %%
def extract_vocabulary_frequency(sentences, target_word, stopwords=STOPWORDS_SET, n=300):
  fd = nltk.FreqDist()
  for sentence in sentences:
    for word in set(sentence) - set(stopwords) - set(target_word):
      fd[word] += 1

  return fd.most_common()[:n+1]


def extract_vocabulary(sentences, target_word="", stopwords=STOPWORDS_SET, n=300):
  return [w for w, f in extract_vocabulary_frequency(sentences, target_word, stopwords, n)]

# %%
vocabulary_hard = extract_vocabulary(sentences, "hard")
vocabulary_hard
# Out:
# ['.',
#  ',',
#  'racket',
#  'squash',
#  ')',
#  '(',
#  ':',
#  'like',
#  "'s",
#  "n't",
#  'power',
#  'one',
#  '!',
#  'shoes',
#  'head',
#  'good',
#  'rackets',
#  'string',
#  'read',
#  '?',
#  'would',
#  '...',
#  'control',
#  'new',
#  'also',
#  'used',
#  "'m",
#  'feel',
#  'strings',
#  'dunlop',
#  'asics',
#  'shoe',
#  'great',
#  'prince',
#  'get',
#  'version',
#  'think',
#  'using',
#  "'ve",
#  'pro',
#  'much',
#  'ball',
#  'really',
#  '``',
#  'play',
#  'court',
#  'gel',
#  'comments',
#  'racquet',
#  'grip',
#  'bit',
#  'use',
#  'even',
#  'players',
#  'time',
#  'tecnifibre',
#  'playing',
#  'see',
#  'balance',
#  'well',
#  'adidas',
#  'light',
#  'weight',
#  'better',
#  'black',
#  'years',
#  'played',
#  'first',
#  'back',
#  'try',
#  'frame',
#  'stabil',
#  '-',
#  'around',
#  'model',
#  'tried',
#  'game',
#  'find',
#  'best',
#  'grams',
#  'know',
#  'little',
#  'two',
#  'different',
#  "'d",
#  'hi',
#  'say',
#  'got',
#  'felt',
#  'quite',
#  'sure',
#  'could',
#  'bought',
#  'eye',
#  'tension',
#  'though',
#  'hit',
#  'still',
#  'last',
#  'thanks',
#  'pretty',
#  'links',
#  'carboflex',
#  'strung',
#  'since',
#  'salming',
#  'buy',
#  'found',
#  'us',
#  'tour',
#  'feels',
#  'player',
#  'review',
#  'models',
#  'go',
#  'lot',
#  'want',
#  'seems',
#  'never',
#  'product',
#  'heavy',
#  'far',
#  'looks',
#  'touch',
#  'harrow',
#  'months',
#  'durability',
#  'actually',
#  'nice',
#  'way',
#  'many',
#  'world',
#  'called',
#  'ive',
#  'looking',
#  'ramy',
#  "'re",
#  'difference',
#  'week',
#  'old',
#  '+',
#  'shots',
#  'range',
#  'made',
#  'lbs',
#  'might',
#  'love',
#  'less',
#  'graphene',
#  'top',
#  'another',
#  'similar',
#  'right',
#  'elite',
#  'blade',
#  'heavier',
#  'shape',
#  'pair',
#  'via',
#  'look',
#  'make',
#  'people',
#  'update',
#  'size',
#  ';',
#  'year',
#  'pros',
#  'recommend',
#  'reviews',
#  'lighter',
#  'adipower',
#  'factory',
#  'probably',
#  'give',
#  'open',
#  'karakal',
#  'slightly',
#  'spotted',
#  'biomimetic',
#  'however',
#  'point',
#  'may',
#  'previous',
#  'ago',
#  'anyone',
#  'popular',
#  'sponsored',
#  'need',
#  'long',
#  'ashaway',
#  'pierre',
#  'club',
#  'big',
#  'comfortable',
#  'website',
#  'white',
#  'g',
#  'thought',
#  'balls',
#  'spot',
#  'sweet',
#  'wilson',
#  'hard',
#  'compared',
#  'couple',
#  "'ll",
#  'seem',
#  'blast',
#  'comes',
#  'blue',
#  'original',
#  'powerful',
#  'socks',
#  'red',
#  'airstick',
#  'weeks',
#  'price',
#  'put',
#  'stiff',
#  'thing',
#  'racquets',
#  'going',
#  'cm',
#  'image',
#  'green',
#  'xenon',
#  '/',
#  'wearing',
#  'maybe',
#  'definitely',
#  'enough',
#  'seen',
#  'due',
#  'came',
#  'equipment',
#  'high',
#  'says',
#  'take',
#  'let',
#  'makes',
#  'available',
#  '$',
#  'cushioning',
#  'higher',
#  'mizuno',
#  'swing',
#  'come',
#  'video',
#  'something',
#  'started',
#  'wear',
#  'feet',
#  'small',
#  'ankle',
#  'said',
#  'mm',
#  'getting',
#  '%',
#  'easy',
#  'always',
#  'trying',
#  'pattern',
#  'older',
#  'fit',
#  'tell',
#  'every',
#  'wall',
#  'side',
#  'perfect',
#  'vibration',
#  'cant',
#  'especially',
#  'color',
#  'recently',
#  'men',
#  'support',
#  'foot',
#  'break',
#  'guess',
#  'head-heavy',
#  'note',
#  'several',
#  'almost',
#  'xt',
#  'problem',
#  'end',
#  'name',
#  'post',
#  'ever',
#  'cyano',
#  'line',
#  'times',
#  'change',
#  'cool',
#  'either',
#  'women',
#  'site',
#  'yet',
#  'front',
#  'cut',
#  'next']

# %%
def wsd_condext_features_set(sentence, target_word, vocab, dist=3):
  features = {}
  try:
    ind = sentence.index(target_word)
  except ValueError:
    return {}

  for i in range(max(0, ind - dist), ind):
    j = ind - i
    features['left-context-word-%s(%s)' % (j, sentence[i])] = True

  for i in range(ind + 1, min(ind + dist + 1, len(sentence))):
    j = ind - i
    features['right-context-word-%s(%s)' % (j, sentence[i])] = True

  features['word'] = target_word   

  return features

# %%
res_hard = [classifier.classify(wsd_condext_features_set(sentence, 'hard', vocabulary_hard)) for sentence in sentences if 'hard' in sentence]
res_hard
# Out:
# ['HARD1',
#  'HARD2',
#  'HARD2',
#  'HARD3',
#  'HARD3',
#  'HARD3',
#  'HARD3',
#  'HARD1',
#  'HARD1',
#  'HARD2',
#  'HARD3',
#  'HARD2',
#  'HARD1',
#  'HARD2',
#  'HARD2',
#  'HARD1',
#  'HARD2',
#  'HARD2',
#  'HARD2',
#  'HARD1',
#  'HARD1',
#  'HARD3',
#  'HARD3',
#  'HARD3',
#  'HARD1',
#  'HARD1',
#  'HARD2',
#  'HARD3',
#  'HARD3',
#  'HARD1',
#  'HARD3',
#  'HARD2',
#  'HARD2',
#  'HARD3',
#  'HARD1',
#  'HARD3',
#  'HARD3',
#  'HARD1',
#  'HARD3',
#  'HARD2',
#  'HARD3',
#  'HARD1',
#  'HARD3',
#  'HARD1',
#  'HARD1',
#  'HARD1',
#  'HARD1',
#  'HARD3',
#  'HARD1',
#  'HARD2',
#  'HARD3',
#  'HARD3',
#  'HARD2',
#  'HARD3',
#  'HARD3',
#  'HARD1',
#  'HARD2',
#  'HARD1',
#  'HARD1',
#  'HARD1',
#  'HARD2',
#  'HARD2',
#  'HARD2',
#  'HARD2',
#  'HARD2',
#  'HARD2',
#  'HARD3',
#  'HARD1',
#  'HARD1',
#  'HARD1',
#  'HARD1',
#  'HARD3']

# %%
# trained Naive Bayes classifier for the target word 'line'
classifier2 = wsd_classifier(NaiveBayesClassifier.train, 'line.pos', wsd_context_features)
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.7470

# %%
vocabulary_line = extract_vocabulary(sentences, "line")
res_line = [classifier2.classify(wsd_condext_features_set(sentence, 'line', vocabulary_line)) for sentence in sentences if 'line' in sentence]
set(res_line)
# Out:
# {'cord', 'division', 'formation', 'phone', 'product', 'text'}

# %%
nltk.download('wordnet')

from nltk.corpus import wordnet as wn
from nltk.wsd import lesk
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
for ss in wn.synsets('hard'):
  print(ss, ss.definition())
# Out:
# Synset('difficult.a.01') not easy; requiring great physical or mental effort to accomplish or comprehend or endure
# Synset('hard.a.02') dispassionate;
# Synset('hard.a.03') resisting weight or pressure
# Synset('hard.s.04') very strong or vigorous
# Synset('arduous.s.01') characterized by effort to the point of exhaustion; especially physical effort
# Synset('unvoiced.a.01') produced without vibration of the vocal cords
# Synset('hard.a.07') (of light) transmitted directly from a pointed light source
# Synset('hard.a.08') (of speech sounds); produced with the back of the tongue raised toward or touching the velum
# Synset('intemperate.s.03') given to excessive indulgence of bodily appetites especially for intoxicating liquors
# Synset('hard.s.10') being distilled rather than fermented; having a high alcoholic content
# Synset('hard.s.11') unfortunate or hard to bear
# Synset('hard.s.12') dried out
# Synset('hard.r.01') with effort or force or vigor
# Synset('hard.r.02') with firmness
# Synset('hard.r.03') earnestly or intently
# Synset('hard.r.04') causing great damage or hardship
# Synset('hard.r.05') slowly and with difficulty
# Synset('heavily.r.07') indulging excessively
# Synset('hard.r.07') into a solid condition
# Synset('hard.r.08') very near or close in space or time
# Synset('hard.r.09') with pain or distress or bitterness
# Synset('hard.r.10') to the full extent possible; all the way

# %%
for ss in wn.synsets('line'):
  print(ss, ss.definition())
# Out:
# Synset('line.n.01') a formation of people or things one beside another
# Synset('line.n.02') a mark that is long relative to its width
# Synset('line.n.03') a formation of people or things one behind another
# Synset('line.n.04') a length (straight or curved) without breadth or thickness; the trace of a moving point
# Synset('line.n.05') text consisting of a row of words written across a page or computer screen
# Synset('line.n.06') a single frequency (or very narrow band) of radiation in a spectrum
# Synset('line.n.07') a fortified position (especially one marking the most forward position of troops)
# Synset('argumentation.n.02') a course of reasoning aimed at demonstrating a truth or falsehood; the methodical process of logical reasoning
# Synset('cable.n.02') a conductor for transmitting electrical or optical signals or electric power
# Synset('course.n.02') a connected series of events or actions or developments
# Synset('line.n.11') a spatial location defined by a real or imaginary unidimensional extent
# Synset('wrinkle.n.01') a slight depression in the smoothness of a surface
# Synset('pipeline.n.02') a pipe used to transport liquids or gases
# Synset('line.n.14') the road consisting of railroad track and roadbed
# Synset('telephone_line.n.02') a telephone connection
# Synset('line.n.16') acting in conformity
# Synset('lineage.n.01') the descendants of one individual
# Synset('line.n.18') something (as a cord or rope) that is long and thin and flexible
# Synset('occupation.n.01') the principal activity in your life that you do to earn money
# Synset('line.n.20') in games or sports; a mark indicating positions or bounds of the playing area
# Synset('channel.n.05') (often plural) a means of communication or access
# Synset('line.n.22') a particular kind of product or merchandise
# Synset('line.n.23') a commercial organization serving as a common carrier
# Synset('agate_line.n.01') space for one line of print (one column wide and 1/14 inch deep) used to measure advertising
# Synset('credit_line.n.01') the maximum credit that a customer is allowed
# Synset('tune.n.01') a succession of notes forming a distinctive sequence
# Synset('line.n.27') persuasive but insincere talk that is usually intended to deceive or impress
# Synset('note.n.02') a short personal letter
# Synset('line.n.29') a conceptual separation or distinction
# Synset('production_line.n.01') mechanical system in a factory whereby an article is conveyed through sites at which successive operations are performed on it
# Synset('line.v.01') be in line with; form a line along
# Synset('line.v.02') cover the interior of
# Synset('trace.v.02') make a mark or lines on a surface
# Synset('line.v.04') mark with lines
# Synset('line.v.05') fill plentifully
# Synset('line.v.06') reinforce with fabric

# %% [markdown]
# **Lesk algorithm**

# %%
lesk_res_hard = [(i, lesk(sent, 'hard')) for i, sent in enumerate(sentences) if 'hard' in sent]
lesk_res_line = [(i, lesk(sent, 'line')) for i, sent in enumerate(sentences) if 'line' in sent]

# %%
lesk_res_hard
# Out:
# [(62, Synset('hard.s.11')),
#  (277, Synset('unvoiced.a.01')),
#  (577, Synset('intemperate.s.03')),
#  (598, Synset('hard.r.10')),
#  (652, Synset('hard.s.11')),
#  (731, Synset('hard.s.11')),
#  (841, Synset('hard.a.08')),
#  (921, Synset('hard.s.11')),
#  (1119, Synset('hard.s.11')),
#  (1355, Synset('hard.s.11')),
#  (1381, Synset('hard.a.08')),
#  (1393, Synset('hard.s.11')),
#  (1480, Synset('hard.r.10')),
#  (1487, Synset('hard.s.11')),
#  (1531, Synset('hard.a.08')),
#  (1573, Synset('hard.r.10')),
#  (1580, Synset('hard.s.11')),
#  (1710, Synset('hard.s.11')),
#  (1714, Synset('hard.a.08')),
#  (1828, Synset('hard.s.11')),
#  (1913, Synset('arduous.s.01')),
#  (2103, Synset('unvoiced.a.01')),
#  (2286, Synset('unvoiced.a.01')),
#  (2336, Synset('hard.s.11')),
#  (2389, Synset('hard.s.11')),
#  (2442, Synset('hard.s.11')),
#  (2467, Synset('unvoiced.a.01')),
#  (2551, Synset('hard.s.11')),
#  (2625, Synset('hard.s.11')),
#  (2643, Synset('hard.s.11')),
#  (2689, Synset('hard.a.08')),
#  (2690, Synset('difficult.a.01')),
#  (2703, Synset('intemperate.s.03')),
#  (2910, Synset('hard.s.11')),
#  (2915, Synset('hard.s.11')),
#  (2920, Synset('hard.s.11')),
#  (3092, Synset('hard.s.11')),
#  (3097, Synset('hard.s.11')),
#  (3102, Synset('hard.s.11')),
#  (3145, Synset('unvoiced.a.01')),
#  (3190, Synset('hard.s.11')),
#  (3222, Synset('arduous.s.01')),
#  (3427, Synset('hard.s.11')),
#  (3625, Synset('hard.r.10')),
#  (3746, Synset('hard.s.11')),
#  (4076, Synset('hard.s.11')),
#  (4291, Synset('hard.s.11')),
#  (4373, Synset('hard.s.11')),
#  (4376, Synset('hard.s.11')),
#  (4626, Synset('unvoiced.a.01')),
#  (4629, Synset('arduous.s.01')),
#  (4634, Synset('arduous.s.01')),
#  (4777, Synset('unvoiced.a.01')),
#  (4780, Synset('arduous.s.01')),
#  (4785, Synset('arduous.s.01')),
#  (5055, Synset('hard.r.10')),
#  (5139, Synset('hard.s.11')),
#  (5191, Synset('hard.s.11')),
#  (5299, Synset('hard.s.11')),
#  (5315, Synset('arduous.s.01')),
#  (5369, Synset('intemperate.s.03')),
#  (5481, Synset('intemperate.s.03')),
#  (5645, Synset('hard.a.08')),
#  (5649, Synset('unvoiced.a.01')),
#  (5700, Synset('hard.a.08')),
#  (5704, Synset('unvoiced.a.01')),
#  (6258, Synset('unvoiced.a.01')),
#  (6270, Synset('hard.r.08')),
#  (6748, Synset('hard.r.10')),
#  (6782, Synset('hard.r.10')),
#  (6998, Synset('hard.r.05')),
#  (7168, Synset('hard.s.11'))]

# %%
lesk_res_line
# Out:
# [(147, Synset('agate_line.n.01')),
#  (254, Synset('line.n.20')),
#  (409, Synset('agate_line.n.01')),
#  (501, Synset('production_line.n.01')),
#  (679, Synset('agate_line.n.01')),
#  (801, Synset('agate_line.n.01')),
#  (832, Synset('wrinkle.n.01')),
#  (969, Synset('agate_line.n.01')),
#  (1076, Synset('agate_line.n.01')),
#  (1272, Synset('agate_line.n.01')),
#  (1295, Synset('agate_line.n.01')),
#  (1382, Synset('agate_line.n.01')),
#  (1395, Synset('production_line.n.01')),
#  (1418, Synset('wrinkle.n.01')),
#  (1512, Synset('production_line.n.01')),
#  (1605, Synset('production_line.n.01')),
#  (1646, Synset('production_line.n.01')),
#  (1669, Synset('wrinkle.n.01')),
#  (2761, Synset('production_line.n.01')),
#  (2762, Synset('wrinkle.n.01')),
#  (2943, Synset('production_line.n.01')),
#  (2944, Synset('wrinkle.n.01')),
#  (3557, Synset('wrinkle.n.01')),
#  (3616, Synset('wrinkle.n.01')),
#  (3972, Synset('wrinkle.n.01')),
#  (3977, Synset('wrinkle.n.01')),
#  (4067, Synset('wrinkle.n.01')),
#  (4072, Synset('wrinkle.n.01')),
#  (4219, Synset('occupation.n.01')),
#  (4562, Synset('wrinkle.n.01')),
#  (5127, Synset('line.n.02')),
#  (5143, Synset('line.n.02')),
#  (5167, Synset('line.v.01')),
#  (5267, Synset('occupation.n.01')),
#  (5367, Synset('occupation.n.01')),
#  (5453, Synset('line.v.01')),
#  (5466, Synset('line.v.01')),
#  (5479, Synset('occupation.n.01')),
#  (5515, Synset('line.v.01')),
#  (5978, Synset('wrinkle.n.01')),
#  (6111, Synset('agate_line.n.01')),
#  (6180, Synset('production_line.n.01')),
#  (6217, Synset('wrinkle.n.01')),
#  (6637, Synset('production_line.n.01')),
#  (6644, Synset('occupation.n.01')),
#  (6994, Synset('line.v.01')),
#  (7328, Synset('agate_line.n.01')),
#  (7443, Synset('agate_line.n.01'))]

# %% [markdown]
# **Banerjee & Pedersen's extended Lesk algorithm**

# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
import string
nltk.download('stopwords')
import re

gloss_rel = lambda x: x.definition()
example_rel = lambda x: " ".join(x.examples())
hyponym_rel = lambda x: " ".join(w.definition() for w in x.hyponyms())
meronym_rel = lambda x: " ".join(w.definition() for w in x.member_meronyms() + \
                                 x.part_meronyms() + x.substance_meronyms())
also_rel = lambda x: " ".join(w.definition() for w in x.also_sees())
attr_rel = lambda x: " ".join(w.definition() for w in x.attributes())
hypernym_rel = lambda x: " ".join(w.definition() for w in x.hypernyms())

relpairs = {wn.NOUN: [(hyponym_rel, meronym_rel), (meronym_rel, hyponym_rel),
                      (hyponym_rel, hyponym_rel),
                      (gloss_rel, meronym_rel), (meronym_rel, gloss_rel),
                      (example_rel, meronym_rel), (meronym_rel, example_rel),
                      (gloss_rel, gloss_rel)],
            wn.ADJ: [(also_rel, gloss_rel), (gloss_rel, also_rel),
                     (attr_rel, gloss_rel), (gloss_rel, attr_rel),
                     (gloss_rel, gloss_rel),
                     (example_rel, gloss_rel), (gloss_rel, example_rel),
                     (gloss_rel, hypernym_rel), (hypernym_rel, gloss_rel)],
            wn.VERB:[(example_rel, example_rel),
                     (example_rel, hypernym_rel), (hypernym_rel, example_rel),
                     (hyponym_rel, hyponym_rel),
                     (gloss_rel, hyponym_rel), (hyponym_rel, gloss_rel),
                     (example_rel, gloss_rel), (gloss_rel, example_rel)]}

def preprocess(text):
    """
    Helper function to preprocess text (lowercase, remove punctuation etc.)
    """
    words = nltk.word_tokenize(text)
    punctuation = string.punctuation
    words = [word.lower() for word in words if word not in punctuation]
    words = [word for word in words if not word in stopwords.words('english')] # ? not part of the original algorithm to remove all stopwords! (only ones at the edges of the subsequence)
    return words

def lcs(S1, S2):
    """
    Helper function to compute length and offsets of longest common substring of
    S1 and S2. Uses the classical dynamic programming algorithm.
    """
    M = [[0]*(1+len(S2)) for i in range(1+len(S1))]
    longest, x_longest, y_longest = 0, 0, 0
    for x in range(1,1+len(S1)):
        for y in range(1,1+len(S2)):
            if S1[x-1] == S2[y-1]:
                M[x][y] = M[x-1][y-1] + 1
                if M[x][y]>longest:
                    longest = M[x][y]
                    x_longest = x
                    y_longest = y
            else:
                M[x][y] = 0
    return longest, x_longest - longest, y_longest - longest

def score(gloss1, gloss2, normalized=False):
    """
    Compute score between two glosses based on length of common substrings.
    """
    gloss1 = preprocess(gloss1)
    gloss2 = preprocess(gloss2)
    curr_score = 0
    longest, start1, start2, = lcs(gloss1, gloss2)
    while longest > 0:
        gloss1[start1 : start1 + longest] = []
        gloss2[start2 : start2 + longest] = []
        curr_score += longest ** 2
        longest, start1, start2 = lcs(gloss1, gloss2)
    if normalized and curr_score:
      return curr_score / (len(gloss1) + len(gloss2))
    return curr_score

def relatedness(sense1, sense2, relpairs, normalized=False):
    """
    Compute the relatedness of two senses (synsets) using the list of pairs of
    relations in relpairs.
    """
    return sum(score(pair[0](sense1), pair[1](sense2), normalized=normalized) # Note: normalization not explicitly part of original algorithm!
    for pair in relpairs)

def wsd(context, target, winsize, pos_tag, verbose=False, normalized=False):
    """
    Find the best sense for a word in a given context.
    Arguments:
    context - sentence(s) we are analyzing; expected as list of strings
    target  - string representing the word whose senses we're trying to
              disambiguate. Target is assumed to occur once in sentence. In case
              of multiple occurences, the first one is considered. Will throw
              ValueError if target is not in sentence
    winsize - size of window used for disambiguating. The algorithm will only
              look at winsize words of the appropriate part-of-speech around the
              target word
    pos_tag - part of speech of target word
    """
    context = list(filter(None, [wn.synsets(word, pos=pos_tag) for word in context]))
    target_synsets = wn.synsets(target, pos=pos_tag)
    try:
      pos = context.index(target_synsets)
    except ValueError:
      return None, 0.

    window = context[max(pos - winsize, 0) : pos] + \
             context[pos + 1 : min(pos + winsize + 1, len(context))]
    sense_scores = [sum(sum(relatedness(sense, other_sense, relpairs[pos_tag], normalized=normalized)
                              for other_sense in senses)
                   for senses in window) for sense in target_synsets]
    if verbose:
      print("All scores:")
      for i, s in enumerate(target_synsets):
        print(sense_scores[i], s, s.definition())
    best_score = max(sense_scores)
    best_index = sense_scores.index(best_score)
    return target_synsets[best_index], best_score
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sentences_preprocessed = [preprocess(' '.join(sentence)) for sentence in sentences]
sentences_preprocessed
# Out:
# [['types', 'squash', 'grips', 'racket', 'come', 'stock', 'factory', 'grip'],
#  ['put',
#   'overgrip',
#   'top',
#   'help',
#   'sweat',
#   'absorption',
#   'increase',
#   'size',
#   'grip',
#   'make',
#   'racket',
#   'feel',
#   'comfortable',
#   'freakishly',
#   'large',
#   'hands'],
#  ['also', 'buy', 'replacement', 'grip'],
#  ['case',
#   'remove',
#   'factory',
#   'grip',
#   'put',
#   'replacement',
#   'grip',
#   'instead'],
#  ['generally', 'use', 'overgrips'],
#  ['favorite', 'always', 'tourna', 'grip'],
#  ["'s",
#   'video',
#   'review',
#   'tourna',
#   'grip',
#   'along',
#   'brief',
#   'tutorial',
#   'grip',
#   'squash',
#   'racket'],
#  ["n't",
#   'use',
#   'replacement',
#   'grips',
#   'often',
#   "'d",
#   'guess',
#   'brand',
#   'replacement',
#   'squash',
#   'grips',
#   'karakal',
#   'pu',
#   'super',
#   'grip'],
#  ['tons', 'pros', 'use', 'karakal'],
#  ['picking', 'grip', 'personal', 'matter'],
#  ['obviously', 'need', 'squash', 'racket', 'feel', 'comfortable', 'hands'],
#  ['experiment',
#   'different',
#   'squash',
#   'grips',
#   'see',
#   'works',
#   'best',
#   'freakishly',
#   'want',
#   'see',
#   'grip',
#   'ramy',
#   'ashour',
#   'used',
#   'win',
#   'world',
#   'championships'],
#  ['sure'],
#  ['comments', 'thoughts', 'grips'],
#  ['gone', 'replacement', 'grips', 'overgrips'],
#  ['overgrips',
#   'faster',
#   'change',
#   'cheaper',
#   'good',
#   'tack',
#   'usually',
#   'use',
#   'sides'],
#  ['points', 'mean', 'change', 'often', 'replacement', 'grips', 'money'],
#  ['buy', 'thin', 'overgrips', 'effect', 'grip', 'size', 'much'],
#  ['karakal', 'pu', 'supergrip'],
#  ['used',
#   'grip',
#   'rackets',
#   'honestly',
#   "n't",
#   'get',
#   'huge',
#   'love',
#   'people'],
#  ['experience',
#   'initially',
#   'great',
#   'tack',
#   'loses',
#   'great',
#   'tackiness',
#   'first',
#   'matches',
#   'becomes',
#   'average',
#   'quite',
#   'fast'],
#  ['technifibre', 'absolut', 'squash', 'replacement', 'grip'],
#  ['good',
#   'initial',
#   'tackiness',
#   'feel',
#   'looses',
#   'best',
#   'feel',
#   'tackiness',
#   'quite',
#   'fast'],
#  ['okay', 'sweaty', 'hands', 'great'],
#  ['would', 'call', 'overall', '``', 'okay', '``', 'product', 'el', 'shorbagy'],
#  ['tourna', 'grip', 'overgrip'],
#  ['initial', 'tackiness', 'good', 'great'],
#  ['dry', '``', 'sandpaper-like', '``', 'feel', 'great', 'durability'],
#  ['best',
#   'grip',
#   'sweaty',
#   'hands',
#   'tackiness',
#   'actually',
#   'increases',
#   'little',
#   'moisture',
#   'get',
#   'slippery',
#   'sweat'],
#  ['bonus', 'use', 'sides', 'grip', 'like', 'wilson', 'yonex'],
#  ['one', 'best', 'overgrips', 'market'],
#  ['rab', 'reflex', 'dry', 'overgrip'],
#  ['tries', 'emulate', 'tourna', 'grip', 'succeeds', 'poorly'],
#  ['low', 'initial', 'tackiness', 'gets', 'little', 'better', 'sweat/moisture'],
#  ['recommend', 'product'],
#  ['wilson', 'pro', 'overgrip'],
#  ['one', 'best', 'overgrips'],
#  ['silky', 'smooth', 'feel', 'difficult', 'explain', 'good', 'tack'],
#  ['smooth', 'feel', 'grip', 'probably', 'best', 'trait'],
#  ['okay', 'sweaty', 'hands', 'good', 'tourna'],
#  ['average',
#   'durability',
#   'use',
#   'sides',
#   '-pack',
#   'actually',
#   'becomes',
#   '-pack'],
#  ['highly', 'recommended', 'yonex', 'super', 'grap', 'overgrip'],
#  ['quite', 'similar', 'good', 'sweaty', 'hands'],
#  ['maybe',
#   'looses',
#   'tackiness',
#   'slightly',
#   'faster',
#   'wilson',
#   'overall',
#   'good',
#   'overgrip'],
#  ['average', 'durability', 'use', 'sides'],
#  ['head', 'xtreme', 'soft'],
#  ['great', 'initial', 'tackiness'],
#  ['nice', 'rubbery', 'feel', 'neon', 'yellow', 'looks', 'cool'],
#  ['tackiness', 'outlasts', 'yonex', 'wilson', 'good', 'durability'],
#  ['slightly', 'thicker', 'yonex', 'wilson'],
#  ['sweaty',
#   'hands',
#   'initially',
#   'feels',
#   'like',
#   'good',
#   'adsorbtion',
#   'depending',
#   'much',
#   'sweat',
#   'suddenly',
#   'become',
#   'slippery'],
#  ['one-sided',
#   'cant',
#   'use',
#   'twice',
#   'overall',
#   'good',
#   'tacky',
#   'grip',
#   'sweat',
#   'alot',
#   'hands'],
#  ['salming', 'extreme', 'sticky', 'replacement', 'grip', 'overgrip'],
#  ['replacement-',
#   'overgrip',
#   'feel',
#   'quite',
#   'similar',
#   'except',
#   'thickness'],
#  ['good', 'tackiness', 'rubbery', 'feel', 'like', 'head'],
#  ['nice', 'feel', 'looks', 'cool', 'average', 'durability'],
#  ['best', 'choice', 'sweaty', 'hands'],
#  ['overall', 'good', 'products'],
#  ['feel',
#   'grips',
#   'tested',
#   'bunch',
#   'grips',
#   'aswell',
#   'ill',
#   'get',
#   'another',
#   'time'],
#  ['tried', 'long'],
#  ['heavy',
#   'maybe',
#   'grams',
#   'changes',
#   'racket',
#   'specks',
#   'totally',
#   'work',
#   'superlite',
#   'headhavy',
#   'harrow',
#   'strung',
#   'balance',
#   'ending',
#   'headlight',
#   'heavy',
#   'racket'],
#  ['kimono', 'grip', 'lightest', 'http', '**', 'toolong'],
#  ['tried',
#   'also',
#   'leather',
#   'grip',
#   'forgiving/dampened',
#   'find',
#   'hard',
#   'hand',
#   'returned',
#   'regular',
#   'karakal',
#   'pu'],
#  ['tor',
#   'leather',
#   'grips',
#   'fairway',
#   'kimony',
#   'norway',
#   'still',
#   'want',
#   'try/buy'],
#  ['ole',
#   'overview',
#   'high',
#   'levels',
#   'tackiness',
#   'sweat',
#   'absorption',
#   'comfort',
#   'incredible',
#   'durability',
#   'pu',
#   'supergrip',
#   'sets',
#   'standard',
#   'grips',
#   'aspire'],
#  ['grip',
#   'available',
#   'different',
#   'colours',
#   'appear',
#   'slightly',
#   'different',
#   'properties',
#   'green',
#   'seems',
#   'less',
#   'tacky',
#   'extended',
#   'use',
#   'example',
#   'found',
#   'yellow',
#   'grip',
#   "'ve",
#   'probably',
#   'guessed',
#   'eye',
#   'rackets',
#   'fan'],
#  ['think', 'include', 'grips', 'eye', 'x', 'tacky', 'grip'],
#  ['find', 'reviews', 'information', 'grips', 'well', 'squashxtra', 'app'],
#  ['latest', 'issue', 'talks', 'grips'],
#  ['example',
#   'says',
#   'eye',
#   'grip',
#   'overview',
#   'super',
#   'soft',
#   'extremely',
#   'comfortable',
#   'hand',
#   'x.tacky',
#   'offers',
#   'high',
#   'level',
#   'sweat',
#   'absorption',
#   'maintains',
#   'properties',
#   'even',
#   'prolonged',
#   'usage',
#   'heavy',
#   'sweat',
#   'exposure'],
#  ['tackiness',
#   'level',
#   'incredibly',
#   'high',
#   'leading',
#   'secure',
#   'comfortable',
#   'feel',
#   'however',
#   'mean',
#   'on-the-ny',
#   'grip',
#   'changes',
#   'feel',
#   'clumsy',
#   'awkward',
#   'especially',
#   'starting',
#   'tackiness',
#   'highest',
#   'whilst',
#   'karakal',
#   'says',
#   'overview',
#   'super',
#   'soft',
#   'extremely',
#   'comfortable',
#   'hand',
#   'x.tacky',
#   'offers',
#   'high',
#   'level',
#   'sweat',
#   'absorption',
#   'maintains',
#   'properties',
#   'even',
#   'prolonged',
#   'usage',
#   'heavy',
#   'sweat',
#   'exposure'],
#  ['tackiness',
#   'level',
#   'incredibly',
#   'high',
#   'leading',
#   'secure',
#   'comfortable',
#   'feel',
#   'however',
#   'awkward',
#   'especially',
#   'starting',
#   'tackiness',
#   'highest',
#   'used',
#   'eye',
#   'rackets',
#   'fan',
#   'say',
#   'karakal',
#   'better',
#   'eye',
#   'grips'],
#  ['duration',
#   'quite',
#   'longer',
#   'karakal',
#   'feeling',
#   'similar',
#   'prefer',
#   'thiker',
#   'grips'],
#  ['personally', 'prefer', 'karakal', 'grips'],
#  ['costumize', 'racket', 'different', 'colours', 'grips'],
#  [],
#  ['like',
#   'add',
#   'eye',
#   'grips',
#   'better',
#   'expected',
#   'soft',
#   'thick',
#   'dry',
#   'grip'],
#  ['good',
#   'starting',
#   'point',
#   'brand',
#   'improve',
#   'little',
#   'aspects',
#   'grip',
#   'level',
#   'unbelievable',
#   'rackets'],
#  ['extreme', 'grip', 'problems', 'due', 'sweaty', 'hands'],
#  ['grip', 'recommendations', 'advice'],
#  ['tried', 'every', 'grip', 'recommended'],
#  ['grip',
#   'either',
#   'becomes',
#   'immediately',
#   'slippery',
#   'due',
#   'sweat',
#   'happens',
#   'pu/tacky',
#   'grips',
#   'grips'],
#  ['resort',
#   'tacky-towel',
#   'far',
#   'ideal',
#   'sacrifice',
#   'able',
#   'move',
#   'grip',
#   'changing',
#   'grip',
#   'positions',
#   'ever',
#   'slightly'],
#  ['anyone', 'advice', 'would', 'greatly', 'appreciated'],
#  ['find',
#   'wilson',
#   'overgrips',
#   'best',
#   'tournagrip',
#   'definitely',
#   'best',
#   "'re",
#   'hands',
#   'sweat',
#   'lot',
#   'hate',
#   'way',
#   'feels',
#   'hate',
#   'fact',
#   "'s",
#   'glue',
#   'beginning',
#   'cut',
#   'angle',
#   'plus',
#   'give',
#   'little',
#   'barely',
#   'ever',
#   'enough',
#   'finish',
#   'grip'],
#  ['thanks', 'b+rd', "n't", 'tried', 'eye', 'grips'],
#  ['actually', 'eye', 'racket', 'hand', 'put', 'tourna', 'grip'],
#  ['take', 'see', 'plays'],
#  ['sitting',
#   'tourna',
#   'grip',
#   'several',
#   'months',
#   'may',
#   '``',
#   'fresh',
#   '``',
#   'well',
#   'see'],
#  ['book',
#   'grip',
#   'use',
#   'karakal',
#   'pu',
#   'especially',
#   'green',
#   'tends',
#   'slip',
#   'around',
#   'reason'],
#  ['would',
#   'love',
#   'use',
#   'green',
#   'cool',
#   'color',
#   'squash',
#   'racquet',
#   'yellow',
#   'grips',
#   'perform',
#   'best',
#   'consistently',
#   'get',
#   'box'],
#  ['racquet',
#   'gripping',
#   'technique',
#   'start',
#   'raw',
#   'racquet',
#   'handle',
#   'use',
#   'wraps',
#   'head',
#   'protection',
#   'tape',
#   'clear',
#   'stuff',
#   'gamma',
#   'usually',
#   'tennis',
#   'good',
#   'squash',
#   'overwraps',
#   'get',
#   'desired',
#   'base',
#   'thickness'],
#  ['top',
#   'layer',
#   'putting',
#   'final',
#   'grip',
#   'layer',
#   'head',
#   'protection',
#   'tape',
#   'provides',
#   'smooth',
#   'surface',
#   'grip',
#   'adhere',
#   'also',
#   'allowing',
#   'clean',
#   'removal',
#   'top',
#   'grip',
#   'becomes',
#   'worn'],
#  ['almost',
#   'ukraine',
#   'players',
#   'using',
#   'karakal',
#   'grip',
#   'grip',
#   'country',
#   'really',
#   'good',
#   'grip'],
#  ['found',
#   'self',
#   'new',
#   'grip',
#   'ashaway',
#   'popular',
#   'country',
#   'nobody',
#   'sell',
#   'like',
#   'try',
#   'advice',
#   'buy',
#   'next',
#   'time'],
#  ['cannout',
#   'undesrtand',
#   'offical',
#   'website',
#   'ashaway',
#   'provide',
#   'producst'],
#  ['see', 'strings', 'harrow', 'vapor', 'squash', 'racket', 'harrow', 'vapor'],
#  ['called', 'vapor'],
#  ['slice', 'racket', 'air', 'leaves', 'behind', 'trail', 'water', 'vapor'],
#  ['racket', 'eyes', 'opponent', 'weep', 'softly'],
#  ['sponsored',
#   'links',
#   'product',
#   "'d",
#   'time',
#   'get',
#   'irie',
#   'newest',
#   'design',
#   'harrows',
#   'best',
#   'selling',
#   'racquet',
#   'around',
#   'world'],
#  ['performance',
#   'playability',
#   'come',
#   'expect',
#   'vapor',
#   'jammin',
#   'makeover',
#   'sure',
#   'improve',
#   'game',
#   'style',
#   'mon'],
#  ['maybe', 'racket', 'bob', 'marley', 'would', 'played', 'squash'],
#  ['speaking',
#   'bob',
#   'marley',
#   'ever',
#   'watch',
#   'documentary',
#   'called',
#   'marley'],
#  ['one',
#   'point',
#   'son',
#   'ziggy',
#   'marley',
#   'tells',
#   'story',
#   'bob',
#   'used',
#   'challenge',
#   'kids',
#   'running',
#   'races',
#   'instead',
#   'letting',
#   'kids',
#   'win',
#   'bob',
#   'would',
#   'run',
#   'fast',
#   'possibly',
#   'could'],
#  ['watch',
#   'documentary',
#   'ion',
#   'psx',
#   'element',
#   'black',
#   'non',
#   'selby',
#   'version'],
#  ['tremendous', 'blend', 'power', 'feel', 'durability'],
#  ['ive',
#   'rotating',
#   'rackets',
#   'last',
#   'years',
#   'havent',
#   'suffered',
#   'breakage',
#   'cracks'],
#  ['similar',
#   'terms',
#   'head',
#   'shape',
#   'size',
#   'probably',
#   'fraction',
#   'heavier'],
#  ['scales', 'new', 'white', 'vapor', 'grams', 'lighter', 'weight', 'head'],
#  ['vapor',
#   '``',
#   'smooth',
#   '``',
#   'contact',
#   'ball',
#   'going',
#   'back',
#   'xt',
#   'feels',
#   'really',
#   'stiff',
#   'easier',
#   'generate',
#   'pace'],
#  ['picked',
#   'new',
#   'vapor',
#   'put',
#   'scale',
#   'stock',
#   'configuration.barrage',
#   'pro',
#   'strings',
#   'pu',
#   'gripcame',
#   'g'],
#  ['perhaps',
#   'added',
#   'bit',
#   'material',
#   'strengthen',
#   'newer',
#   'mold',
#   'deal',
#   'past',
#   'breakage',
#   'issues',
#   '..',
#   'got',
#   'outlier'],
#  ['yes', 'made', 'graphite'],
#  ['almost',
#   'squash',
#   'rackets',
#   'made',
#   'graphite',
#   'except',
#   'heavy',
#   'beginner',
#   'rackets',
#   'use',
#   'branding',
#   'rackets',
#   'also',
#   'made',
#   'graphite'],
#  ['harrow',
#   'vapor',
#   'high-end',
#   'racket',
#   'love',
#   'since',
#   'first',
#   'racket',
#   'recommend',
#   'find',
#   'something',
#   'less',
#   'expensive',
#   'start',
#   'something',
#   'around',
#   'us'],
#  ['hi', 'pierre', 'thanks', 'great', 'squash', 'website'],
#  ['original',
#   'vapor',
#   'also',
#   'came',
#   'pink',
#   'lime',
#   'green',
#   'version',
#   'called',
#   'prep',
#   'paint',
#   'scheme',
#   'ultralite',
#   'retro',
#   'may',
#   'homage',
#   'towards'],
#  ['funny',
#   'think',
#   'retro',
#   'hey',
#   'guess',
#   'terms',
#   'rackets',
#   "'s",
#   'long',
#   'time'],
#  ['links',
#   'found',
#   'trying',
#   'learn',
#   'prep',
#   'recently',
#   'bought',
#   'gently',
#   'used',
#   'version',
#   'ebay',
#   'less',
#   'costs',
#   'rackets',
#   'restrung'],
#  ['right',
#   'call',
#   'vapor',
#   '``',
#   'extremely',
#   'playable',
#   '``',
#   'last',
#   'paragraph',
#   'article',
#   'harrows',
#   'mark',
#   'hayden'],
#  ['know',
#   'cosmetics',
#   'changed',
#   'frame',
#   'balance',
#   'weight',
#   'head-size',
#   'string',
#   'pattern',
#   'remained',
#   'primarily',
#   'otherwise'],
#  ["'d",
#   'get',
#   'another',
#   'one',
#   'probably',
#   'less',
#   'dollars',
#   'time',
#   'also',
#   'probably',
#   'pink',
#   'either'],
#  ['thanks', 'dan', 'interesting', 'article', 'harrow', 'founder'],
#  ["'ve",
#   'played',
#   'red',
#   'black',
#   'vapor',
#   "n't",
#   'know',
#   'whether',
#   'models',
#   'changed',
#   'much',
#   'years'],
#  ['understand', 'changing', 'paint', 'job', 'subtle', 'effect'],
#  ['hey', 'difference', 'new', 'misfit', 'previous', 'red/black', 'one'],
#  ['also',
#   'say',
#   'difference',
#   'red/',
#   'black',
#   'one',
#   'older',
#   'model',
#   'green',
#   'top',
#   'head',
#   'asked',
#   'harrow',
#   'email',
#   'years',
#   'ago'],
#  ['ive', 'playing', 'misfit', 'one', 'skull', 'year'],
#  ['apparently', 'started', 'custom', 'paint', 'job', 'squash', 'club'],
#  ['harrow', 'extras', 'quickly', 'sold', 'shipments', 'ordered'],
#  ["'m",
#   'guessing',
#   'one',
#   'club',
#   'bought',
#   'popular',
#   'harrow',
#   'decided',
#   'make',
#   'standard'],
#  ['black/blue', 'misfit', 'black/red', 'play', 'interchangeably'],
#  ['told',
#   'agent',
#   'uk',
#   'red/black',
#   'vapor',
#   'improved',
#   'balance',
#   'weight',
#   'compared',
#   'lime/black',
#   'model'],
#  ['thanks', 'clarifying', 'situation', 'misfit'],
#  ['seems',
#   'premium',
#   'racket',
#   'red',
#   'black',
#   'vapor',
#   'wanted',
#   'make',
#   'sure'],
#  ['using', 'harrow', 'vapor', 'since', 'dread', 'model'],
#  ['noticed',
#   'move',
#   'gloss',
#   'paint',
#   'job',
#   'mat',
#   'finish',
#   'racket',
#   'remaining'],
#  ['one', 'complaint', 'rather', 'fragile'],
#  ['otherwise', 'absolutely', 'love'],
#  ['racket',
#   'cam',
#   'close',
#   'dunlop',
#   'elite',
#   'let',
#   'introduced',
#   'lime',
#   'green',
#   'version',
#   'one',
#   'bronze',
#   'version',
#   'different',
#   'racket'],
#  ['sold', 'head', 'rackets', "'m", '``', 'heading', '``', 'harrow', 'rackets'],
#  ['got',
#   'impressed',
#   'harrow',
#   'spark',
#   'kasey',
#   'brown',
#   'first',
#   'choice',
#   'choose',
#   'vapor',
#   'second',
#   'racket',
#   'similar',
#   'spark'],
#  ['head',
#   'squash',
#   'rackets',
#   'roundup',
#   'head',
#   'squash',
#   'rackets',
#   'quite',
#   'popular',
#   'used',
#   'many',
#   'pros',
#   'including',
#   'laura',
#   'massaro',
#   'joelle',
#   'king',
#   'nour',
#   'el',
#   'tayeb',
#   'jenny',
#   'duncalf',
#   'karim',
#   '``',
#   'dark',
#   'prince',
#   '``',
#   'darwish'],
#  ["'ve", 'updated', 'page', 'models', 'came', 'recently'],
#  ['head', 'cyano', 'head', 'graphene', 'xt', 'cyano', 'new'],
#  ['teardrop-style', 'racket'],
#  ['jenny',
#   'duncalf',
#   'nour',
#   'el',
#   'tayeb',
#   'line',
#   'hansen',
#   'used',
#   'prior',
#   'version',
#   'head',
#   'graphene',
#   'cyano'],
#  ['looks',
#   'like',
#   'head',
#   'taken',
#   'grams',
#   'head',
#   'season',
#   'keep',
#   'eye',
#   'whether',
#   'remains',
#   'popular'],
#  ['hey',
#   'pierre',
#   'wondering',
#   'could',
#   'review',
#   'head',
#   'graphene',
#   'xt',
#   'cyano'],
#  ['found', 'amazon', 'sportchek.ca', 'could', 'find', 'single', 'review'],
#  ['anyone', 'else', 'knows', 'anything', 'racket', 'could', 'let', 'know'],
#  ['currently',
#   'use',
#   'racquet',
#   'got',
#   'sport',
#   'chek',
#   'compared',
#   'last',
#   'racquet',
#   'prince',
#   'airstick',
#   'lot',
#   'durable',
#   'number',
#   'wall',
#   'hits'],
#  ['would', 'imagine', 'similar', 'cyano', 'pierre', 'review'],
#  ['like',
#   'factory',
#   'strings',
#   'tension',
#   "n't",
#   'getting',
#   'much',
#   'power',
#   'cut',
#   'ball'],
#  ['changing',
#   'ashaway',
#   'supernick',
#   'xl',
#   'micro',
#   'world',
#   'difference',
#   'respects'],
#  ["'m", 'thinking', 'trying', 'new', 'racquet'],
#  ['either', 'suprem', 'carboflex', 'xamsa', 'pxt-'],
#  ['anyone', 'could', 'offer', 'advice', 'would', 'greatly', 'appreciated'],
#  ['noticed',
#   'head',
#   'ig',
#   'extreme',
#   'squash',
#   'racket',
#   'recently',
#   'pdh',
#   'sports',
#   'website',
#   'reduced'],
#  ['also', 'checked', 'head', 'website', 'cant', 'see', 'released', 'year'],
#  ['hi', 'decide', 'racket', 'buy'],
#  ['would', 'like', 'buy', 'head', 'one', 'saw', 'cyano-s', 'xenon-s'],
#  ['balance', 'power', 'control'],
#  ['play', 'week', 'less'],
#  ['expert', 'would', 'say', 'bit', 'intermidiate'],
#  ['would',
#   'much',
#   'apreciate',
#   'opinion',
#   'andre',
#   "'ve",
#   'tried',
#   'cyano',
#   'xenon',
#   'think',
#   'good',
#   'balance',
#   'power',
#   'control'],
#  ['like',
#   'head-heavy',
#   'feeling',
#   'would',
#   'go',
#   'xenon',
#   'like',
#   'racket',
#   'feel',
#   'lighter',
#   'maneuverable',
#   'would',
#   'suggest',
#   'cyano'],
#  ['light', 'beginners', 'snare', 'broke', 'weeks', 't.a.w'],
#  [],
#  ['ashaway', 'ultra', 'nick', 'green', 'kg'],
#  ['marvellous', 'trampoline', 'smashing', 'drives'],
#  ['words', "n't", 'work', 'km/ph', 'like', 'dunlop', 'pounds'],
#  ['questions',
#   'send',
#   'm.',
#   'mizuno',
#   'squash',
#   'shoes',
#   'mizuno',
#   "n't",
#   'specifically',
#   'make',
#   'squash',
#   'shoes',
#   'make',
#   'non-marking',
#   'court',
#   'shoes',
#   'sports',
#   'volleyball',
#   'handball',
#   'appropriate',
#   'squash',
#   'courts'],
#  ['mizuno', 'sometimes', 'labeled', 'unisex', 'i.e'],
#  ['either', 'men', 'women', 'tried', 'separate', 'mens', 'women', 'shoes'],
#  ['sure', 'differences', 'shoes', 'trying', 'collect', 'one', 'place'],
#  ['many', 'pros', 'wear', 'mizuno'],
#  ['ones',
#   'know',
#   'daryl',
#   'selby',
#   'low',
#   'wee',
#   'wern',
#   'misaki',
#   'kobayashi'],
#  ['mizuno',
#   'shoes',
#   'comparable',
#   'asics',
#   'terms',
#   'origin',
#   'japan',
#   'sheer',
#   'number',
#   'models',
#   'striking',
#   'colours',
#   'volleyball',
#   'shoes',
#   'high',
#   'quality'],
#  ['hello', 'beginner'],
#  ["'m", 'kg', 'slim', 'feet', 'shoes', 'recommend'],
#  ['explain', 'benefits', 'make', 'eg'],
#  ['stealth', 'etc'],
#  ["'ll",
#   'using',
#   'badminton',
#   'squash',
#   'think',
#   'lateral',
#   'support',
#   'considered',
#   'comments',
#   'first',
#   'let',
#   'start',
#   'saying',
#   'thanks',
#   'great',
#   'site',
#   '..'],
#  ['adidas',
#   'stabil',
#   'fan',
#   'years',
#   'probably',
#   'owned',
#   'atleast',
#   'one',
#   'every',
#   'generation',
#   'stabil',
#   'exception',
#   'generation',
#   'one',
#   'boost'],
#  ['first',
#   'impression',
#   'newer',
#   'stabil',
#   'boost',
#   'stabil',
#   'boost',
#   'ii',
#   'solid'],
#  ['shoes',
#   'weeks',
#   'played',
#   'times',
#   'however',
#   'noteable',
#   'differences',
#   'construction',
#   'quite',
#   'pronounced'],
#  ['first',
#   'touge',
#   'gap',
#   'quite',
#   'large',
#   'much',
#   'larger',
#   'older',
#   'stabil',
#   'models',
#   'assume',
#   'adidas',
#   'shoes',
#   'tend',
#   'tight',
#   'fitting',
#   'great',
#   'wide',
#   'footed',
#   'players'],
#  ['perhaps',
#   'adidas',
#   'thought',
#   'shortening',
#   'shoe',
#   'sidewalls',
#   'increasing',
#   'size',
#   'tounge',
#   'gap',
#   'would',
#   'accomidate',
#   'larger',
#   'foot'],
#  ['done',
#   'increase',
#   'span',
#   'lace',
#   'across',
#   'top',
#   'shoe',
#   'resulting',
#   'lace',
#   'less',
#   'shoe',
#   'coming',
#   'across',
#   'tounge'],
#  ['biggest', 'problem', 'shoe', 'regarding', 'laceeyeletts', 'rippling'],
#  ['really',
#   'pull',
#   'laces',
#   'get',
#   'shoe',
#   'snug',
#   'allot',
#   'pressure',
#   'lace',
#   'play',
#   'absorbed',
#   'well',
#   'shoe',
#   'likely',
#   'cause',
#   'eyelett',
#   'damage',
#   'cited'],
#  ['top',
#   'vs',
#   'prior',
#   'generation',
#   'stabil',
#   'shoe',
#   'wall',
#   'construction',
#   'looks',
#   'feels',
#   'bit',
#   'thin',
#   'specifically',
#   'around',
#   'lace',
#   'eyelets',
#   'attempted',
#   'reinforce',
#   'think',
#   'rubber',
#   'peice',
#   'looks',
#   'like',
#   'fashion',
#   'vs',
#   'function'],
#  ['adidas', 'done', 'great', 'job', 'reinforcing', 'shoe', 'outside'],
#  ['heel',
#   'support',
#   'amazing',
#   'side',
#   'wall',
#   'good',
#   '..',
#   'toe',
#   'box',
#   'quite',
#   'snug',
#   'yet',
#   'still',
#   'comfortable'],
#  ['redesigned',
#   'toe',
#   'box',
#   'vs',
#   'old',
#   'stabils',
#   'gen',
#   'boosts',
#   'much',
#   'better',
#   'seems',
#   'eliminate',
#   'wrinkles',
#   'occurred',
#   'across',
#   'top',
#   'toe',
#   'box',
#   'models'],
#  ['new',
#   'sole',
#   'grips',
#   'well',
#   'shoe',
#   'weight',
#   'seems',
#   'inline',
#   'bit',
#   'lighter',
#   'stabil',
#   'models'],
#  ["'m", 'really'],
#  ['shoe', 'feels', 'comfortable', 'supportive', 'responds', 'well', 'court'],
#  ['felt', 'little', 'bit', 'spongy'],
#  ['furthermore', 'grip', 'asics', 'better'],
#  ['worst',
#   'part',
#   'holes',
#   'laces',
#   'tore',
#   'weeks',
#   'http',
#   '**',
#   'toolong',
#   'hope',
#   'working'],
#  ['returned', 'try', 'salming'],
#  ['couple', 'guys', 'club', 'shoes'],
#  ['seem', 'enjoy', 'told', 'fit', 'little', 'tighter', 'around', 'foot'],
#  ['compared', 'infamous', 'adipower', 'stabil', 'seem', 'content'],
#  ["n't",
#   'take',
#   'word',
#   'comments',
#   'hi',
#   'pierre',
#   'using',
#   'progressive',
#   'last',
#   'years',
#   'love',
#   'shoe'],
#  ['seem', 'discontinued', 'know', 'bringing', 'replacement'],
#  ['tried',
#   'new',
#   'asics',
#   'upcourt',
#   'gel-rocket',
#   'lot',
#   'less',
#   'cushioning',
#   "n't",
#   'feel',
#   'anywhere',
#   'near',
#   'good'],
#  ['getting', 'desperate', 'progressives', 'last', 'legs'],
#  ['kind',
#   'regards',
#   'paul',
#   'hi',
#   'paul',
#   "n't",
#   'heard',
#   'new',
#   'version',
#   'progressive'],
#  ['shoes', 'asics', 'lineup', '``', 'i.g.s', '``'],
#  ['technology',
#   'gel',
#   'blade',
#   'gel',
#   'blast',
#   'cyber',
#   'sensei',
#   'volley',
#   'elite'],
#  ["n't",
#   'tried',
#   'trying',
#   'give',
#   'thread',
#   'follow',
#   'terms',
#   'shoes',
#   'may',
#   'similar',
#   'construction'],
#  ['hope', 'helps', 'little'],
#  ['hi',
#   'pierre',
#   'thanks',
#   'great',
#   'info',
#   'trial',
#   'error',
#   'shoes',
#   'expensive',
#   'mistakes',
#   'choose',
#   'pair',
#   'salmings',
#   'let',
#   'know',
#   'get',
#   'brand',
#   'change',
#   'kind',
#   'regards',
#   'paul',
#   'looking',
#   'new',
#   'shoe',
#   'accommodate',
#   'inserts',
#   'tried',
#   'lots',
#   'brands',
#   'looking',
#   'asics'],
#  ['progressive', 'elite', 'volley'],
#  ['definitely', 'elite', 'volley', 'lateral', 'movement'],
#  ['asics',
#   'comfy',
#   'good',
#   'support',
#   'across',
#   'typical',
#   'issue',
#   'may',
#   'throw',
#   'stepping',
#   'court',
#   'feel',
#   'heel',
#   'going',
#   'come'],
#  ['distracting',
#   'new',
#   'asics',
#   'users',
#   'forget',
#   'quickly',
#   "n't",
#   'hinder',
#   'movement',
#   'adidas',
#   'squash',
#   'shoes',
#   'adidas',
#   'squash',
#   'shoes',
#   'quite',
#   'popular',
#   'amongst',
#   'professionals',
#   'well',
#   'club',
#   'players'],
#  ['adidas', 'shoes', 'appropriate', 'indoor', 'courts'],
#  ['adidas', 'actually', 'make', 'squash-specific', 'shoe'],
#  ['make', 'handball', 'volleyball', 'shoes', 'appropriate', 'squash', 'court'],
#  ['adidas', 'team', 'spezial', 'adidas', 'team', 'spezial', 'new', 'model'],
#  ['marketed',
#   'handball',
#   'shoe',
#   'like',
#   'stabil',
#   'court',
#   'stabil',
#   'essence'],
#  ["n't",
#   'seen',
#   'squash',
#   'players',
#   'using',
#   'yet',
#   'looks',
#   'similar',
#   'stabil',
#   'models',
#   'several',
#   'years',
#   'ago',
#   'wonder',
#   'itll',
#   'catch'],
#  ['price'],
#  ['adidas',
#   'counterblast',
#   'adidas',
#   'counterblast',
#   'non-marking',
#   'court',
#   'shoes',
#   'indoor',
#   'market',
#   'like',
#   'adipower',
#   'stabil',
#   'court',
#   'stabil',
#   'essence',
#   'except',
#   'counterblast',
#   'generally',
#   'lighter',
#   'less',
#   'padding'],
#  ['wear', 'squash', 'goggles'],
#  ['wear', 'squash', 'goggles', 'every', 'time', 'play', 'practice', 'squash'],
#  ['squash',
#   'played',
#   'close',
#   'quarters',
#   "n't",
#   'want',
#   'flying',
#   'ball',
#   'racket',
#   'make',
#   'contact',
#   'eyes',
#   'potentially',
#   'damage',
#   'eyesight'],
#  ['personally', 'know', 'two', 'guys', 'permanent', 'eye', 'damage', 'squash'],
#  ['wear',
#   'goggles',
#   'one',
#   'favorite',
#   'things',
#   'use',
#   'eyes',
#   'look',
#   'stuff'],
#  ['pros',
#   "n't",
#   'wear',
#   'goggles',
#   'think',
#   "'s",
#   'mistake',
#   'even',
#   'pros',
#   'get',
#   'whacked',
#   'face',
#   'occasion'],
#  ['case',
#   'many',
#   'squash',
#   'facilities',
#   'squash',
#   'leagues',
#   'squash',
#   'tournaments',
#   'require',
#   'wear',
#   'protective',
#   'eyewear',
#   'court'],
#  ['best',
#   'squash',
#   'goggles',
#   'get',
#   'sufficient',
#   'eye',
#   'protection',
#   'need',
#   'goggles',
#   'polycarbonate',
#   'lenses'],
#  ['us',
#   'eyewear',
#   'must',
#   'meet',
#   'something',
#   'called',
#   'astm-f',
#   'standard'],
#  ['ok',
#   'wear',
#   'contact',
#   'lenses',
#   'long',
#   'wear',
#   'polycarbonate',
#   'lenses'],
#  ['regular', 'eyeglasses', 'safe', 'enough', 'play', 'squash'],
#  ['wear',
#   'prescription',
#   'lenses',
#   "'ll",
#   'need',
#   'purchase',
#   'prescription',
#   'squash',
#   'glasses'],
#  ['talk', 'optician', 'ordering', 'pair'],
#  ['read',
#   'comments',
#   '``',
#   'two',
#   'guys',
#   'permanent',
#   'eye',
#   'damage',
#   'squash',
#   '..',
#   '``',
#   'something',
#   'really',
#   'worry'],
#  ['regular', 'squash', 'player', 'like', 'active', 'frequent', 'player'],
#  ['sometimes',
#   'know',
#   'maybe',
#   'influence',
#   'professional',
#   'player',
#   'live',
#   'tv',
#   'wear',
#   'eye',
#   'protection',
#   'make',
#   'want'],
#  ['reason', 'pro'],
#  ['next', 'time', 'would', 'purchase', 'one', 'protect'],
#  ['friend',
#   'peter',
#   'philadelphia',
#   'says',
#   'bought',
#   'rec',
#   'specs',
#   'maxx-',
#   'mx-',
#   'liberty',
#   'sports',
#   'framesdirect.com',
#   'years',
#   'ago',
#   'prescription',
#   'lenses',
#   'added',
#   'locally'],
#  ['says', 'really', 'likes'],
#  ['searching',
#   'searching',
#   'reviewing',
#   'bags',
#   'finally',
#   'ordered',
#   'genuine',
#   'racquet',
#   'squash',
#   'bag',
#   'karakal'],
#  ['shoulder', 'style', 'bag', 'used', 'one', 'two', 'straps', 'shoulders'],
#  ['one',
#   'good',
#   'sized',
#   'center',
#   'compartment',
#   'multi-racquet',
#   'compartment',
#   'side',
#   'two',
#   'smaller',
#   'side',
#   'pockets',
#   'soft',
#   'lined',
#   'eyeglass',
#   'pocket',
#   'dedicated',
#   'shoe',
#   'sweaty',
#   'gear',
#   'pocket'],
#  ['plus',
#   'two',
#   'racquet',
#   'shoes',
#   'pockets',
#   'small',
#   'mesh',
#   'vent',
#   'screens',
#   'bag',
#   'lightweight',
#   'yet',
#   'well',
#   'made',
#   'sturdy'],
#  ['love', 'bag', 'pleased', 'final', 'decision'],
#  ['found',
#   'guy',
#   'canada',
#   'live',
#   'stocks',
#   'karakal',
#   'line',
#   'squash',
#   'gear',
#   'shipped',
#   'bag',
#   'reasonable',
#   'shipping',
#   'fear',
#   'live',
#   'vancouver',
#   'area',
#   'gave',
#   'great',
#   'customer',
#   'service'],
#  ['included',
#   'charge',
#   'bag',
#   'three',
#   'replacement',
#   'karakal',
#   'grip',
#   'strips',
#   'bonus',
#   'ordering',
#   'bag',
#   'surfed',
#   'blog',
#   'site',
#   'lots',
#   'fact',
#   'first',
#   'seem',
#   'karakal',
#   'gear',
#   'site'],
#  ['wonder',
#   'feedback',
#   'rest',
#   'sqaush',
#   'gear',
#   'cheers',
#   'tc',
#   'wilson',
#   'backpack',
#   'models',
#   'quite',
#   'spacious'],
#  ['highly', 'recommended'],
#  ['main',
#   'compartment',
#   'spacious',
#   'cube-like',
#   'shape',
#   'makes',
#   'easier',
#   'keep',
#   'packing',
#   'stuff'],
#  ['shoulder',
#   'bags',
#   'even',
#   'backpack',
#   'straps',
#   'long',
#   'slender',
#   'compartments',
#   'non-racquet',
#   'gear',
#   'much',
#   'difficult',
#   'pack'],
#  ['order',
#   'facilitate',
#   'agility',
#   'stability',
#   'still',
#   'maintain',
#   'lightweight',
#   'characteristics',
#   'designed',
#   'midsole',
#   'rear',
#   'end',
#   'higher',
#   'side',
#   'walls',
#   'wraps',
#   'around',
#   'heel',
#   'area'],
#  ['combination',
#   'lms',
#   'plus',
#   'new',
#   'fully',
#   'integrated',
#   'exoskeleton',
#   'construction',
#   'ensures',
#   'excellent',
#   'stability',
#   'perfect',
#   'fit'],
#  ['exoskeleton-',
#   'fully',
#   'integrated',
#   'kobras',
#   'exoskeleton',
#   'design',
#   'totally',
#   'integrated',
#   'lacing',
#   'construction',
#   'order',
#   'facilitate',
#   'best',
#   'possible',
#   'wrap-around',
#   'effect',
#   'foot'],
#  ['keeps',
#   'foot',
#   'right',
#   'position',
#   'lateral',
#   'movements',
#   'high',
#   'performance',
#   'activities'],
#  ['like', 'idea', 'fully', 'integrated', 'exoskeleton', 'mention'],
#  ['teasers',
#   'salming',
#   'back',
#   'shoe',
#   'launching',
#   'summer',
#   'comments',
#   'wear',
#   'balls',
#   'foot',
#   'inside',
#   'kobra',
#   'r'],
#  ['inside', 'underneath', 'balls', 'feet'],
#  ['shoes',
#   'wear',
#   'away',
#   'often',
#   'cause',
#   'holes',
#   'inner',
#   'cant',
#   'make',
#   'mind',
#   'kobras',
#   'wilson',
#   'xaos'],
#  ['regards', 'barry-lee', 'seems', 'case', 'salming', 'shoes'],
#  ['th',
#   'pair',
#   'recently',
#   'looking',
#   'getting',
#   'kobras',
#   'due',
#   'price',
#   'tag',
#   'uk',
#   'put',
#   'managed',
#   'pick',
#   'orange',
#   'vipers',
#   'cheap',
#   'went'],
#  ['theses',
#   'arrived',
#   'month',
#   'ago',
#   'already',
#   'showing',
#   'significant',
#   'wear',
#   'toe',
#   'step',
#   'shoe'],
#  ['however',
#   'previous',
#   'vipers',
#   'green',
#   'went',
#   'similar',
#   'process',
#   'wear',
#   'appears',
#   'quickly',
#   'upper',
#   "n't",
#   'get',
#   'much',
#   'worse'],
#  ['problem',
#   'sole',
#   'step',
#   'wore',
#   'much',
#   'barely',
#   'rubber',
#   'sole',
#   'underneath',
#   'big',
#   'toe',
#   'bought',
#   'jan',
#   'ditch',
#   'august'],
#  ['however', 'must', 'say', 'comfy', 'light', 'flexible'],
#  ['far', 'best', 'shoes', 'ive', 'played', 'durability'],
#  ['salming', 'vipers', 'fatal', 'flaw', 'sole', 'one', 'piece'],
#  ["'m",
#   'free',
#   'replacement',
#   'salming',
#   'sole',
#   'non-lead',
#   'leg',
#   'ripping',
#   'week'],
#  ['granted',
#   'play',
#   'hard',
#   'scramble',
#   'look',
#   'court',
#   'shoes',
#   'sole',
#   'molded',
#   'piece'],
#  ['viper', 'piece', 'overlaid', 'glued'],
#  ['onto', 'bottom'],
#  ['bad', 'design'],
#  ['looking',
#   'forward',
#   'reviews',
#   "'m",
#   'really',
#   'curious',
#   'whether',
#   'salming',
#   'finally',
#   'managed',
#   'make',
#   'durable'],
#  ["'m",
#   'rd',
#   'pair',
#   'race',
#   'r',
#   'within',
#   'months',
#   'think',
#   'pretty',
#   'poor',
#   'price',
#   "'ve",
#   'used',
#   'r',
#   'r',
#   'viper'],
#  ['completely',
#   'agree',
#   'piere',
#   'viper',
#   'really',
#   'low',
#   'profile',
#   'therefore',
#   'little',
#   'padding',
#   'heel',
#   'ankle',
#   'area'],
#  ['r', 'shoes', 'incredibly', 'comfortable'],
#  ["'m", 'currently', 'using', 'r', 'season', "'m", 'pleased'],
#  ['similar',
#   'prince',
#   'shoes',
#   "'m",
#   'interested',
#   'padding',
#   'situation',
#   'kobra'],
#  ['like', 'r', 'r', "'ll", 'getting', 'next', 'season', 'look', 'great'],
#  ['must',
#   'say',
#   'person',
#   "'s",
#   'actively',
#   'looking',
#   'salming',
#   'shoes',
#   'something',
#   'padding/comfort',
#   'continually',
#   'get',
#   'heal',
#   'bruising',
#   'cheap',
#   'mizunos',
#   'find',
#   'lineup',
#   'naming',
#   'number',
#   'system',
#   'quite',
#   'confusing'],
#  ["'ve",
#   'seen',
#   'elsewhere',
#   'net',
#   '``',
#   'race',
#   '``',
#   'models',
#   'considered',
#   'best',
#   'padding/comfort/support',
#   'think',
#   'different',
#   'versions',
#   "'s",
#   'models',
#   'like',
#   'viper',
#   'kobra',
#   'etc',
#   'anyone',
#   'know',
#   'actual',
#   'difference',
#   'comes',
#   'comfort/padding',
#   'would',
#   'buy',
#   'r',
#   'r',
#   'r',
#   'etc'],
#  ['seems',
#   'r',
#   'would',
#   'current',
#   'choice',
#   'latest',
#   'version',
#   'r',
#   'based',
#   'pricing',
#   'r',
#   'bit',
#   'higher',
#   'r',
#   'suggests',
#   'r',
#   'lineup',
#   'bit',
#   'confusing',
#   'agree'],
#  ["n't", 'know', 'kobra', 'adder', 'yet'],
#  ["'ve", 'personally', 'worn', 'r', 'r', 'viper'],
#  ['feel', 'viper', 'least', 'padding', "'d", 'rule'],
#  ['could',
#   "n't",
#   'detect',
#   'padding',
#   'difference',
#   'r',
#   'r',
#   "'ve",
#   'heard',
#   'say',
#   'r',
#   'little',
#   'better'],
#  ['within',
#   'r',
#   'r',
#   'version',
#   'numbers',
#   "n't",
#   'believe',
#   "'s",
#   'big',
#   'difference',
#   'recent',
#   'versions',
#   'i.e'],
#  ["'d", 'get', 'whatevers', 'available', 'looks', 'coolest'],
#  ['lastly', 'r', 'similar', 'r', 'r', 'ankle', 'support', 'want'],
#  ['hope', 'helps'],
#  ['pulled', 'trigger', 'bought', 'one'],
#  ['really',
#   'loved',
#   'dunlop',
#   'aerogel',
#   'elitebut',
#   'hopped',
#   'ring',
#   'w/',
#   'big',
#   'brute',
#   'guy',
#   'two',
#   'days',
#   'agoas',
#   'nice',
#   'guy',
#   "'ll",
#   'meet',
#   'ft',
#   'lbs'],
#  ['every', 'swing', 'sledgehammer', 'shot'],
#  ['nice', 'guy'],
#  ['best',
#   'play',
#   'heyi',
#   'remember',
#   'starting',
#   'trying',
#   'get',
#   'games.anyways',
#   'mighty',
#   'swing',
#   'took',
#   'dunlop'],
#  ['getting', 'precision', 'pro'],
#  ['pierre',
#   'gon',
#   'na',
#   'use',
#   'squashgear',
#   'linked',
#   'able',
#   'get',
#   'new',
#   'one',
#   'ebay',
#   'bucks',
#   'less',
#   'squash',
#   'gear',
#   'offered'],
#  ['try', 'end', 'save', 'anybody', 'info', 'one'],
#  ['looking',
#   'head',
#   'graphene',
#   'xenon',
#   "'m",
#   'starting',
#   'like',
#   'precision',
#   'pro'],
#  ['love',
#   'cosmetics',
#   'seems',
#   'like',
#   'really',
#   'great',
#   'control',
#   'head',
#   'light',
#   'balanced',
#   'head',
#   'price',
#   'range'],
#  ['ca', "n't", 'seem', 'find', 'information', 'reviews'],
#  ['anybody', 'help', 'please'],
#  ['hi', 'guido', 'old', 'favorite', 'dunlop', 'pro', 'gts'],
#  ["'m", 'site', 'keep', 'changing', 'rackets', 'time'],
#  ['current', 'go-to', 'head', 'graphene', 'xenon'],
#  ['generally', 'like', 'traditional', 'head', 'shapes', 'medium', 'weight'],
#  ['head',
#   'really',
#   'good',
#   'choice',
#   'pierre',
#   'one',
#   'last',
#   'year',
#   'miss',
#   'feeling',
#   'racket',
#   'try',
#   'find',
#   'nick'],
#  ['problem', 'grommets', 'made', 'change', 'eye', 'control'],
#  ['similar',
#   'rackets',
#   'despite',
#   'difference',
#   'weight',
#   'little',
#   'bit',
#   'powerful',
#   'eye',
#   'control',
#   'head'],
#  ['mizuno', 'wave', 'bolt'],
#  ['replaces', 'mizuno', 'wave', 'bolt'],
#  ['volleyball', 'court', 'shoe', 'mizuno'],
#  ['heel', 'area', "n't", 'appear', 'much', 'grip'],
#  ['mk',
#   'confirmed',
#   'comment',
#   'prior',
#   'model',
#   'mizuno',
#   'wave',
#   'bolt',
#   'avoid',
#   'heel',
#   "n't",
#   'right',
#   'rubber',
#   'adequate',
#   'read',
#   '...',
#   'wilson',
#   'pro',
#   'staff',
#   'countervail',
#   'spotted',
#   'july',
#   'available',
#   'pre-order'],
#  ['similar',
#   'head',
#   'shape',
#   'wilson',
#   'pro',
#   'staff',
#   'ultra',
#   'light',
#   'based',
#   'wilson',
#   'tour',
#   'blx'],
#  ['priced',
#   'guess',
#   'high-end',
#   'frame',
#   'wilson',
#   'squash',
#   'rackets',
#   'range'],
#  ['price',
#   'read',
#   '...',
#   'dunlop',
#   'hyperfibre+',
#   'revelation',
#   'jnr',
#   'squash',
#   'racket',
#   'juniors'],
#  ["'s", 'part', 'dunlop', 'hyperfibre', 'range', "'s", 'come'],
#  ['cosmetics', 'similar', 'dunlop', 'hyperfibre+', 'revelation'],
#  ["'m",
#   'sure',
#   'length',
#   'racket',
#   'junior',
#   'squash',
#   'rackets',
#   'often',
#   'read',
#   '...',
#   'asics',
#   'gel',
#   'upcourt',
#   'first',
#   'saw',
#   'asics',
#   'gel',
#   'upcourt',
#   'feet',
#   'regular',
#   'playing',
#   'partner',
#   'jeremy'],
#  ['liked', 'much', 'got', 'another', 'color'],
#  ['good-looking', 'said', 'comfortable', 'right', 'box'],
#  ['another', 'guy', 'play', 'peter', 'plays'],
#  ['think',
#   'said',
#   'little',
#   'bit',
#   'small',
#   '``',
#   'price',
#   'right',
#   '``',
#   'right'],
#  ['later', 'able', 'review', 'check', 'video', 'review'],
#  ['comments',
#   'hi',
#   'forgot',
#   'mention',
#   'shoes',
#   'built',
#   'gel',
#   'cushion',
#   'heel',
#   'forefoot',
#   'makes',
#   'landing',
#   'take',
#   'comfortable'],
#  ['shoes', 'gel', 'zones.this', 'cushions', 'foot', 'impact', 'good', 'knees'],
#  ['also',
#   'shoes',
#   'one',
#   'lightest',
#   'available',
#   'helps',
#   'quick',
#   'movement',
#   'court'],
#  ['using', 'year', 'hours', 'giving'],
#  ['weigh', 'kilos'],
#  ['asics',
#   'gel',
#   'blast',
#   'asics',
#   'gel',
#   'blast',
#   'started',
#   'come',
#   'august'],
#  ['successors', 'asics', 'gel', 'blast', 'given', 'nice', 'facelift'],
#  ['story',
#   'far',
#   'asics',
#   'gel',
#   'blast',
#   'prior',
#   'popular',
#   'squash',
#   'players'],
#  ['asics',
#   'came',
#   'gel',
#   'blast',
#   'made',
#   'significant',
#   'changes',
#   'lot',
#   'squash',
#   'players',
#   'sad'],
#  ['many', 'blast', 'fans', 'switched', 'asics', 'gel', 'fastball'],
#  ['long', 'awaited', 'shoe', 'worth', 'waiting', 'loved', 'blast'],
#  ['blast',
#   'new',
#   'surpass',
#   'expectations',
#   'asics',
#   'gone',
#   'back',
#   'traditional',
#   'styling',
#   'previous',
#   'models',
#   'providing',
#   'superior',
#   'durability',
#   'quicker',
#   'cuts',
#   'arouind',
#   'court'],
#  ['sponsored',
#   'links',
#   'product',
#   "'d",
#   'ones',
#   'called',
#   'blue',
#   'jewel',
#   'white',
#   'flash',
#   'coral'],
#  ['listed', 'mens', 'shoe', 'zalando', 'sites', 'womens', 'model'],
#  ['based',
#   'colors',
#   'shoes',
#   'comments',
#   'really',
#   'liked',
#   'shoeswhile',
#   'lasted'],
#  ['sure', 'called', 'gel-blast', 'last', 'weeks', 'seems', 'way'],
#  ['bizarre',
#   'considering',
#   'last',
#   'pair',
#   'gel',
#   'rockets',
#   'lasted',
#   'close',
#   'years'],
#  ["'m",
#   'exactly',
#   'sure',
#   'compound',
#   'used',
#   'rubber',
#   'sole',
#   "'s",
#   'grip',
#   'left',
#   'front',
#   'inside',
#   'portion',
#   'either',
#   'shoe',
#   'left',
#   'shoe',
#   'obvious',
#   'hole',
#   "'s",
#   'longer',
#   'rubber'],
#  ["'m", 'happy', 'got', 'sale', "'d", 'pretty', 'upset', 'paid', 'money'],
#  ['guess',
#   "'re",
#   'going',
#   'backup',
#   'pair',
#   "'ll",
#   'switching',
#   'companies',
#   'best',
#   'asics'],
#  ['point',
#   "'m",
#   'runner',
#   'still',
#   'expect',
#   'pair',
#   'shoes',
#   'retails',
#   'close',
#   'canadian',
#   'tax',
#   'last',
#   'bit',
#   'longer',
#   'months'],
#  ['traditional',
#   'player',
#   'would',
#   'definitely',
#   'last',
#   'longer',
#   'considering',
#   'still',
#   'look',
#   'brand',
#   'new'],
#  ['clearly', 'werent', 'designed', 'player', 'pushes', 'toes', 'laterally'],
#  ['bought', 'red', 'pair', 'october'],
#  ["'re", 'stable', 'like', 'feel', 'even', 'little', 'heavy', 'warm'],
#  ['play',
#   'times',
#   'week',
#   'shoes',
#   'basically',
#   'destroyed',
#   'end',
#   'january'],
#  ['factor',
#   'gone',
#   'three',
#   'weeks',
#   'november',
#   "n't",
#   'play',
#   'week',
#   'christmas',
#   'would',
#   'give',
#   'f',
#   'durability'],
#  ['shoelaces',
#   'broke',
#   'within',
#   'two',
#   'months',
#   'soles',
#   'worn',
#   'rubber',
#   'front',
#   'shoe',
#   'gone',
#   'front',
#   'stitching',
#   'coming',
#   'lose'],
#  ["n't",
#   'play',
#   'extremely',
#   'competitively',
#   'shouldve',
#   'held',
#   'much',
#   'longer'],
#  ['previous', 'mizunos', 'lasted', 'years', 'showed', 'little', 'wear'],
#  ['even',
#   'pair',
#   'adidas',
#   'running',
#   'shoes',
#   'last',
#   'longer',
#   'first',
#   'started',
#   'playing'],
#  ['two',
#   'months',
#   'left',
#   'season',
#   "'m",
#   'ready',
#   'failed',
#   'yellow',
#   'outsole'],
#  ['hexagon', 'rubber', 'stuff', 'vamp', 'held', 'great'],
#  ["'d",
#   'understand',
#   'one',
#   'thing',
#   'wore',
#   'fact',
#   'laces',
#   'insoles',
#   'cant',
#   'last',
#   'half',
#   'life',
#   'shoe',
#   'sign',
#   'poor',
#   'quality',
#   'control',
#   'extreme',
#   'cost',
#   'cutting',
#   'measures'],
#  ['got', 'gel', 'blast', 'back', 'june', 'official', 'release', 'countries'],
#  ['uncle', 'mine', 'trusted', "'d", 'get', 'good', 'shoe'],
#  ['seeing',
#   'pros',
#   'coming',
#   'gelblast',
#   'recent',
#   'tournaments',
#   'reassures',
#   'made',
#   'good',
#   'decision'],
#  ['hi', 'guys', 'bought', 'new', 'blast', 'last', 'week', 'trying', 'morning'],
#  ['reference',
#   "'ve",
#   'previously',
#   'used',
#   'order',
#   'asics',
#   'rocket',
#   'progressive',
#   'fastball',
#   'current'],
#  ['ill', 'report', 'back', 'later', 'quick', 'review'],
#  ['bought', 'pair'],
#  ['seem', 'look', 'little', 'weird'],
#  ['front',
#   'tip',
#   'shoe',
#   'exactly',
#   'example',
#   'middle',
#   'tip',
#   'little',
#   'left',
#   'vise',
#   'versa',
#   'left',
#   'shoe'],
#  ['purpose'],
#  ['squash', 'pro', 'friend', 'mine', 'says', 'squash', 'shoes'],
#  ["'s", 'much', 'info', 'gel', 'blast', 'refer', 'court', 'shoe'],
#  ['anyone', 'able', "'d", 'light', 'share', 'experience', 'playing'],
#  ['technically',
#   'true',
#   'asics',
#   'make',
#   'squash',
#   'shoes',
#   'make',
#   'shoes',
#   'handball',
#   'volleyball',
#   'badminton'],
#  ['according',
#   'asics',
#   'gel',
#   'blast',
#   'range',
#   'supposed',
#   'handball',
#   'shoe',
#   'appropriate',
#   'squash',
#   'courts',
#   'meaning',
#   'non-marking'],
#  ['squash', 'players', 'used', 'e.g'],
#  ['mathieu', 'castagnet', 'worn', 'asics', 'gel', 'blast'],
#  ["n't",
#   'seen',
#   'anybody',
#   'wearing',
#   'gel',
#   'blast',
#   'yet',
#   'pretty',
#   'new',
#   'still',
#   'hopefully',
#   'well',
#   'see',
#   'feedback',
#   'due',
#   'course'],
#  ['old',
#   'school',
#   'prince',
#   'extender',
#   'os',
#   'squash',
#   'rackets',
#   'remember',
#   'prince',
#   'extender'],
#  ['bomb', 'racket', 'late'],
#  ['think',
#   'mightve',
#   'used',
#   'bigboy',
#   "'m",
#   'sure',
#   'another',
#   'model',
#   'used',
#   'roll',
#   'im',
#   'forgetting',
#   'name',
#   'red',
#   'color',
#   'scheme',
#   'update',
#   'jon',
#   'reminds',
#   'called',
#   'featherlite'],
#  ['incidentally',
#   'proud',
#   'owner',
#   'current',
#   'user',
#   'prince',
#   'extender',
#   'os',
#   'thunder'],
#  ['purchased',
#   'circa',
#   'cant',
#   'really',
#   'remember',
#   'honest.patent',
#   'still',
#   'pending',
#   'time',
#   'purchase'],
#  ['case', 'served', 'well', 'years'],
#  ['used', 'againts', 'pros'],
#  ['back', 'day', 'taking', '``', 'grandpas', '``', 'club'],
#  ['prince',
#   'extender',
#   'os',
#   'featherlite',
#   'maroon',
#   'color',
#   'red',
#   'yes',
#   'find',
#   'closet'],
#  ['squash', 'days', 'due', 'nerve', 'problems', 'feet'],
#  ['great', 'piece', 'post', 'ebay'],
#  ["'s",
#   'scratch',
#   'still',
#   'holographic',
#   'sticker',
#   'place',
#   "'ll",
#   'see',
#   'get',
#   'bucks'],
#  ['send', 'pic', 'well'],
#  ['bit',
#   'novice',
#   "'ve",
#   'started',
#   'playing',
#   'dads',
#   'olds',
#   'racket',
#   'extended',
#   'os',
#   'destroyer'],
#  ['question', 'playing', 'older', 'model', 'like', 'hampering', 'game'],
#  ['might', 'see', 'improvement', 'use', 'modern', 'racket'],
#  ['anything',
#   'using',
#   'older',
#   'usually',
#   'heavier',
#   'racquet',
#   'help',
#   'progression'],
#  ['added',
#   'weight',
#   'helps',
#   'guide',
#   'racquet',
#   'swing',
#   'plus',
#   'always',
#   'found',
#   'heavier',
#   'racquet',
#   'helps',
#   'remember',
#   'proper',
#   'pre-swing',
#   'preperation'],
#  ['mention', 'older', 'racquets', 'seem', 'alot', 'less', 'fragile'],
#  ["'m",
#   'beginner',
#   'bought',
#   'prince',
#   'extender',
#   'outrage',
#   'charity',
#   'shop'],
#  ['played', 'tonight', 'beat', 'partner', 'fir', 'first', 'time', 'months'],
#  ["'d", 'say', 'best', 'frenchie', 'thinking', 'featherlite'],
#  ['lightest', 'model', 'made', 'time', 'red', 'color', 'scheme'],
#  ['broke',
#   'mine',
#   'switched',
#   'princes',
#   'new',
#   'power',
#   'ring',
#   'line',
#   'senior',
#   'year'],
#  ['pictures', 'videos', 'shoes', 'come', 'looking', 'red'],
#  ['real', 'life', "'re", 'red', 'dash', 'orange'],
#  ['advised',
#   'fellow',
#   'players',
#   'pinch',
#   'shoes',
#   'double',
#   'traffic',
#   'cones'],
#  ['comments',
#   'hi',
#   'pierre',
#   'using',
#   'salming',
#   'pretty',
#   'happy',
#   'apart',
#   'sole',
#   'peeled',
#   'side',
#   'pairs'],
#  ['close',
#   'great',
#   'asic',
#   'progressive',
#   'used',
#   'wear',
#   'apart',
#   'footbed',
#   'gets',
#   'really',
#   'hot',
#   'ventilation',
#   'holes',
#   'salmings'],
#  ['unfortunately', 'cant', 'get', 'hold', 'seem', 'replaced'],
#  ['thinking', 'kobra', 'expensive', 'wonder', 'compare'],
#  ['video', 'comparing', 'kobra', 'vs', 'race', 'check'],
#  ['slight', 'differences', 'liked'],
#  ['another', 'using', 'weeks', "n't", 'know', 'longevity'],
#  ['terms', 'feel', 'feet', 'adder', 'little', 'closer', 'race'],
#  ["'re", 'exactly', 'cheap', "'re", 'less', 'expensive', 'kobras'],
#  ['might', 'worth', 'look'],
#  ['thanks', 'thanks', 'pierre', 'watched', 'videos', 'great', 'information'],
#  ['slightly',
#   'worried',
#   'silly',
#   'string',
#   'loop',
#   'design',
#   'kobra',
#   'may',
#   'go',
#   'adders',
#   'time',
#   'see',
#   'get'],
#  ['many', 'thanks', 'great', 'site'],
#  ['hi',
#   'pierre',
#   'quick',
#   'uodate',
#   'ended',
#   'buying',
#   'salming',
#   'r',
#   'mids',
#   'feel',
#   'super',
#   'similar',
#   'r',
#   'cant',
#   'even',
#   'feel',
#   'difference'],
#  ['really',
#   'pleased',
#   'bought',
#   'spare',
#   'pair',
#   'well.the',
#   'extra',
#   'height',
#   'minimal',
#   'playing'],
#  ["n't",
#   'want',
#   'take',
#   'chance',
#   'crazy',
#   'expensive',
#   'race',
#   'x',
#   'released'],
#  ['thanks', 'tried', 'size', 'salming', 'r', 'heel', 'pain'],
#  ["'m",
#   'guessing',
#   'must',
#   'friction',
#   'tried',
#   'another',
#   'pair',
#   'recent',
#   'r',
#   'size',
#   'fit',
#   'perfectly',
#   'heel',
#   'pain'],
#  ['seem', 'run', 'half', 'size', 'big'],
#  ['love', 'grip', 'floor'],
#  ['bought', 'womens', 'r', 'almost', 'r'],
#  ['found', 'smaller', 'squash', 'shoes', 'others'],
#  ['shoes',
#   'comfortable',
#   'light',
#   'wore',
#   'month',
#   'train',
#   'times',
#   'week',
#   'two',
#   'tournaments'],
#  ['using',
#   'also',
#   'adidas',
#   'adipower',
#   'stabil',
#   'also',
#   'womens',
#   'model',
#   'lasted',
#   'almost',
#   'year'],
#  ['hope', 'salming', 'could', 'develop', 'sustainable', 'shoes'],
#  ['seen',
#   'many',
#   'comments',
#   'regarding',
#   'size',
#   'shoes',
#   'want',
#   'buy',
#   'online',
#   'cant',
#   'find',
#   'country',
#   'need',
#   'adidas',
#   'adipower',
#   'stabil',
#   'size',
#   'us',
#   'anyone',
#   'tell',
#   'size',
#   'salming',
#   'similar',
#   'adidas',
#   'buy',
#   'different',
#   'size',
#   'otherwise',
#   "'ll",
#   'buy',
#   'adidas'],
#  ['thank',
#   'wore',
#   'adidas',
#   'adipower',
#   'stabil',
#   'size',
#   'us',
#   'wear',
#   'salming',
#   'race',
#   'r',
#   'also'],
#  ['happy', 'size'],
#  ['race', 'r', 'feels', 'little', 'wider', 'adipower'],
#  ['think',
#   'probably',
#   'could',
#   'equally',
#   'happy',
#   'size',
#   'salmings',
#   'never',
#   'tried',
#   'onlike',
#   'ordered',
#   'another',
#   'country'],
#  ['hope', 'helps'],
#  ['month',
#   'playsing',
#   'squash',
#   'salming',
#   'grip',
#   'anymore',
#   'salming',
#   'r',
#   'shoe',
#   'durable',
#   "'ve",
#   'played',
#   'times',
#   'week',
#   'h',
#   'could',
#   'see',
#   'picture',
#   'shoes',
#   'ascics',
#   'gel',
#   'blade',
#   'wonderful',
#   'great',
#   'shoe',
#   'wonderful',
#   'month',
#   'upper',
#   'shoe',
#   'components',
#   'lot',
#   'holes',
#   "'ve",
#   'bought',
#   'asics',
#   'gel',
#   'blade',
#   'eur',
#   'germany',
#   'salming',
#   'r'],
#  ['sold',
#   'shop',
#   'shoe',
#   'similar',
#   'durable',
#   'gel',
#   'blade',
#   'would',
#   'like',
#   'post',
#   'relevant',
#   'infos'],
#  ['probably', 'order', 'online', 'another', 'pair', 'salming', 'r', 'see'],
#  ['bought', 'r', 'eur', 'germany', 'six', 'month', 'ago', 'pleased', 'shoe'],
#  ['shoe',
#   'comfortable',
#   'light',
#   'durability',
#   'unbelievable',
#   'play',
#   'times',
#   'week',
#   'h',
#   'week',
#   'old',
#   'asics',
#   'gel',
#   'blade',
#   'lasts',
#   'month',
#   'procedure',
#   'asics',
#   'gel',
#   'rocket'],
#  ['based',
#   'reviews',
#   'ive',
#   'ordered',
#   'half',
#   'size',
#   'smaller',
#   'us',
#   'size',
#   'r',
#   'blue',
#   'usually'],
#  ['surprise', 'smaller'],
#  ['went',
#   'store',
#   'near',
#   'got',
#   'viper',
#   'size',
#   'yes',
#   "'s",
#   'small',
#   'gap',
#   'fingers',
#   'forefront',
#   'shoes',
#   'perfect',
#   'sides'],
#  ['maybe',
#   'due',
#   'slightly',
#   'wider',
#   'feet',
#   'people',
#   'wear',
#   'adidas',
#   '``',
#   'known',
#   'shoes',
#   'narrow',
#   'feet',
#   '``'],
#  ['anyway',
#   'since',
#   'history',
#   'ankle',
#   'knees',
#   'injuries',
#   'store',
#   "'ve",
#   'started',
#   'trying',
#   'different',
#   'models',
#   'r',
#   'cushioning',
#   'kind',
#   'shoe',
#   'perfect',
#   'history',
#   'higher',
#   'average',
#   'squash',
#   'shoes'],
#  ['viper', 'foot', 'bun', 'intended', 'low', 'would', 'surprise', 'low'],
#  ['widest', 'gum', 'rubber', 'sole', 'plus', 'terms', 'stability', 'court'],
#  [],
#  ['ive',
#   'good',
#   'nowover',
#   'months',
#   'play',
#   'nights',
#   'week',
#   "'m",
#   'slouchi',
#   'abuse',
#   'heck',
#   'wear',
#   'starbucks',
#   'ordered',
#   'half-size',
#   'smaller',
#   'perfect'],
#  [],
#  ['months', 'later', 'puppies', 'holding', 'form', 'feel', 'wonderful'],
#  ['fact',
#   'ive',
#   'ordered',
#   'another',
#   'pair',
#   'ready',
#   'use',
#   'back',
#   'forth',
#   'save',
#   'wear',
#   'tear'],
#  ['comfortable',
#   'squash',
#   'shoe',
#   'ive',
#   'ever',
#   'worn',
#   'wont',
#   'going',
#   'back',
#   'asics',
#   'adidas'],
#  ["'re",
#   'freakin',
#   'cool',
#   'lookingthe',
#   'words',
#   'squash',
#   'shoes',
#   'stylish',
#   'synonymous',
#   "'s",
#   'added',
#   'bonus'],
#  ['thanks',
#   'review',
#   'opinion',
#   'r',
#   'durable',
#   'month',
#   'shoe',
#   'got',
#   'shredded',
#   'side'],
#  ['last', 'week', 'got', 'salming', 'viper'],
#  ['hopefully', 'last', 'longer', 'otherwise', 'get', 'back', 'asics'],
#  ['say',
#   'without',
#   'doubt',
#   'feel',
# ...
#  ['vision', 'great'],
#  ['suggest', 'placing', 'lens', 'portion', 'tube', 'sock', 'scratches'],
#  ['usually',
#   'wear',
#   'bandana',
#   'sweat',
#   'band',
#   'extends',
#   'life',
#   'imask',
#   'sweatband'],
#  ["'m", 'second', 'imask'],
#  ['first',
#   'one',
#   'reached',
#   'point',
#   'many',
#   'nicks',
#   'aged',
#   'six',
#   'years',
#   'bent'],
#  ['new',
#   'versions',
#   'headband',
#   'improvement',
#   'old',
#   'one',
#   'sponge',
#   'like',
#   'thing',
#   'got',
#   'three'],
#  ['one',
#   'benefit',
#   'video',
#   'mention',
#   'get',
#   'hit',
#   'racquet',
#   'elbow',
#   'imask',
#   'takes',
#   'blow',
#   'flies'],
#  ["'ve", 'encounters', 'walked', 'away', 'unbruised'],
#  ['learn', 'push', 'imask', 'grab', 'water', 'bottle'],
#  ['also',
#   'space',
#   'plastic',
#   'bridge',
#   'curved',
#   'lens',
#   'smaller',
#   'squash',
#   'ball'],
#  ['know',
#   'since',
#   'lost',
#   'ball',
#   'lights',
#   'hit',
#   'exact',
#   'point',
#   'got',
#   'stuck',
#   'bridge',
#   'lens'],
#  ['point', 'could', 'stop', 'laughing'],
#  ['happened',
#   'look',
#   'squash',
#   'doubles',
#   'clips',
#   'earlier',
#   'today',
#   'nick',
#   'matthew',
#   'adrian',
#   'grant',
#   'seemed',
#   'using',
#   'commonwealth',
#   'games',
#   'least',
#   'something',
#   'similar',
#   'https',
#   '//www.youtube.com/watch'],
#  ['v=ur', 'xa', 'love', 'i-mask'],
#  ['wear',
#   'glasses',
#   "'ve",
#   'found',
#   'i-mask',
#   'far',
#   'superior',
#   'rx',
#   'goggles'],
#  ['also',
#   "n't",
#   'fog',
#   'even',
#   'though',
#   'looks',
#   'awkward',
#   'really',
#   'comfortable',
#   'light',
#   'point',
#   "'m",
#   'aware',
#   "'m",
#   'wearing'],
#  ['im', 'surprised', "n't", 'popular', 'glasses', 'non-glasses', 'wearers'],
#  ['prince',
#   'pro',
#   'prince',
#   'team',
#   'squash',
#   'rackets',
#   "'s",
#   'sneak',
#   'peek',
#   'prince',
#   'pro',
#   'prince',
#   'team',
#   'range',
#   'prince',
#   'squash',
#   'rackets-',
#   'coming'],
#  ['word',
#   'street',
#   'frame',
#   'shapes',
#   'last',
#   'years',
#   'models',
#   'prince',
#   'moved',
#   'production',
#   'new',
#   'factory'],
#  ['prince', 'range', 'split', '``', 'pro', '``', '``', 'team', '``', 'models'],
#  ['guess',
#   'pro',
#   'models',
#   'high-end',
#   'rackets',
#   'team',
#   'models',
#   'mid-range',
#   'rackets'],
#  ['terms',
#   'design',
#   'pro',
#   'models',
#   'color',
#   'outside',
#   'part',
#   'frame',
#   'black',
#   'inside',
#   'frame'],
#  ['team', 'models', 'black', 'outside', 'frame', 'color', 'inside'],
#  ['prince',
#   'pro',
#   'models',
#   'models',
#   'appear',
#   'include',
#   'newer',
#   'textreme',
#   'material'],
#  ['believe',
#   'names',
#   'comments',
#   'read',
#   'specs',
#   'new',
#   'racquets',
#   'local',
#   'shop',
#   'got',
#   'advance',
#   'brochure',
#   'weeks'],
#  ['pro',
#   'phantom',
#   '``',
#   'replacement',
#   '``',
#   'pro',
#   'rebel',
#   'previously',
#   'exo',
#   'rebel'],
#  [],
#  ['noted',
#   '``',
#   'pro',
#   '``',
#   'models',
#   'largely',
#   '``',
#   'team',
#   '``',
#   'models',
#   'except',
#   'addition',
#   'lighter',
#   'stiffer',
#   'higher',
#   'quality',
#   'textreme',
#   'carbon'],
#  ['makes', 'much', 'lighter', 'also', 'considerably', 'expensive'],
#  [],
#  ['textreme',
#   'wraps',
#   'around',
#   'whole',
#   'top',
#   'part',
#   'frame',
#   'around',
#   'oclock',
#   'right',
#   'top',
#   'round',
#   'around',
#   'oclock'],
#  ['previous',
#   'textreme',
#   'racquets',
#   'small',
#   'patch',
#   'oclock',
#   'oclock',
#   'points'],
#  [],
#  ['new',
#   'pro',
#   'beast',
#   'racquet',
#   'range',
#   'use',
#   'powerbite',
#   'string',
#   'pattern',
#   'slightly',
#   'heavier',
#   'predecessor',
#   'g',
#   'unstrung',
#   'previous',
#   'ones',
#   'g',
#   'know',
#   "'ve",
#   'four'],
#  [],
#  [],
#  ['spec-wise',
#   "n't",
#   'think',
#   '``',
#   'new',
#   '``',
#   'racquets',
#   'changed',
#   'great',
#   'deal',
#   'earlier',
#   'entire',
#   'range'],
#  ['might',
#   'uk',
#   'weaker',
#   'comparison',
#   'g/',
#   'last',
#   'year',
#   'could',
#   'also',
#   'due',
#   'extra',
#   'textreme',
#   'used',
#   'construction'],
#  ['looks', 'like', 'pro', 'rackets', 'feature', 'textreme', 'team', 'rackets'],
#  ['four', 'range', 'spec', 'terms', 'weight', 'power', 'string', 'pattern'],
#  ['looks',
#   'like',
#   'phantom',
#   'take',
#   '**',
#   'toolong',
#   'head',
#   'shape',
#   'whereas',
#   'three',
#   'airsick/warrior/beast',
#   'look',
#   'like',
#   'airsick',
#   'headship',
#   'probably',
#   'mimic',
#   'previous',
#   'models',
#   'weights',
#   'ranges',
#   'always',
#   'followed'],
#  ['beast', 'definitely', 'string', 'pattern', 'whereas', 'airsick', 'warrior'],
#  ['nice',
#   'see',
#   'simplify',
#   'range',
#   'last',
#   'shame',
#   'theyve',
#   'gone',
#   'putting',
#   'speed/',
#   'ports',
#   'headshape',
#   'style',
#   'racket',
#   'always',
#   'wondered',
#   'would',
#   'play',
#   'favourites',
#   'time',
#   'speed',
#   'port',
#   'black',
#   'strange',
#   'see',
#   'team',
#   'rebel',
#   'among'],
#  ['think',
#   'shame',
#   'way',
#   'little',
#   'information',
#   'find',
#   'prince',
#   'squash',
#   'gear',
#   'nowadays',
#   'cant',
#   'even',
#   'find',
#   'official',
#   'website',
#   'anymore',
#   '..',
#   'asics',
#   'gel',
#   'fireblast',
#   'asics',
#   'gel',
#   'fireblast',
#   'around',
#   'couple',
#   'years'],
#  ['world',
#   'mohamed',
#   'el',
#   'shorbagy',
#   'uses',
#   'shoes',
#   'top',
#   'french',
#   'player',
#   'gregoire',
#   'marche'],
#  ['readers', 'felt', 'shoes', 'gouged', 'ankles', 'though'],
#  ['read', 'details'],
#  ['three',
#   'members',
#   'club',
#   'including',
#   'bought',
#   'shoes',
#   'two',
#   'weeks',
#   'ago'],
#  ['us',
#   'regularly',
#   'finish',
#   'games',
#   'blooded',
#   'socks',
#   'cm',
#   'wounds',
#   'inside',
#   'ankles'],
#  ['skin', 'removed', 'spot'],
#  ['us',
#   'regular',
#   'asics',
#   'wearers',
#   'appears',
#   'new',
#   'brand',
#   'design',
#   'fault'],
#  ['side', 'coin', 'turns', 'mohamed', 'el', 'shorbagy', 'wears'],
#  ['fact', 'qatar', 'classic'],
#  ['comments',
#   'got',
#   'shoe',
#   'like',
#   'month',
#   'ago',
#   'thought',
#   'would',
#   'give',
#   'feedback'],
#  ['little',
#   'heads',
#   'know',
#   'comparing',
#   'asics',
#   'rocket',
#   'pro',
#   'great',
#   'narrow',
#   'feet',
#   'light',
#   'low',
#   'price',
#   'good',
#   'grip',
#   'cushioning/',
#   'con',
#   'weak',
#   'support',
#   'ankle',
#   'hurt',
#   'intense',
#   'sessions',
#   '-adidas',
#   'court',
#   'stabil',
#   'pro',
#   'great',
#   'narrow',
#   'feet',
#   'light',
#   'good',
#   'support/con',
#   'needed',
#   'buy',
#   'insole',
#   'better',
#   'cushioning',
#   '-adidas',
#   'counterblast',
#   'pro',
#   'light',
#   'good',
#   'grip',
#   'cushioning/con',
#   'price',
#   'supportive',
#   'enough',
#   'ankle',
#   '-adidas',
#   'adipower',
#   'stabil',
#   'pro',
#   'great',
#   'wide',
#   'feet',
#   'great',
#   'support',
#   'cushioning/con',
#   'price',
#   'heavy-bulky',
#   '-mizuno',
#   'wave',
#   'stealth',
#   'pro',
#   'great',
#   'wide',
#   'feet',
#   'great',
#   'support',
#   'cushioning',
#   'good',
#   'grip/con',
#   'price',
#   'feels',
#   'high',
#   'ground',
#   'fireblast'],
#  ['narrow', 'feet', 'perfect'],
#  ['someone', 'wide', 'feet', 'might', 'find', 'snug'],
#  ['great',
#   'grip',
#   'great',
#   'cushioning',
#   'best',
#   'thing',
#   'love',
#   '``',
#   'side',
#   'wing',
#   '``',
#   'gives',
#   'best',
#   'stability',
#   'push',
#   'ever',
#   'experienced'],
#  ['pricey',
#   'older',
#   'model',
#   'find',
#   'good',
#   'discounts',
#   'online',
#   'feels',
#   'restrictive',
#   'akward'],
#  ['break', 'period', 'molds', 'feet', 'becomes', 'supper', 'comfortable'],
#  ['low', 'feeling', 'court', 'still', 'great', 'cushioning'],
#  ['final', 'verdict', 'best', 'shoe', 'ever', 'played', 'narrow', 'feet'],
#  ['bit', 'pricey', "n't", 'find', 'discount', 'needs', 'break-in', 'period'],
#  ['asside',
#   'highly',
#   'recommend',
#   'cheers',
#   'zsolt',
#   'great',
#   'distinctive',
#   'way'],
#  ['rockets',
#   'made',
#   'price',
#   'affordability',
#   'lacked',
#   'cushioning',
#   'design'],
#  ['blades', 'little', 'low', 'comfortable', 'maneuverable', 'great', 'grip'],
#  ['best', 'far', 'blasts'],
#  ['due', 'switch', 'shoes'],
#  ['wondering', 'fireblasts', 'next', 'logical', 'progression'],
#  ['first', 'thing', 'strikes', 'price'],
#  ['far', 'opinion', 'costliest', 'squash', 'shoes', 'market'],
#  [],
#  ['pair', 'would', 'recommend', 'asics', 'stable'],
#  ['perhaps',
#   'price',
#   "'ve",
#   'seen',
#   'many',
#   'people',
#   'wear',
#   'east',
#   'coast'],
#  ['yellow-black',
#   'ones',
#   'look',
#   'killer',
#   'seem',
#   'really',
#   'hard',
#   'find',
#   'like',
#   'gregoire',
#   'marche',
#   'wears'],
#  ['advice',
#   'pierre',
#   'reader',
#   'take',
#   'rather',
#   'expensive',
#   'plunge',
#   'pair'],
#  ['must', 'something', 'special', 'priced', 'high'],
#  ['guessing', 'even', 'costlier', 'top-end', 'asics', 'running', 'shoe'],
#  ['hello'],
#  ["'ve", 'asked', 'brian', 'morning', 'shoes', 'cutting', 'ankles'],
#  ['problems'],
#  ['says', 'light', 'manoverable'],
#  ['world'],
#  ['years', 'ago', "'ll", 'take', 'review', 'confidence', 'others'],
#  ['although', 'everyone', 'course', 'different'],
#  ['still', 'think', "'m", 'going', 'buy', 'pair'],
#  ['looking', 'black', 'yellow', 'model'],
#  ['thanks',
#   'sponsored',
#   'links',
#   'product',
#   "'d",
#   'apparently',
#   'racket',
#   'made',
#   'basalt',
#   'fibers'],
#  ["'s", 'right', 'basalt', 'cooled-off', 'lava', 'straight', 'volcano'],
#  ['exactly', 'people', 'going', 'say', 'play', 'racket'],
#  ['spotted',
#   'check',
#   'peter',
#   'barker',
#   'using',
#   'racket',
#   'nick',
#   'matthew',
#   'crazy',
#   'rally',
#   'finals',
#   'case',
#   'swedish',
#   'open'],
#  ['peters', 'moving', 'well'],
#  ['might', 'even', 'say', 'flowing', 'like', 'lava'],
#  ['hiya', 'greetings', 'salutations'],
#  ['managed',
#   'buy',
#   'two',
#   'used',
#   'brand',
#   'new',
#   'usd',
#   'thought',
#   'pretty',
#   'sweet',
#   'deal'],
#  ['currently',
#   'using',
#   'carboflex',
#   'feel',
#   'so-so',
#   'racket',
#   'albeit',
#   'immense',
#   'popularity',
#   'among',
#   'professional',
#   'players'],
#  ['all-time', 'fave', 'still', 'dunlop', 'aerogel', 'elite'],
#  ['first', 'head-heavy', 'blx', 'tour', 'powerful', 'racket'],
#  ['played',
#   'sets',
#   'using',
#   'solely',
#   'racket',
#   'buddies',
#   'simply',
#   'last',
#   'night'],
#  ['easy', 'head-heavy', 'frame', 'execute', 'cross-court', 'nick'],
#  ['regardless',
#   'power',
#   'within',
#   'simply',
#   'defy',
#   'mother',
#   'nature',
#   "'m",
#   'year',
#   'games',
#   'dragged',
#   'racket',
#   'really',
#   'started',
#   'feel',
#   'like',
#   'thors',
#   'hammer'],
#  ['th',
#   'th',
#   'game',
#   'practically',
#   'forehand',
#   'volley',
#   'drops',
#   'went',
#   'ringing',
#   'tin',
#   'like',
#   'jackpot',
#   'machine'],
#  ['change',
#   'tactics',
#   'down-the-wall',
#   'attrition',
#   'squash',
#   'simply',
#   'no-go'],
#  ['weight', 'distribution', 'obvious'],
#  ['overall', 'sheer', 'pleasure', 'playing', 'racket', 'player', 'fresh'],
#  ['update', 'durability', 'due', 'course'],
#  ['thank'],
#  ['hope', 'mail', 'find', 'well'],
#  ['professional',
#   'sporting',
#   'equipment',
#   'supplier',
#   'tennis',
#   'badminton',
#   'rackets',
#   'sell',
#   'also',
#   'customize',
#   'racket',
#   'info',
#   'pls',
#   'referred',
#   'http',
#   '//www.hm-trade.com/',
#   'need',
#   'pls',
#   'let',
#   'us',
#   'know',
#   'freely'],
#  ['looking', 'forward', 'repy'],
#  ['rackets', 'discount'],
#  ['strung', 'regripped', 'karakal', 'grip', 'racket', 'weighs', 'grams'],
#  ['wilson',
#   'site',
#   'mentions',
#   'balancepoint',
#   'cm',
#   "'ve",
#   'measured',
#   'cm',
#   'would',
#   'call',
#   'slightly',
#   'head-heavy'],
#  ['immediately', 'first', 'balls', 'hit', 'felt', 'good'],
#  ['great', 'control', 'feel', 'plenty', 'power', '``', 'hood', '``'],
#  ['like',
#   'wilson',
#   'tour',
#   'blx',
#   'rackets',
#   'simple',
#   'straight',
#   'decent',
#   'design'],
#  ['sponsored',
#   'links',
#   'product',
#   "'d",
#   'marwan',
#   'using',
#   'harrow',
#   'silk',
#   'years'],
#  ['new',
#   'racket',
#   'harrow',
#   'response',
#   'also',
#   'teardrop-shaped',
#   'picture',
#   'appears',
#   'slightly',
#   'different',
#   'frame'],
#  ['harrow', 'says', 'racket', '``', 'new', 'trap', 'door', 'end', 'cap', '``'],
#  ['guess',
#   'means',
#   "'s",
#   'bit',
#   'graphite',
#   'rattling',
#   'around',
#   'inside',
#   'frame',
#   'rare',
#   'super',
#   'annoying',
#   'open',
#   'trap',
#   'door',
#   'shake'],
#  ['comments',
#   'wondering',
#   'entirely',
#   'new',
#   'racquet',
#   'rebranded',
#   'harrow',
#   'renegade',
#   'specs'],
#  ['question',
#   "n't",
#   'utilize',
#   'silk',
#   'signature',
#   'edition',
#   'however',
#   'string',
#   'tension',
#   'high',
#   'harrow',
#   'lbs',
#   'tension'],
#  ["'d",
#   'like',
#   'overlay',
#   'racquet',
#   'silk',
#   'renegade',
#   'see',
#   'frames',
#   'line'],
#  ['christian',
#   'asked',
#   'question',
#   'compression',
#   'socks',
#   'squash',
#   'squashsource',
#   "'re",
#   'usopensquash',
#   'review',
#   'calf',
#   'compression',
#   'sleeves',
#   'see'],
#  ['tough', 'see', 'brands', 'etc'],
#  ['seem',
#   'popular',
#   'thx',
#   'christian',
#   'a.',
#   'sidor',
#   'christiansidor',
#   'october',
#   'us',
#   'read',
#   '...',
#   'recently',
#   'looking',
#   'white',
#   'squash',
#   'clothing',
#   'wear',
#   'one',
#   'country',
#   'clubs',
#   'philly',
#   'white',
#   'clothing',
#   'policy'],
#  ['took',
#   'find',
#   'right',
#   'stuff',
#   'thought',
#   "'d",
#   'share',
#   'ended',
#   'purchasing'],
#  ["'s",
#   'video',
#   'overview',
#   'read',
#   '...',
#   'thought',
#   "'d",
#   'create',
#   'page',
#   'squash',
#   'socks',
#   'people',
#   'ask',
#   'questions',
#   'leave',
#   'suggestions',
#   'use'],
#  ['longest', 'time', 'wore', 'regular', 'white', 'athletic', 'crew', 'socks'],
#  ['cheap',
#   'fine',
#   'elastic',
#   'started',
#   'wear',
#   'away',
#   'got',
#   'sort',
#   'droopy',
#   'read',
#   '...',
#   'via',
#   'ebay.com',
#   'affiliate',
#   'links',
#   'buy',
#   'us',
#   'amazon.com',
#   'ebay.com',
#   'got',
#   'gift',
#   'christmas',
#   'really',
#   'liking',
#   'squash'],
#  ["'s",
#   'little',
#   'difficult',
#   'find',
#   'exact',
#   'item',
#   'thought',
#   'would',
#   'let',
#   'everyone',
#   'know',
#   'brand',
#   'read',
#   '...',
#   'creating',
#   'page',
#   'salming',
#   'shirts'],
#  ['like',
#   'salming',
#   'polo',
#   'shirt',
#   "n't",
#   'posted',
#   'much',
#   'squash',
#   'clothing',
#   'category',
#   'think',
#   'shirt',
#   'pretty',
#   'cool',
#   'remember',
#   'amr',
#   'shabana',
#   'looking',
#   'dapper',
#   'read',
#   '...',
#   "'s",
#   'another',
#   'one',
#   'adidas',
#   'adizero',
#   'tee',
#   'shirts'],
#  ['like', 'one', 'might', 'go', 'pretty', 'well', 'new', 'shoes', 'transit'],
#  ['might', 'get', 'shirt', 'wait', 'get', 'shoes', 'make', 'moves', 'though'],
#  ['photos',
#   'via',
#   'holabirdsports.com',
#   'buy',
#   'us',
#   'holabirdsports.com',
#   'read',
#   '...',
#   "'s",
#   'james',
#   'willstrop',
#   'left',
#   'ramy',
#   'ashour',
#   'semifinals',
#   'north',
#   'american',
#   'open'],
#  ['like',
#   'willstrop',
#   'confused',
#   'orange',
#   'look',
#   'goes',
#   'better',
#   'shoes'],
#  ['photo',
#   'dan',
#   'bogosh',
#   'naosquash.com',
#   'anyhow',
#   'tracked',
#   'read',
#   '...',
#   'asics',
#   'gel',
#   'rocket',
#   "'s",
#   'asics',
#   'gel',
#   'rocket'],
#  ['asics',
#   'gel',
#   'rockets',
#   'relatively',
#   'low-priced',
#   'usually',
#   'pretty',
#   'cool',
#   'styles',
#   'making',
#   'one',
#   'popular',
#   'squash',
#   'shoes',
#   'around'],
#  ['tested',
#   'shoe',
#   'video',
#   'review',
#   'shoe',
#   'comes',
#   'lots',
#   'different',
#   'color',
#   'schemes',
#   'longer',
#   'available'],
#  ['please', 'see', 'different', 'variations'],
#  ['possible', 'ive', 'provided', 'affiliate', 'links'],
#  ['buy',
#   'one',
#   'affiliate',
#   'links',
#   'receive',
#   'small',
#   'commission',
#   'thanks'],
#  ['weight',
#   'shoes',
#   'grams',
#   'per',
#   'shoe',
#   'based',
#   'mens',
#   'us',
#   'size',
#   'pair'],
#  ['comments', 'hi', 'jo', 'pair'],
#  ['insole', 'glued', 'looks', 'like', 'peeled', 'removed'],
#  ['able',
#   'peel',
#   'partway',
#   'though',
#   "n't",
#   'pull',
#   'way',
#   "n't",
#   'want',
#   'risk',
#   'wrecking'],
#  ['remained',
#   'stuck',
#   'bottom',
#   'shoe',
#   'peeled',
#   'back',
#   'suspect',
#   'using',
#   'shoes',
#   'pounding',
#   'probably',
#   'fused',
#   'together',
#   'especially',
#   'heel',
#   'tried',
#   'unpeel'],
#  ['ca', "n't", 'sure', 'guess', "'ll", 'able', 'remove', 'problem'],
#  ['ive', 'wearing', 'rockets', 'since', 'around', 'new', 'year'],
#  ['agree', 'need', 'pretty', 'low', 'price', 'look', 'ok', 'well'],
#  ['previously',
#   'wore',
#   'blasts',
#   'although',
#   'cushioned',
#   'felt',
#   'significantly',
#   'heavier'],
#  ['still',
#   'pair',
#   'upcourts',
#   'xmas',
#   'sales',
#   'cupboard',
#   'picked',
#   'week',
#   '``',
#   'white/blue/lime',
#   'version'],
#  ["'m", 'really', 'enjoying'],
#  ...]

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
wordnet_pos_mapping = {
    "N": wn.NOUN,
    "V": wn.VERB,
    "J": wn.ADJ,
    "R": wn.ADV
}

def pos_tag_wordnet(tokens):
  """
    Tag text with wordnet format
  """
  pos_tagged_text = nltk.pos_tag(tokens)

  # map the pos tagging output with wordnet 
  pos_tagged_text = [(word, wordnet_pos_mapping.get(pos_tag[0])) if (pos_tag[0] in wordnet_pos_mapping.keys()) and (pos_tag[0] != "R")
                                                                 else (word, wn.NOUN)
                      for (word, pos_tag) in pos_tagged_text]
  
  return pos_tagged_text

# [(Synset('line.n.18'), 23),
#  (Synset('line.n.18'), 78),
#  (Synset('line.n.18'), 44),
#  (Synset('line.n.11'), 42670),
#  (Synset('line.n.18'), 43),
#  (Synset('line.n.18'), 43),
#  (Synset('line.n.18'), 21),
#  (Synset('line.n.18'), 19),
#  (Synset('line.n.18'), 67),
#  (Synset('line.n.18'), 19),
#  (Synset('line.n.18'), 67),
#  (Synset('line.n.11'), 32),
#  (Synset('line.n.11'), 56),
#  (Synset('line.n.18'), 42),
#  (Synset('line.n.11'), 11),
#  (Synset('line.n.11'), 11),
#  (Synset('line.n.11'), 56),
#  (Synset('line.n.18'), 42),
#  (Synset('line.n.18'), 71),
#  (Synset('line.n.11'), 36),
#  (Synset('line.n.18'), 71),
#  (Synset('line.n.11'), 36),
#  (Synset('line.n.18'), 70),
#  (Synset('line.n.18'), 38),
#  (Synset('line.n.11'), 25),
#  (Synset('line.n.11'), 72),
#  (Synset('line.n.11'), 25),
#  (Synset('line.n.11'), 72),
#  (Synset('line.n.18'), 57),
#  (Synset('line.n.11'), 72),
#  (Synset('line.n.18'), 49),
#  (Synset('line.n.11'), 113),
#  (Synset('line.n.11'), 10),
#  (Synset('line.n.20'), 57),
#  (Synset('line.n.11'), 42663),
#  (Synset('line.n.18'), 88),
#  (Synset('line.n.11'), 10),
#  (Synset('line.n.11'), 42663),
#  (Synset('line.n.18'), 88),
#  (Synset('line.n.11'), 8),
#  (Synset('line.n.18'), 36),
#  (Synset('line.n.18'), 36),
#  (Synset('line.n.18'), 22),
#  (Synset('line.n.11'), 63),
#  (Synset('line.n.18'), 18),
#  (Synset('line.n.11'), 22),
#  (Synset('line.n.18'), 27),
#  (Synset('line.n.18'), 27)]

# %% [markdown]
# 2. Compute the proportion of word occurrences which were disambiguated identically by the three algorithms, separately for `line` and `hard` (#identical outputs / #total occurences of word). For which of the two words is there higher agreement between the methods?  (..mapping?)

# %%
# manually mapping between SENSEVAL 2 corpus and WordNet   

senseval_wn_mapping = {
    "HARD1": ["difficult.a.01",
              "arduous.s.01",
              "hard.s.11",
              "hard.r.01",
              "hard.r.09"],    # needing much effort or skill to accomplish, deal with, or understand
    "HARD2": ["hard.a.02",          # dispassionate - not influenced by strong emotion, and so able to be rational and impartial
              "difficult.a.01",
              "hard.s.04",
              "intemperate.s.03",
              "unvoiced.a.01"],
    "HARD3": ["hard.a.03", 
              "hard.r.07", 
              "heavily.r.07"],         # resisting weight or pressure / solid, firm, and rigid; not easily broken, bent, or pierced
    "cord": ["line.n.18", "cable.n.02"],
    "division": ["line.n.29"],
    "phone": ["telephone_line.n.02"],
    "product": ["line.n.22"],
    "text": ["line.n.05", "note.n.02", "agate_line.n.01"]
}

# %%
count = 0
for it in zip(res_hard, lesk_res_hard, bp_results_hard):
  if it[2][0] is None:
    continue
  if it[1][1] != it[2][0]: # check if the corpus-based approaches disagree:
    continue
  else:
    for syn_map in senseval_wn_mapping[it[0]]:
      if syn_map == it[1][1].name():
        count += 1
        continue

print('Coverage of all three algorithms for word `hard` :', count / len(bp_results_hard))
# Out:
# Coverage of all three algorithms for word `hard` : 0.013888888888888888

# %%
count = 0
for it in zip(res_line, lesk_res_line, bp_results_line):
  if it[2][0] is None:
    continue
  if it[1][1] != it[2][0]: # check if the corpus-based approaches disagree:
    continue
  else:
    for syn_map in senseval_wn_mapping[it[0]]:
      if syn_map == it[1][1].name():
        count += 1
        continue

print('Coverage of all three algorithms for word `line` :', count / len(bp_results_line))
# Out:
# Coverage of all three algorithms for word `line` : 0.0

# %% [markdown]
# 3. Pick one of the knowledge-based algorithms above and print the instances where it disagreed with the Naive Bayes method. (they returned a different prediction): show the context where the word occured, and the outputs for each of the methods.

# %%
for it in zip(lesk_res_hard, res_hard):
  disagreement = True

  for syn_map in senseval_wn_mapping[it[1]]:
    if syn_map == it[0][1].name():
      disagreement = False

  if disagreement:
    print('Sentence:', ' '.join(sentences[it[0][0]]))
    print('Output:')
    print('\t Naive Bayes:', senseval_wn_mapping[it[1]])
    print('\t Lesk Algorithm:', it[0][1].name(), ' - ', it[0][1].definition())
    print()
# Out:
# Sentence: the bad small sweet spot , and the string type it came with is not to my liking at all ( feels hard , and was not helped by manufacturer string tension ) .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.r.10  -  to the full extent possible; all the way
#
# Sentence: i have to pull the laces tighter on the so that my foot does n't move within the shoe on hard lunges .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: i have to pull the laces tighter on the so that my foot does n't move within the shoe on hard lunges .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: i also got hit hard with a racquet on a follow through and once again i came out of it unscathed and so did the i-mask .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.a.08  -  (of speech sounds); produced with the back of the tongue raised toward or touching the velum
#
# Sentence: the design is very cool , i felt them a bit hard at the beginning but it always takes my feet some time to adapt because they are very different from the adidas adipower stabil .
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: that said , i feel more grounded and stable , but the later months of my gel blade were with my pair of those shoes being very worn down so its hard to say .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.a.08  -  (of speech sounds); produced with the back of the tongue raised toward or touching the velum
#
# Sentence: if you are a hard hitter go for kgs or .
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: i believe the full name of this racket is actually the `` head graphene xt xenon slimbody `` but yowzer that 's hard to remember and even harder to say .
# Output:
# 	 Naive Bayes: ['difficult.a.01', 'arduous.s.01', 'hard.s.11', 'hard.r.01', 'hard.r.09']
# 	 Lesk Algorithm: hard.r.10  -  to the full extent possible; all the way
#
# Sentence: it worked better on a warmer court and against a hard hitter .
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: the feeling is different with the new model , i think its the weight distribution and the technology enhancement made on the previous version ( years of hard work !
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.a.08  -  (of speech sounds); produced with the back of the tongue raised toward or touching the velum
#
# Sentence: i believe the full name of this racket is actually the `` head graphene xt xenon slimbody `` but yowzer that 's hard to remember and even harder to say .
# Output:
# 	 Naive Bayes: ['difficult.a.01', 'arduous.s.01', 'hard.s.11', 'hard.r.01', 'hard.r.09']
# 	 Lesk Algorithm: hard.r.10  -  to the full extent possible; all the way
#
# Sentence: it worked better on a warmer court and against a hard hitter .
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: if you are a hard hitter go for kgs or .
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: the feeling is different with the new model , i think its the weight distribution and the technology enhancement made on the previous version ( years of hard work !
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.a.08  -  (of speech sounds); produced with the back of the tongue raised toward or touching the velum
#
# Sentence: hours playing hard and the ball is dead .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: unvoiced.a.01  -  produced without vibration of the vocal cords
#
# Sentence: hours playing hard and the ball is dead .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: unvoiced.a.01  -  produced without vibration of the vocal cords
#
# Sentence: i like to hit hard , but also to put the ball dead in the corner .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: socks are well made , comfortable and its hard to worn them out .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: socks are well made , comfortable and its hard to worn them out .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: my insights : i have problems hitting hard with the x.lite control .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.a.08  -  (of speech sounds); produced with the back of the tongue raised toward or touching the velum
#
# Sentence: my game has significantly improved after switching its relatively hard to cut the ball as compared to rebel that was .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: but its heavy so its hard on your wrist .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: my game has significantly improved after switching its relatively hard to cut the ball as compared to rebel that was .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: but its heavy so its hard on your wrist .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: however , have a junior who managed to break jewels in around three months and she 's far from what youd classify as an aggressive player or a hard hitter who smashes the back corners .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: so i guess next one will either be the carbonflex or the the the dunergy as i play hard thus i do n't need a racket that primarily generates power .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: i believe the full name of this racket is actually the `` head graphene xt xenon slimbody `` but yowzer that 's hard to remember and even harder to say .
# Output:
# 	 Naive Bayes: ['difficult.a.01', 'arduous.s.01', 'hard.s.11', 'hard.r.01', 'hard.r.09']
# 	 Lesk Algorithm: hard.r.10  -  to the full extent possible; all the way
#
# Sentence: strings are a very subjective matter so its hard to recommend one `` best `` string .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: i have the old yellow , so does quit a few elite players , it is very good in two ways ; it does not break so easily , and when using it i 'm thinking the rest of the work has to be done by myself and hard work not shopping , by technical improving , swing , timing etc .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: arduous.s.01  -  characterized by effort to the point of exhaustion; especially physical effort
#
# Sentence: i 'm open to change in old yellow , so does quit a few elite players , it is very good in two ways ; it does not break so easily , and when using it i 'm thinking the rest of the work has to be done by myself and hard work not shopping , by technical improving , swing , timing etc .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: arduous.s.01  -  characterized by effort to the point of exhaustion; especially physical effort
#
# Sentence: i have the old yellow , so does quit a few elite players , it is very good in two ways ; it does not break so easily , and when using it i 'm thinking the rest of the work has to be done by myself and hard work not shopping , by technical improving , swing , timing etc .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: arduous.s.01  -  characterized by effort to the point of exhaustion; especially physical effort
#
# Sentence: i 'm open to change in old yellow , so does quit a few elite players , it is very good in two ways ; it does not break so easily , and when using it i 'm thinking the rest of the work has to be done by myself and hard work not shopping , by technical improving , swing , timing etc .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: arduous.s.01  -  characterized by effort to the point of exhaustion; especially physical effort
#
# Sentence: i believe the full name of this racket is actually the `` head graphene xt xenon slimbody `` but yowzer that 's hard to remember and even harder to say .
# Output:
# 	 Naive Bayes: ['difficult.a.01', 'arduous.s.01', 'hard.s.11', 'hard.r.01', 'hard.r.09']
# 	 Lesk Algorithm: hard.r.10  -  to the full extent possible; all the way
#
# Sentence: image via tecnifibre.com i think this is the same string , just the prior packaging : image via amazon.com and i think this is also the same string , with yet another package variation : comments tension alone wo n't cause string to fray its how hard you hit and how much cut you hit with .
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear
#
# Sentence: sponsored links product i 'd : reviews we have been inundated over the past few weeks with requests for advice on tough , durable high performance squash shoes so we have done some hard looking at what is on the market right now .
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.a.08  -  (of speech sounds); produced with the back of the tongue raised toward or touching the velum
#
# Sentence: sponsored links product i 'd : reviews we have been inundated over the past few weeks with requests for advice on tough , durable high performance squash shoes so we have done some hard looking at what is on the market right now .
# Output:
# 	 Naive Bayes: ['hard.a.02', 'difficult.a.01', 'hard.s.04', 'intemperate.s.03', 'unvoiced.a.01']
# 	 Lesk Algorithm: hard.a.08  -  (of speech sounds); produced with the back of the tongue raised toward or touching the velum
#
# Sentence: one reader said the + . string `` felt tight and hard `` ( that 's what she said ) , and another said `` it was too stiff for my liking `` ( that 's what she said ) .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: unvoiced.a.01  -  produced without vibration of the vocal cords
#
# Sentence: i tried both the and the + on the same day and i had a hard time telling one from the other , no joke , its really close , especially when the + is brand new .
# Output:
# 	 Naive Bayes: ['difficult.a.01', 'arduous.s.01', 'hard.s.11', 'hard.r.01', 'hard.r.09']
# 	 Lesk Algorithm: hard.r.08  -  very near or close in space or time
#
# Sentence: i believe the full name of this racket is actually the `` head graphene xt xenon slimbody `` but yowzer that 's hard to remember and even harder to say .
# Output:
# 	 Naive Bayes: ['difficult.a.01', 'arduous.s.01', 'hard.s.11', 'hard.r.01', 'hard.r.09']
# 	 Lesk Algorithm: hard.r.10  -  to the full extent possible; all the way
#
# Sentence: i believe the full name of this racket is actually the `` head graphene xt xenon slimbody `` but yowzer that 's hard to remember and even harder to say .
# Output:
# 	 Naive Bayes: ['difficult.a.01', 'arduous.s.01', 'hard.s.11', 'hard.r.01', 'hard.r.09']
# 	 Lesk Algorithm: hard.r.10  -  to the full extent possible; all the way
#
# Sentence: my + was strung at m/ c and it felt good for that string with good power and no vibration even though it is a very hard string .
# Output:
# 	 Naive Bayes: ['difficult.a.01', 'arduous.s.01', 'hard.s.11', 'hard.r.01', 'hard.r.09']
# 	 Lesk Algorithm: hard.r.05  -  slowly and with difficulty
#
# Sentence: its hard to find a played from pl = text me : meehoo.uk gmail.com hi , always ready to give a good tip .
# Output:
# 	 Naive Bayes: ['hard.a.03', 'hard.r.07', 'heavily.r.07']
# 	 Lesk Algorithm: hard.s.11  -  unfortunate or hard to bear

# %% [markdown]
# Q: For which of the two words is there higher agreement between the methods?
# A: For the word 'hard' is a higher agreement between the three methods. This may be due to the fact that the word *'line'* has more meanings compared to the word *'hard'*.

# %% [markdown]
# 4. Train several NaiveBayes models for 'hard.pos'/'interest.pos', including at least the following:
# - for the wsd_word_features version, vary number between 100, 200 and 300,
# - and vary the stopwords_list between [] (i.e., the null list) and STOPWORDS;

# %%
# NB, with features based on 100 most frequent context words
wsd_classifier(trainer=NaiveBayesClassifier.train, word='hard.pos', features=wsd_word_features, number=100)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8431

# %%
# NB, with features based on 200 most frequent context words
wsd_classifier(trainer=NaiveBayesClassifier.train, word='hard.pos', features=wsd_word_features, number=200)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8547

# %%
# NB, with features based on 100 most frequent context words
wsd_classifier(trainer=NaiveBayesClassifier.train, word='hard.pos', features=wsd_word_features, number=300)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8547

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, word='hard.pos', features=wsd_word_features, number=300, stopwords_list=[])
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8604

# %%
# NB, with features based on 100 most frequent context words
wsd_classifier(trainer=NaiveBayesClassifier.train, word='line.pos', features=wsd_word_features, number=100)
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.6169

# %%
# NB, with features based on 200 most frequent context words
wsd_classifier(trainer=NaiveBayesClassifier.train, word='line.pos', features=wsd_word_features, number=200)
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.6663

# %%
# NB, with features based on 300 most frequent context words
wsd_classifier(trainer=NaiveBayesClassifier.train, word='line.pos', features=wsd_word_features, number=300)
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.6928

# %%
# NB, with features based on 300 most frequent context words
wsd_classifier(trainer=NaiveBayesClassifier.train, word='line.pos', features=wsd_word_features, number=300, stopwords_list=[])
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.6843

# %% [markdown]
# - for the wsd_context_features version, vary the distance between 1, 2 and 3,
# - and vary the stopwords_list between [] and STOPWORDS.
# - try to only keep the POS of the words in the context (remove the word itself from the features, and use the POSs instead)

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='hard.pos', 
               features=wsd_context_features,
               distance=1)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.9135

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='hard.pos', 
               features=wsd_context_features,
               stopwords_list=[],
               distance=1)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.9135

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='hard.pos', 
               features=wsd_context_features,
               distance=2)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.9066

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='hard.pos', 
               features=wsd_context_features,
               stopwords_list=[],
               distance=2)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.9066

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='hard.pos', 
               features=wsd_context_features,
               distance=3)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8927

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='hard.pos', 
               features=wsd_context_features,
               stopwords_list=[],
               distance=3)
# Out:
# Reading data...
#  Senses: HARD2 HARD1 HARD3
# Training classifier...
# Testing classifier...
# Accuracy: 0.8927

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='line.pos', 
               features=wsd_context_features,
               distance=1)
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.7470

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='line.pos', 
               features=wsd_context_features,
               distance=2)
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.7470

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='line.pos', 
               features=wsd_context_features,
               distance=3)
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.7470

# %%
wsd_classifier(trainer=NaiveBayesClassifier.train, 
               word='line.pos', 
               features=wsd_context_features,
               stopwords_list=[],
               distance=3)
# Out:
# Reading data...
#  Senses: formation cord text division product phone
# Training classifier...
# Testing classifier...
# Accuracy: 0.7470
