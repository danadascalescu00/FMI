# %%
import re
import string
import unicodedata
from time import time

import numpy as np
import pandas as pd

from numpy.linalg import norm

import nltk
from nltk.corpus import stopwords
from nltk.corpus import brown, movie_reviews, gutenberg, treebank, inaugural 
from nltk.corpus import wordnet as wn

from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('brown')
nltk.download('wordnet')
nltk.download('treebank')
nltk.download('inaugural')
nltk.download('gutenberg')
nltk.download('stopwords')
nltk.download('movie_reviews')

import multiprocessing
from gensim.models import Word2Vec
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Unzipping corpora/inaugural.zip.
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Training

# %% [markdown]
# ## Dataset
#
# The dataset used to train the word embeddings model using gensim from scratch consists of 5 different datasets available through *nltk*:
#
#
# 1.   [Brown Corpus](http://korpus.uib.no/icame/brown/bcm.html)
# 2.   Movie Reviews
# 3.   Inaugural
# 4.   Gutenberg Books
# 5.   Stanford Sentiment Treebank

# %%
brown_dataset = []
for sent in brown.sents():
  sentence = ' '.join(sent)
  brown_dataset.append(sentence)

# %%
df1 = pd.DataFrame(brown_dataset, columns = ['text'])
df1.describe()
# Out:
#          text
# count   57340
# unique  56418
# top         )
# freq       58

# %%
# eliminate empty rows
df1 = df1.dropna().reset_index(drop=True)
df1.isnull().sum()

# eliminate duplicates
df1.drop_duplicates(inplace=True)
df1
# Out:
#                                                     text
# 0      The Fulton County Grand Jury said Friday an in...
# 1      The jury further said in term-end presentments...
# 2      The September-October term jury had been charg...
# 3      `` Only a relative handful of such reports was...
# 4      The jury said it did find that many of Georgia...
# ...                                                  ...
# 57335                                     S. J. Perelman
# 57336                            revulsion in the desert
# 57337  the doors of the D train slid shut , and as I ...
# 57338  She was a living doll and no mistake -- the bl...
# 57339  From what I was able to gauge in a swift , gre...
#
# [56418 rows x 1 columns]

# %%
inaugural_dataset = []
for sent in treebank.sents():
  sentence = ' '.join(sent)
  inaugural_dataset.append(sentence)

# %%
df3 = pd.DataFrame(inaugural_dataset, columns = ['text'])
df3.describe()
# Out:
#                                   text
# count                             3914
# unique                            3904
# top     Terms were n't disclosed *-1 .
# freq                                 8

# %%
# eliminate empty rows
df3 = df5.dropna().reset_index(drop=True)
df3.isnull().sum()

# eliminate duplicates
df3.drop_duplicates(inplace=True)
df3
# Out:
#                                                    text
# 0     Pierre Vinken , 61 years old , will join the b...
# 1     Mr. Vinken is chairman of Elsevier N.V. , the ...
# 2     Rudolph Agnew , 55 years old and former chairm...
# 3     A form of asbestos once used * * to make Kent ...
# 4     The asbestos fiber , crocidolite , is unusuall...
# ...                                                 ...
# 3899  Moreover , they said 0 the first appropriation...
# 3900  They also said that more than a dozen presiden...
# 3901  Sen. Kennedy said in a separate statement that...
# 3902  Trinity Industries Inc. said 0 it reached a pr...
# 3903  Trinity said 0 it plans *-1 to begin delivery ...
#
# [3904 rows x 1 columns]

# %%
treebank_dataset = []
for sent in treebank.sents():
  sentence = ' '.join(sent)
  treebank_dataset.append(sentence)

# %%
df5 = pd.DataFrame(treebank_dataset, columns = ['text'])
df5.describe()
# Out:
#                                   text
# count                             3914
# unique                            3904
# top     Terms were n't disclosed *-1 .
# freq                                 8

# %%
# eliminate empty rows
df5 = df5.dropna().reset_index(drop=True)
df5.isnull().sum()

# eliminate duplicates
df5.drop_duplicates(inplace=True)
df5
# Out:
#                                                    text
# 0     Pierre Vinken , 61 years old , will join the b...
# 1     Mr. Vinken is chairman of Elsevier N.V. , the ...
# 2     Rudolph Agnew , 55 years old and former chairm...
# 3     A form of asbestos once used * * to make Kent ...
# 4     The asbestos fiber , crocidolite , is unusuall...
# ...                                                 ...
# 3908  Moreover , they said 0 the first appropriation...
# 3909  They also said that more than a dozen presiden...
# 3910  Sen. Kennedy said in a separate statement that...
# 3911  Trinity Industries Inc. said 0 it reached a pr...
# 3913  Trinity said 0 it plans *-1 to begin delivery ...
#
# [3904 rows x 1 columns]

# %%
gutenberg_dataset = []
for sent in gutenberg.sents():
  sentence = ' '.join(sent)
  gutenberg_dataset.append(sentence)

# %%
df4 = pd.DataFrame(gutenberg_dataset, columns = ['text'])
df4.describe()
# Out:
#          text
# count   98552
# unique  93572
# top     Ham .
# freq      337

# %%
# eliminate empty rows
df4 = df4.dropna().reset_index(drop=True)
df4.isnull().sum()

# eliminate duplicates
df4.drop_duplicates(inplace=True)
df4
# Out:
#                                                     text
# 0                           [ Emma by Jane Austen 1816 ]
# 1                                               VOLUME I
# 2                                              CHAPTER I
# 3      Emma Woodhouse , handsome , clever , and rich ...
# 4      She was the youngest of the two daughters of a...
# ...                                                  ...
# 98547  Now for my last -- let me look back a moment ;...
# 98548  Long have we lived , joy ' d , caress ' d toge...
# 98549  Yet let me not be too hasty , Long indeed have...
# 98550  May - be it is you the mortal knob really undo...
# 98551                                         my Fancy .
#
# [93572 rows x 1 columns]

# %%
movie_reviews_dataset = []
for sent in movie_reviews.sents():
  sentence = ' '.join(sent)
  movie_reviews_dataset.append(sentence)

# %%
df2 = pd.DataFrame(movie_reviews_dataset, columns = ['text'])
df2.describe()
# Out:
#          text
# count   71532
# unique  66014
# top         .
# freq     3079

# %%
# eliminate empty rows
df2 = df2.dropna().reset_index(drop=True)
df2.isnull().sum()

# eliminate duplicates
df2.drop_duplicates(inplace=True)
df2
# Out:
#                                                     text
# 0      plot : two teen couples go to a church party ,...
# 1                            they get into an accident .
# 2      one of the guys dies , but his girlfriend cont...
# 3                                    what ' s the deal ?
# 4               watch the movie and " sorta " find out .
# ...                                                  ...
# 71527  it ' s a quick , straight shot to the movie ' ...
# 71528  in terms of overall quality , i would compare ...
# 71529  both films are well made with interesting stor...
# 71530  but neither film really felt like it capitaliz...
# 71531  nevertheless , i look forward to niccol ' s ne...
#
# [66014 rows x 1 columns]

# %% [markdown]
# Before training the embedding model, we process the text. The preprocessing stage consists of the following procedure:
#
#
# *   The text is decoded and then normalized, i.e., the data is transformed from complex symbols into simple characters. Characters can be subjected to various forms of encoding, such as Latin, ISO/IEC 8859-1, etc. Therefore, for better analysis, it is necessary to keep the data in a standard encoding format. For this requirement, we choose UTF-8 encoding because it is widely accepted and often recommended.
# *   We eliminate all numeric and special characters.
# *   Any letter repeated more than three times in a row is replaced by two repetitions of the same letter as the usual rules of English spelling forbid triple letters (for example "coooool" is replaced by "cool")
# *   Split the text in smaller units (word tokens).

# %%
def normalize_text(x):
    x = unicodedata.normalize('NFKD', x).encode('ascii', 'ignore').decode('utf-8', 'ignore') # remove accented chars
    return x

"""
    Any letter repeated more than three times in a row is replaced by two repetitions of the same letter
"""
def remove_multiple_occurences(text):
    n = len(text)

    if n < 3:
        return text

    i, count = 0, 0
    while i < n - 1:
        i += 1
        if text[i] != text[i-1]:
            count = 0
        else:
            count += 1
            if count >= 2:
                text = text[:i] + text[i+1:]
                n -= 1
                i -= 1

    return text

# %%
from nltk.tokenize import word_tokenize

def preprocessing(text_dataframe, set_stopwords=None): 
  # STEP 1: Normalization
  text_dataframe['text'] = text_dataframe['text'].apply(lambda x: normalize_text(x))
  # STEP 2: Eliminate special characters
  special_characters = string.punctuation + string.digits
  text_dataframe['text'] = text_dataframe['text'].apply(lambda x : x.translate(str.maketrans(' ', ' ', special_characters)))
  # STEP 3: Replace any sequence of the same letter of length greater than 2 with a sequence of length 2
  text_dataframe['text'] = text_dataframe['text'].apply(remove_multiple_occurences)
  # STEP 4: Lowercasing
  text_dataframe['text'] = text_dataframe['text'].apply(lambda x: x.lower())
  # STEP 5: Tokenization
  text_dataframe['words'] = text_dataframe['text'].apply(lambda x: word_tokenize(x))
  # Optional: eliminate stopwords
  if set_stopwords is not None:
    text_dataframe['words'] = text_dataframe['words'].apply(lambda x: [w for w in x if w not in set_stopwords])
  
  """
    The central idea of Word2Vec is Skipgram with Negative Sampling, so it uses
    context words to learn the embeddings. If a sentence has less than 4 words,
    we will eliminate it.
  """
  text_dataframe['num_words'] = text_dataframe['words'].apply(lambda x: len(x))
  text_dataframe = text_dataframe[text_dataframe['num_words'] > 4]

  return text_dataframe

# %%
df = pd.concat([df1, df2, df3, df4, df5], axis=0, ignore_index=True)
df
# Out:
#                                                      text
# 0       The Fulton County Grand Jury said Friday an in...
# 1       The jury further said in term-end presentments...
# 2       The September-October term jury had been charg...
# 3       `` Only a relative handful of such reports was...
# 4       The jury said it did find that many of Georgia...
# ...                                                   ...
# 223807  Moreover , they said 0 the first appropriation...
# 223808  They also said that more than a dozen presiden...
# 223809  Sen. Kennedy said in a separate statement that...
# 223810  Trinity Industries Inc. said 0 it reached a pr...
# 223811  Trinity said 0 it plans *-1 to begin delivery ...
#
# [223812 rows x 1 columns]

# %%
df = preprocessing(df, set_stopwords=stopwords.words('english'))
df
# Out:
#                                                      text  \
# 0       the fulton county grand jury said friday an in...
# 1       the jury further said in termend presentments ...
# 2       the septemberoctober term jury had been charge...
# 3        only a relative handful of such reports was r...
# 4       the jury said it did find that many of georgia...
# ...                                                   ...
# 223807  moreover  they said  the first appropriations ...
# 223808  they also said that more than a dozen presiden...
# 223809  sen kennedy said in a separate statement that ...
# 223810  trinity industries inc said  it reached a prel...
# 223811  trinity said  it plans  to begin delivery in t...
#
#                                                     words  num_words
# 0       [fulton, county, grand, jury, said, friday, in...         16
# 1       [jury, said, termend, presentments, city, exec...         18
# 2       [septemberoctober, term, jury, charged, fulton...         20
# 3       [relative, handful, reports, received, jury, s...         14
# 4       [jury, said, find, many, georgias, registratio...         12
# ...                                                   ...        ...
# 223807  [moreover, said, first, appropriations, bill, ...         15
# 223808  [also, said, dozen, presidents, ppa, called, l...         19
# 223809  [sen, kennedy, said, separate, statement, supp...         24
# 223810  [trinity, industries, inc, said, reached, prel...         14
# 223811  [trinity, said, plans, begin, delivery, first,...          9
#
# [174621 rows x 3 columns]

# %% [markdown]
# ## Training the word embeddings from scratch

# %%
cores = multiprocessing.cpu_count()

# %%
# initialize model
model = Word2Vec(min_count=50,
                 window=15,           # Bigger window size => relatedness
                 size=150,            # We choose *size* parameter to be 150 due to our small dataset
                 sg=1,                # trainig algorithm
                #  sample=1e-7,
                #  alpha=0.015,
                #  min_alpha=0.0005,
                #  negative=7,        
                 workers=cores)

# %%
t = time()

model.build_vocab(df['words'], progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to build vocab: 0.05 mins

# %%
model.corpus_count
# Out:
# 174621

# %%
t = time()

model.train(df['words'], total_examples=model.corpus_count, epochs=model.iter + 2, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# Time to train the model: 2.48 mins

# %% [markdown]
# ## Exploring the model

# %%
print('Most similar to \'number\':\n', model.wv.most_similar(positive=["number"]))
# Out:
# Most similar to 'number':
#  [('numbers', 0.5407553911209106), ('numbered', 0.5209192037582397), ('fifty', 0.46774619817733765), ('thousand', 0.4514497220516205), ('sum', 0.44452738761901855), ('males', 0.4422333836555481), ('nine', 0.44021376967430115), ('eight', 0.4339964687824249), ('threescore', 0.4332047402858734), ('according', 0.42926108837127686)]

# %%
print('Most similar to \'modern\':\n', model.wv.most_similar(positive=["modern"]))
# Out:
# Most similar to 'modern':
#  [('culture', 0.5394097566604614), ('designs', 0.5135877132415771), ('contemporary', 0.49742984771728516), ('myth', 0.4955432415008545), ('tradition', 0.4731130599975586), ('era', 0.4685472846031189), ('greek', 0.46849197149276733), ('civilization', 0.4638400077819824), ('primitive', 0.46175244450569153), ('inspiration', 0.4594225287437439)]

# %%
print('Most similar to \'expenses\':\n', model.wv.most_similar(positive=["expenses"]))
# Out:
# Most similar to 'expenses':
#  [('taxes', 0.7442578077316284), ('wages', 0.6972888708114624), ('income', 0.6941887736320496), ('revenue', 0.6820709705352783), ('estimated', 0.662767767906189), ('expense', 0.6597381234169006), ('salary', 0.639643669128418), ('excess', 0.6345015168190002), ('secured', 0.623443603515625), ('exceed', 0.622524082660675)]

# %% [markdown]
# # Evaluation

# %% [markdown]
# ### WordNet coverage
# Percentage of all words in your embedding space which can be found in WordNet. For each word, you will check whether he word or its lemma occurs in a synset in WordNet.

# %%
lemmatizer = WordNetLemmatizer()

# %%
vocab = list(model.wv.vocab)

# %%
wn_lemmas = set(wn.all_lemma_names())

count = 0
for word in vocab:
  lemmatized_word = lemmatizer.lemmatize(word)
  if word in wn_lemmas or lemmatized_word in wn_lemmas:
    count += 1

print('WordNet coverage: %.2f' % ((count / len(vocab)) * 100.))
# Out:
# WordNet coverage: 88.41

# %% [markdown]
# ### Precision, Recall, F1-score

# %%
rnd_ind = np.random.randint(len(vocab), size=(1000))
vocab = np.array(vocab)
words_pairs = [(w1, w2) for i, w1 in enumerate(vocab[rnd_ind]) for w2 in vocab[rnd_ind][i+1:] if w1 != w2]
words_pairs
# Out:
# [('cops', 'associate'),
#  ('cops', 'dave'),
#  ('cops', 'light'),
#  ('cops', 'programs'),
#  ('cops', 'workers'),
#  ('cops', 'live'),
#  ('cops', 'able'),
#  ('cops', 'tide'),
#  ('cops', 'doctors'),
#  ('cops', 'buster'),
#  ('cops', 'opportunity'),
#  ('cops', 'vile'),
#  ('cops', 'thunder'),
#  ('cops', 'health'),
#  ('cops', 'sister'),
#  ('cops', 'conceive'),
#  ('cops', 'calm'),
#  ('cops', 'editing'),
#  ('cops', 'bleak'),
#  ('cops', 'nov'),
#  ('cops', 'donnell'),
#  ('cops', 'dropped'),
#  ('cops', 'dixon'),
#  ('cops', 'magnitude'),
#  ('cops', 'surprised'),
#  ('cops', 'pressures'),
#  ('cops', 'abilities'),
#  ('cops', 'clothing'),
#  ('cops', 'leo'),
#  ('cops', 'attended'),
#  ('cops', 'tough'),
#  ('cops', 'passed'),
#  ('cops', 'rarely'),
#  ('cops', 'elliot'),
#  ('cops', 'par'),
#  ('cops', 'vehicle'),
#  ('cops', 'alicia'),
#  ('cops', 'realistic'),
#  ('cops', 'temper'),
#  ('cops', 'barred'),
#  ('cops', 'always'),
#  ('cops', 'protestant'),
#  ('cops', 'saint'),
#  ('cops', 'top'),
#  ('cops', 'sweet'),
#  ('cops', 'evening'),
#  ('cops', 'emma'),
#  ('cops', 'mansion'),
#  ('cops', 'dancing'),
#  ('cops', 'ages'),
#  ('cops', 'punishment'),
#  ('cops', 'randalls'),
#  ('cops', 'function'),
#  ('cops', 'familiar'),
#  ('cops', 'propaganda'),
#  ('cops', 'butter'),
#  ('cops', 'effect'),
#  ('cops', 'planning'),
#  ('cops', 'pushing'),
#  ('cops', 'tricks'),
#  ('cops', 'enjoyment'),
#  ('cops', 'picking'),
#  ('cops', 'equally'),
#  ('cops', 'cheesy'),
#  ('cops', 'trilogy'),
#  ('cops', 'best'),
#  ('cops', 'family'),
#  ('cops', 'ltd'),
#  ('cops', 'thrust'),
#  ('cops', 'fortune'),
#  ('cops', 'deed'),
#  ('cops', 'runs'),
#  ('cops', 'consider'),
#  ('cops', 'creative'),
#  ('cops', 'denying'),
#  ('cops', 'advantages'),
#  ('cops', 'detective'),
#  ('cops', 'marks'),
#  ('cops', 'punish'),
#  ('cops', 'revolves'),
#  ('cops', 'invited'),
#  ('cops', 'troubled'),
#  ('cops', 'device'),
#  ('cops', 'verse'),
#  ('cops', 'sudden'),
#  ('cops', 'forcing'),
#  ('cops', 'turned'),
#  ('cops', 'accurate'),
#  ('cops', 'forty'),
#  ('cops', 'borne'),
#  ('cops', 'glance'),
#  ('cops', 'needless'),
#  ('cops', 'strings'),
#  ('cops', 'morgan'),
#  ('cops', 'complain'),
#  ('cops', 'almost'),
#  ('cops', 'discussion'),
#  ('cops', 'answering'),
#  ('cops', 'wherewith'),
#  ('cops', 'accused'),
#  ('cops', 'toys'),
#  ('cops', 'impact'),
#  ('cops', 'thrice'),
#  ('cops', 'thing'),
#  ('cops', 'thanks'),
#  ('cops', 'hoffman'),
#  ('cops', 'gloom'),
#  ('cops', 'boogie'),
#  ('cops', 'screening'),
#  ('cops', 'hast'),
#  ('cops', 'recognize'),
#  ('cops', 'thankfully'),
#  ('cops', 'regardless'),
#  ('cops', 'feeling'),
#  ('cops', 'experiment'),
#  ('cops', 'jokes'),
#  ('cops', 'hoffman'),
#  ('cops', 'compliment'),
#  ('cops', 'relatively'),
#  ('cops', 'clear'),
#  ('cops', 'growth'),
#  ('cops', 'digital'),
#  ('cops', 'model'),
#  ('cops', 'franklin'),
#  ('cops', 'vpon'),
#  ('cops', 'jacket'),
#  ('cops', 'dealt'),
#  ('cops', 'caused'),
#  ('cops', 'september'),
#  ('cops', 'fool'),
#  ('cops', 'editing'),
#  ('cops', 'purely'),
#  ('cops', 'affectionate'),
#  ('cops', 'lips'),
#  ('cops', 'would'),
#  ('cops', 'trace'),
#  ('cops', 'points'),
#  ('cops', 'doubted'),
#  ('cops', 'grateful'),
#  ('cops', 'led'),
#  ('cops', 'snare'),
#  ('cops', 'shown'),
#  ('cops', 'manasseh'),
#  ('cops', 'roads'),
#  ('cops', 'riding'),
#  ('cops', 'reserved'),
#  ('cops', 'passing'),
#  ('cops', 'elinor'),
#  ('cops', 'pregnant'),
#  ('cops', 'tension'),
#  ('cops', 'imports'),
#  ('cops', 'practices'),
#  ('cops', 'films'),
#  ('cops', 'talents'),
#  ('cops', 'doctors'),
#  ('cops', 'reed'),
#  ('cops', 'convenient'),
#  ('cops', 'companions'),
#  ('cops', 'find'),
#  ('cops', 'del'),
#  ('cops', 'exalted'),
#  ('cops', 'advised'),
#  ('cops', 'martin'),
#  ('cops', 'bye'),
#  ('cops', 'samuel'),
#  ('cops', 'flood'),
#  ('cops', 'teenagers'),
#  ('cops', 'tiger'),
#  ('cops', 'filled'),
#  ('cops', 'sprang'),
#  ('cops', 'pattern'),
#  ('cops', 'curtain'),
#  ('cops', 'cloud'),
#  ('cops', 'rigid'),
#  ('cops', 'landlord'),
#  ('cops', 'climactic'),
#  ('cops', 'wide'),
#  ('cops', 'well'),
#  ('cops', 'persuade'),
#  ('cops', 'harville'),
#  ('cops', 'clear'),
#  ('cops', 'transaction'),
#  ('cops', 'attack'),
#  ('cops', 'causes'),
#  ('cops', 'agreeable'),
#  ('cops', 'second'),
#  ('cops', 'gifts'),
#  ('cops', 'management'),
#  ('cops', 'anticipation'),
#  ('cops', 'depths'),
#  ('cops', 'fare'),
#  ('cops', 'would'),
#  ('cops', 'wood'),
#  ('cops', 'allowed'),
#  ('cops', 'growth'),
#  ('cops', 'shepherd'),
#  ('cops', 'check'),
#  ('cops', 'therein'),
#  ('cops', 'babylon'),
#  ('cops', 'vine'),
#  ('cops', 'choices'),
#  ('cops', 'court'),
#  ('cops', 'institution'),
#  ('cops', 'rough'),
#  ('cops', 'martial'),
#  ('cops', 'scarcely'),
#  ('cops', 'ultimately'),
#  ('cops', 'poem'),
#  ('cops', 'flung'),
#  ('cops', 'simon'),
#  ('cops', 'astonishment'),
#  ('cops', 'filmmaking'),
#  ('cops', 'construction'),
#  ('cops', 'begat'),
#  ('cops', 'discovers'),
#  ('cops', 'ways'),
#  ('cops', 'systems'),
#  ('cops', 'lady'),
#  ('cops', 'daring'),
#  ('cops', 'raising'),
#  ('cops', 'price'),
#  ('cops', 'wounded'),
#  ('cops', 'given'),
#  ('cops', 'function'),
#  ('cops', 'moscow'),
#  ('cops', 'yeargin'),
#  ('cops', 'orange'),
#  ('cops', 'cabin'),
#  ('cops', 'multi'),
#  ('cops', 'shouldest'),
#  ('cops', 'ross'),
#  ('cops', 'strengthen'),
#  ('cops', 'across'),
#  ('cops', 'sustain'),
#  ('cops', 'crap'),
#  ('cops', 'reform'),
#  ('cops', 'another'),
#  ('cops', 'interpretation'),
#  ('cops', 'temper'),
#  ('cops', 'mud'),
#  ('cops', 'tents'),
#  ('cops', 'recovery'),
#  ('cops', 'hedge'),
#  ('cops', 'apostles'),
#  ('cops', 'monday'),
#  ('cops', 'borne'),
#  ('cops', 'personally'),
#  ('cops', 'ate'),
#  ('cops', 'subject'),
#  ('cops', 'knowest'),
#  ('cops', 'formation'),
#  ('cops', 'depression'),
#  ('cops', 'twists'),
#  ('cops', 'jolly'),
#  ('cops', 'eleazar'),
#  ('cops', 'thinking'),
#  ('cops', 'affectionate'),
#  ('cops', 'legend'),
#  ('cops', 'essence'),
#  ('cops', 'suspension'),
#  ('cops', 'quaid'),
#  ('cops', 'associates'),
#  ('cops', 'certainty'),
#  ('cops', 'corn'),
#  ('cops', 'claims'),
#  ('cops', 'slapstick'),
#  ('cops', 'nicholson'),
#  ('cops', 'pestilence'),
#  ('cops', 'tuesday'),
#  ('cops', 'democracy'),
#  ('cops', 'event'),
#  ('cops', 'theresa'),
#  ('cops', 'solid'),
#  ('cops', 'ice'),
#  ('cops', 'scott'),
#  ('cops', 'street'),
#  ('cops', 'final'),
#  ('cops', 'frightening'),
#  ('cops', 'intellectual'),
#  ('cops', 'anyone'),
#  ('cops', 'mamma'),
#  ('cops', 'promotion'),
#  ('cops', 'appoint'),
#  ('cops', 'sphere'),
#  ('cops', 'indignation'),
#  ('cops', 'attributed'),
#  ('cops', 'divide'),
#  ('cops', 'id'),
#  ('cops', 'mixture'),
#  ('cops', 'successful'),
#  ('cops', 'exciting'),
#  ('cops', 'status'),
#  ('cops', 'expanding'),
#  ('cops', 'flat'),
#  ('cops', 'supporting'),
#  ('cops', 'cape'),
#  ('cops', 'ample'),
#  ('cops', 'forests'),
#  ('cops', 'house'),
#  ('cops', 'seat'),
#  ('cops', 'various'),
#  ('cops', 'potential'),
#  ('cops', 'gracious'),
#  ('cops', 'secretary'),
#  ('cops', 'provides'),
#  ('cops', 'drives'),
#  ('cops', 'riches'),
#  ('cops', 'human'),
#  ('cops', 'offended'),
#  ('cops', 'companies'),
#  ('cops', 'toys'),
#  ('cops', 'lacking'),
#  ('cops', 'running'),
#  ('cops', 'advancing'),
#  ('cops', 'february'),
#  ('cops', 'fly'),
#  ('cops', 'naive'),
#  ('cops', 'children'),
#  ('cops', 'heathen'),
#  ('cops', 'pressure'),
#  ('cops', 'truman'),
#  ('cops', 'proportion'),
#  ('cops', 'leisure'),
#  ('cops', 'focused'),
#  ('cops', 'sore'),
#  ('cops', 'hughes'),
#  ('cops', 'consumer'),
#  ('cops', 'whales'),
#  ('cops', 'quite'),
#  ('cops', 'tabernacle'),
#  ('cops', 'belt'),
#  ('cops', 'remove'),
#  ('cops', 'essentially'),
#  ('cops', 'sailed'),
#  ('cops', 'belonging'),
#  ('cops', 'prevail'),
#  ('cops', 'entered'),
#  ('cops', 'soldiers'),
#  ('cops', 'supreme'),
#  ('cops', 'panic'),
#  ('cops', 'follows'),
#  ('cops', 'safely'),
#  ('cops', 'warren'),
#  ('cops', 'duty'),
#  ('cops', 'moral'),
#  ('cops', 'vampire'),
#  ('cops', 'capture'),
#  ('cops', 'inheritance'),
#  ('cops', 'souls'),
#  ('cops', 'longer'),
#  ('cops', 'proof'),
#  ('cops', 'poems'),
#  ('cops', 'lowest'),
#  ('cops', 'keep'),
#  ('cops', 'weather'),
#  ('cops', 'sounds'),
#  ('cops', 'killer'),
#  ('cops', 'hatred'),
#  ('cops', 'heareth'),
#  ('cops', 'belongs'),
#  ('cops', 'levites'),
#  ('cops', 'frequent'),
#  ('cops', 'audience'),
#  ('cops', 'wages'),
#  ('cops', 'particulars'),
#  ('cops', 'hills'),
#  ('cops', 'problem'),
#  ('cops', 'associated'),
#  ('cops', 'inheritance'),
#  ('cops', 'atlanta'),
#  ('cops', 'larger'),
#  ('cops', 'theater'),
#  ('cops', 'immortal'),
#  ('cops', 'wan'),
#  ('cops', 'early'),
#  ('cops', 'investigate'),
#  ('cops', 'holes'),
#  ('cops', 'dropping'),
#  ('cops', 'details'),
#  ('cops', 'boyfriend'),
#  ('cops', 'review'),
#  ('cops', 'consumer'),
#  ('cops', 'consideration'),
#  ('cops', 'chiefly'),
#  ('cops', 'seeking'),
#  ('cops', 'daughters'),
#  ('cops', 'agency'),
#  ('cops', 'broadway'),
#  ('cops', 'consumed'),
#  ('cops', 'dealing'),
#  ('cops', 'wet'),
#  ('cops', 'seed'),
#  ('cops', 'wedding'),
#  ('cops', 'proper'),
#  ('cops', 'extended'),
#  ('cops', 'vampire'),
#  ('cops', 'appearances'),
#  ('cops', 'italian'),
#  ('cops', 'contrary'),
#  ('cops', 'multiply'),
#  ('cops', 'audience'),
#  ('cops', 'student'),
#  ('cops', 'space'),
#  ('cops', 'segment'),
#  ('cops', 'smite'),
#  ('cops', 'september'),
#  ('cops', 'ignored'),
#  ('cops', 'pretend'),
#  ('cops', 'dirt'),
#  ('cops', 'encourage'),
#  ('cops', 'ambitious'),
#  ('cops', 'preached'),
#  ('cops', 'hilarious'),
#  ('cops', 'slowly'),
#  ('cops', 'duvall'),
#  ('cops', 'leg'),
#  ('cops', 'filmed'),
#  ('cops', 'panel'),
#  ('cops', 'personality'),
#  ('cops', 'boldly'),
#  ('cops', 'league'),
#  ('cops', 'arriving'),
#  ('cops', 'gabriel'),
#  ('cops', 'relatively'),
#  ('cops', 'formation'),
#  ('cops', 'significance'),
#  ('cops', 'deadly'),
#  ('cops', 'originality'),
#  ('cops', 'waving'),
#  ('cops', 'shopping'),
#  ('cops', 'chariot'),
#  ('cops', 'comedies'),
#  ('cops', 'form'),
#  ('cops', 'minor'),
#  ('cops', 'lamp'),
#  ('cops', 'centers'),
#  ('cops', 'brilliant'),
#  ('cops', 'sincerity'),
#  ('cops', 'knight'),
#  ('cops', 'scary'),
#  ('cops', 'midnight'),
#  ('cops', 'lost'),
#  ('cops', 'warren'),
#  ('cops', 'sweeping'),
#  ('cops', 'marrying'),
#  ('cops', 'thirst'),
#  ('cops', 'theres'),
#  ('cops', 'cent'),
#  ('cops', 'youth'),
#  ('cops', 'devoted'),
#  ('cops', 'demonstrate'),
#  ('cops', 'write'),
#  ('cops', 'carrying'),
#  ('cops', 'fill'),
#  ('cops', 'lane'),
#  ('cops', 'concrete'),
#  ('cops', 'planning'),
#  ('cops', 'gross'),
#  ('cops', 'horizon'),
#  ('cops', 'extra'),
#  ('cops', 'seen'),
#  ('cops', 'client'),
#  ('cops', 'necessity'),
#  ('cops', 'treasures'),
#  ('cops', 'ladies'),
#  ('cops', 'cruise'),
#  ('cops', 'francisco'),
#  ('cops', 'charity'),
#  ('cops', 'coupled'),
#  ('cops', 'largely'),
#  ('cops', 'moab'),
#  ('cops', 'tom'),
#  ('cops', 'wilson'),
#  ('cops', 'conspiracy'),
#  ('cops', 'directed'),
#  ('cops', 'center'),
#  ('cops', 'quietly'),
#  ('cops', 'churches'),
#  ('cops', 'economic'),
#  ('cops', 'brethren'),
#  ('cops', 'pointed'),
#  ('cops', 'serving'),
#  ('cops', 'worshipped'),
#  ('cops', 'professor'),
#  ('cops', 'acts'),
#  ('cops', 'tedious'),
#  ('cops', 'mixed'),
#  ('cops', 'nixon'),
#  ('cops', 'la'),
#  ('cops', 'assured'),
#  ('cops', 'finest'),
#  ('cops', 'abuse'),
#  ('cops', 'tuesday'),
#  ('cops', 'alice'),
#  ('cops', 'spielberg'),
#  ('cops', 'rachel'),
#  ('cops', 'crowd'),
#  ('cops', 'minute'),
#  ('cops', 'technology'),
#  ('cops', 'findings'),
#  ('cops', 'fiction'),
#  ('cops', 'begin'),
#  ('cops', 'work'),
#  ('cops', 'elijah'),
#  ('cops', 'recall'),
#  ('cops', 'opinion'),
#  ('cops', 'analysis'),
#  ('cops', 'foe'),
#  ('cops', 'usual'),
#  ('cops', 'patterns'),
#  ('cops', 'drive'),
#  ('cops', 'stir'),
#  ('cops', 'accuracy'),
#  ('cops', 'lo'),
#  ('cops', 'solitary'),
#  ('cops', 'kingdoms'),
#  ('cops', 'consequence'),
#  ('cops', 'villain'),
#  ('cops', 'behind'),
#  ('cops', 'causing'),
#  ('cops', 'mississippi'),
#  ('cops', 'turtle'),
#  ('cops', 'widow'),
#  ('cops', 'shouted'),
#  ('cops', 'departments'),
#  ('cops', 'funds'),
#  ('cops', 'consumed'),
#  ('cops', 'wages'),
#  ('cops', 'threw'),
#  ('cops', 'stone'),
#  ('cops', 'fled'),
#  ('cops', 'confirm'),
#  ('cops', 'calif'),
#  ('cops', 'pick'),
#  ('cops', 'infamous'),
#  ('cops', 'sick'),
#  ('cops', 'nails'),
#  ('cops', 'quiet'),
#  ('cops', 'glass'),
#  ('cops', 'domestic'),
#  ('cops', 'state'),
#  ('cops', 'acceptance'),
#  ('cops', 'whither'),
#  ('cops', 'portion'),
#  ('cops', 'derek'),
#  ('cops', 'lloyd'),
#  ('cops', 'atonement'),
#  ('cops', 'experiments'),
#  ('cops', 'post'),
#  ('cops', 'wished'),
#  ('cops', 'levels'),
#  ('cops', 'teaching'),
#  ('cops', 'span'),
#  ('cops', 'suppose'),
#  ('cops', 'fathers'),
#  ('cops', 'personally'),
#  ('cops', 'flowing'),
#  ('cops', 'odd'),
#  ('cops', 'remote'),
#  ('cops', 'pity'),
#  ('cops', 'remotely'),
#  ('cops', 'host'),
#  ('cops', 'asian'),
#  ('cops', 'representative'),
#  ('cops', 'less'),
#  ('cops', 'generic'),
#  ('cops', 'atom'),
#  ('cops', 'young'),
#  ('cops', 'hearted'),
#  ('cops', 'cotton'),
#  ('cops', 'cheer'),
#  ('cops', 'earnings'),
#  ('cops', 'begat'),
#  ('cops', 'achieved'),
#  ('cops', 'bands'),
#  ('cops', 'shed'),
#  ('cops', 'inches'),
#  ('cops', 'substance'),
#  ('cops', 'anti'),
#  ('cops', 'meal'),
#  ('cops', 'centre'),
#  ('cops', 'tis'),
#  ('cops', 'mildly'),
#  ('cops', 'decides'),
#  ('cops', 'dave'),
#  ('cops', 'purse'),
#  ('cops', 'sphere'),
#  ('cops', 'exploration'),
#  ('cops', 'deemed'),
#  ('cops', 'pardon'),
#  ('cops', 'determination'),
#  ('cops', 'rising'),
#  ('cops', 'poetic'),
#  ('cops', 'winner'),
#  ('cops', 'thee'),
#  ('cops', 'scientist'),
#  ('cops', 'barred'),
#  ('cops', 'minds'),
#  ('cops', 'functions'),
#  ('cops', 'experienced'),
#  ('cops', 'rocky'),
#  ('cops', 'recovered'),
#  ('cops', 'knight'),
#  ('cops', 'performers'),
#  ('cops', 'drug'),
#  ('cops', 'likely'),
#  ('cops', 'post'),
#  ('cops', 'strongest'),
#  ('cops', 'small'),
#  ('cops', 'kingdom'),
#  ('cops', 'beasts'),
#  ('cops', 'minute'),
#  ('cops', 'principal'),
#  ('cops', 'earth'),
#  ('cops', 'extreme'),
#  ('cops', 'heir'),
#  ('cops', 'phase'),
#  ('cops', 'aspects'),
#  ('cops', 'stops'),
#  ('cops', 'whatever'),
#  ('cops', 'matt'),
#  ('cops', 'sale'),
#  ('cops', 'january'),
#  ('cops', 'conscious'),
#  ('cops', 'wet'),
#  ('cops', 'combined'),
#  ('cops', 'bit'),
#  ('cops', 'achieved'),
#  ('cops', 'properties'),
#  ('cops', 'washed'),
#  ('cops', 'goddard'),
#  ('cops', 'occurs'),
#  ('cops', 'pillar'),
#  ('cops', 'keeps'),
#  ('cops', 'arthur'),
#  ('cops', 'remainder'),
#  ('cops', 'comrades'),
#  ('cops', 'vincent'),
#  ('cops', 'cable'),
#  ('cops', 'thrills'),
#  ('cops', 'touched'),
#  ('cops', 'lonely'),
#  ('cops', 'assumed'),
#  ('cops', 'seem'),
#  ('cops', 'crew'),
#  ('cops', 'declare'),
#  ('cops', 'swallowed'),
#  ('cops', 'objective'),
#  ('cops', 'inherent'),
#  ('cops', 'funding'),
#  ('cops', 'cry'),
#  ('cops', 'connor'),
#  ('cops', 'meat'),
#  ('cops', 'times'),
#  ('cops', 'astonishing'),
#  ('cops', 'woe'),
#  ('cops', 'treasury'),
#  ('cops', 'likeness'),
#  ('cops', 'concerned'),
#  ('cops', 'persuaded'),
#  ('cops', 'basis'),
#  ('cops', 'distribution'),
#  ('cops', 'chiefly'),
#  ('cops', 'stripped'),
#  ('cops', 'slavery'),
#  ('cops', 'resemblance'),
#  ('cops', 'fare'),
#  ('cops', 'harsh'),
#  ('cops', 'speech'),
#  ('cops', 'integration'),
#  ('cops', 'introduction'),
#  ('cops', 'cost'),
#  ('cops', 'exp'),
#  ('cops', 'satisfaction'),
#  ('cops', 'serve'),
#  ('cops', 'phase'),
#  ('cops', 'pause'),
#  ('cops', 'ann'),
#  ('cops', 'employment'),
#  ('cops', 'sections'),
#  ('cops', 'terror'),
#  ('cops', 'viewed'),
#  ('cops', 'combination'),
#  ('cops', 'tip'),
#  ('cops', 'station'),
#  ('cops', 'lake'),
#  ('cops', 'cleaning'),
#  ('cops', 'whalemen'),
#  ('cops', 'critics'),
#  ('cops', 'general'),
#  ('cops', 'questions'),
#  ('cops', 'dragon'),
#  ('cops', 'embarrassment'),
#  ('cops', 'rate'),
#  ('cops', 'thirty'),
#  ('cops', 'proud'),
#  ('cops', 'honest'),
#  ('cops', 'feature'),
#  ('cops', 'sperm'),
#  ('cops', 'moments'),
#  ('cops', 'staged'),
#  ('cops', 'january'),
#  ('cops', 'speak'),
#  ('cops', 'giant'),
#  ('cops', 'arriving'),
#  ('cops', 'work'),
#  ('cops', 'account'),
#  ('cops', 'happening'),
#  ('cops', 'spawn'),
#  ('cops', 'subsequent'),
#  ('cops', 'newest'),
#  ('cops', 'placed'),
#  ('cops', 'measuring'),
#  ('cops', 'scorsese'),
#  ('cops', 'basket'),
#  ('cops', 'acquired'),
#  ('cops', 'remember'),
#  ('cops', 'height'),
#  ('cops', 'sees'),
#  ('cops', 'didst'),
#  ('cops', 'russell'),
#  ('cops', 'vehicle'),
#  ('cops', 'fever'),
#  ('cops', 'york'),
#  ('cops', 'promising'),
#  ('cops', 'dancer'),
#  ('cops', 'sudden'),
#  ('cops', 'rising'),
#  ('cops', 'defense'),
#  ('cops', 'bought'),
#  ('cops', 'department'),
#  ('cops', 'accomplished'),
#  ('cops', 'outside'),
#  ('cops', 'drove'),
#  ('cops', 'plenty'),
#  ('cops', 'resolution'),
#  ('cops', 'harville'),
#  ('cops', 'appear'),
#  ('cops', 'feeding'),
#  ('cops', 'multiple'),
#  ('cops', 'consequently'),
#  ('cops', 'amazement'),
#  ('cops', 'planned'),
#  ('cops', 'bank'),
#  ('cops', 'interpretation'),
#  ('cops', 'darted'),
#  ('cops', 'expressed'),
#  ('cops', 'ha'),
#  ('cops', 'originally'),
#  ('cops', 'sphere'),
#  ('cops', 'pretend'),
#  ('cops', 'dried'),
#  ('cops', 'ah'),
#  ('cops', 'odd'),
#  ('cops', 'supply'),
#  ('cops', 'porn'),
#  ('cops', 'generous'),
#  ('cops', 'fbi'),
#  ('cops', 'whereof'),
#  ('cops', 'hook'),
#  ('cops', 'seek'),
#  ('cops', 'wisely'),
#  ('cops', 'candy'),
#  ('cops', 'speak'),
#  ('cops', 'nicely'),
#  ('cops', 'frequent'),
#  ('cops', 'advanced'),
#  ('cops', 'pan'),
#  ('cops', 'blew'),
#  ('cops', 'citizen'),
#  ('cops', 'multitude'),
#  ('cops', 'cast'),
#  ('cops', 'covering'),
#  ('cops', 'santa'),
#  ('cops', 'reflected'),
#  ('cops', 'job'),
#  ('cops', 'arrived'),
#  ('cops', 'romantic'),
#  ('cops', 'england'),
#  ('cops', 'spice'),
#  ('cops', 'ministry'),
#  ('cops', 'notable'),
#  ('cops', 'proportion'),
#  ('cops', 'loose'),
#  ('cops', 'assets'),
#  ('cops', 'maintain'),
#  ('cops', 'without'),
#  ('cops', 'constantly'),
#  ('cops', 'af'),
#  ('cops', 'content'),
#  ('cops', 'talent'),
#  ('cops', 'surprisingly'),
#  ('cops', 'definition'),
#  ('cops', 'else'),
#  ('cops', 'approach'),
#  ('cops', 'typical'),
#  ('cops', 'foremost'),
#  ('cops', 'shall'),
#  ('cops', 'moab'),
#  ('cops', 'virgin'),
#  ('cops', 'snare'),
#  ('cops', 'representing'),
#  ('cops', 'existed'),
#  ('cops', 'kept'),
#  ('cops', 'snare'),
#  ('cops', 'vehicle'),
#  ('cops', 'spectacle'),
#  ('cops', 'eliminate'),
#  ('cops', 'treasury'),
#  ('cops', 'singers'),
#  ('cops', 'heat'),
#  ('cops', 'superior'),
#  ('cops', 'filling'),
#  ('cops', 'interference'),
#  ('cops', 'encounter'),
#  ('cops', 'feeding'),
#  ('cops', 'cash'),
#  ('cops', 'mud'),
#  ('cops', 'deaths'),
#  ('cops', 'tokyo'),
#  ('cops', 'drink'),
#  ('cops', 'n'),
#  ('cops', 'secure'),
#  ('cops', 'greek'),
#  ('cops', 'gazing'),
#  ('cops', 'accurately'),
#  ('cops', 'careful'),
#  ('cops', 'dwell'),
#  ('cops', 'sentimental'),
#  ('cops', 'references'),
#  ('cops', 'narration'),
#  ('cops', 'lawyers'),
#  ('cops', 'bursal'),
#  ('cops', 'obsessed'),
#  ('cops', 'disbelief'),
#  ('cops', 'extreme'),
#  ('cops', 'advantage'),
#  ('cops', 'doctrine'),
#  ('cops', 'smite'),
#  ('cops', 'oct'),
#  ('cops', 'foot'),
#  ('cops', 'great'),
#  ('cops', 'chambers'),
#  ('cops', 'affection'),
#  ('cops', 'encounters'),
#  ('cops', 'breakfast'),
#  ('cops', 'raising'),
#  ('cops', 'year'),
#  ('cops', 'succeeds'),
#  ('cops', 'bones'),
#  ('cops', 'revealed'),
#  ('cops', 'barred'),
#  ('cops', 'shakespeare'),
#  ('cops', 'wedding'),
#  ('cops', 'fever'),
#  ('cops', 'attendant'),
#  ('cops', 'acquisition'),
#  ('cops', 'difficulties'),
#  ('cops', 'master'),
#  ('cops', 'suggests'),
#  ('cops', 'advanced'),
#  ('cops', 'selected'),
#  ('cops', 'commandment'),
#  ('cops', 'drama'),
#  ('cops', 'dry'),
#  ('cops', 'afterwards'),
#  ('cops', 'district'),
#  ('cops', 'names'),
#  ('cops', 'vine'),
#  ('cops', 'adequate'),
#  ('cops', 'porter'),
#  ('cops', 'campaign'),
#  ('cops', 'reserve'),
#  ('cops', 'expression'),
#  ('cops', 'giue'),
#  ('cops', 'simply'),
#  ('cops', 'marching'),
#  ('cops', 'cabin'),
#  ('cops', 'everywhere'),
#  ('cops', 'albert'),
#  ('cops', 'purple'),
#  ('cops', 'initial'),
#  ('cops', 'collected'),
#  ('cops', 'motives'),
#  ('cops', 'almost'),
#  ('cops', 'race'),
#  ('cops', 'preach'),
#  ('cops', 'planning'),
#  ('cops', 'satisfied'),
#  ('cops', 'italy'),
#  ('cops', 'grant'),
#  ('cops', 'attention'),
#  ('cops', 'mouth'),
#  ('cops', 'exp'),
#  ('cops', 'process'),
#  ('cops', 'wheeler'),
#  ('cops', 'nonetheless'),
#  ('cops', 'reaction'),
#  ('cops', 'clooney'),
#  ('cops', 'lou'),
#  ('cops', 'equity'),
#  ('cops', 'repeat'),
#  ('cops', 'zedekiah'),
#  ('cops', 'fascinating'),
#  ('cops', 'mm'),
#  ('cops', 'resolve'),
#  ('cops', 'moves'),
#  ('cops', 'mistakes'),
#  ('cops', 'trading'),
#  ('cops', 'network'),
#  ('cops', 'disappeared'),
#  ('cops', 'knowledge'),
#  ('cops', 'obliged'),
#  ('cops', 'irresistible'),
#  ('cops', 'idol'),
#  ('cops', 'canaan'),
#  ('cops', 'endure'),
#  ('cops', 'pace'),
#  ('cops', 'attack'),
#  ('cops', 'gladness'),
#  ('cops', 'virtues'),
#  ('cops', 'judgment'),
#  ('cops', 'fancied'),
#  ('cops', 'acquaintance'),
#  ('cops', 'curve'),
#  ('cops', 'thief'),
#  ('cops', 'producing'),
#  ('cops', 'curiously'),
#  ('cops', 'air'),
#  ('cops', 'basement'),
#  ('cops', 'studies'),
#  ('cops', 'gorgeous'),
#  ('cops', 'colours'),
#  ('cops', 'gags'),
#  ('cops', 'different'),
#  ('cops', 'crash'),
#  ('cops', 'nonetheless'),
#  ('cops', 'shades'),
#  ('cops', 'maker'),
#  ('cops', 'benjamin'),
#  ('cops', 'sticking'),
#  ('cops', 'admired'),
#  ('cops', 'greatly'),
#  ('cops', 'killers'),
#  ('cops', 'political'),
#  ('cops', 'become'),
#  ('cops', 'pregnant'),
#  ('cops', 'custom'),
#  ('cops', 'rough'),
#  ('cops', 'unwilling'),
#  ('cops', 'work'),
#  ('cops', 'laughter'),
#  ('cops', 'behold'),
#  ('cops', 'units'),
#  ('cops', 'priest'),
#  ('cops', 'reminded'),
#  ('cops', 'genuine'),
#  ('cops', 'enthusiasm'),
#  ('cops', 'stomach'),
#  ('cops', 'members'),
#  ('cops', 'degree'),
#  ('cops', 'previous'),
#  ('cops', 'due'),
#  ('cops', 'void'),
#  ('cops', 'delivering'),
#  ('cops', 'obsessed'),
#  ('cops', 'seed'),
#  ('cops', 'leg'),
#  ('cops', 'studied'),
#  ('cops', 'nightingale'),
#  ('cops', 'scarcely'),
#  ('cops', 'hunger'),
#  ('cops', 'pursuing'),
#  ('cops', 'base'),
#  ('cops', 'intense'),
#  ('cops', 'void'),
#  ('cops', 'bliss'),
#  ('cops', 'share'),
#  ('cops', 'curious'),
#  ('cops', 'opinion'),
#  ('cops', 'held'),
#  ('cops', 'unique'),
#  ('cops', 'open'),
#  ('cops', 'recovery'),
#  ('cops', 'cecilia'),
#  ('cops', 'offering'),
#  ('cops', 'value'),
#  ('cops', 'defined'),
#  ('cops', 'suspected'),
#  ('cops', 'rabbit'),
#  ('cops', 'producing'),
#  ('cops', 'magical'),
#  ('cops', 'print'),
#  ('cops', 'destination'),
#  ('cops', 'firstborn'),
#  ('cops', 'encountered'),
#  ('cops', 'starting'),
#  ('cops', 'seth'),
#  ('cops', 'parent'),
#  ('associate', 'dave'),
#  ...]

# %%
cosine_threshold = 0.55

S_emb = []
for words_pair in words_pairs:
  v1 = model.wv[words_pair[0]]
  v2 = model.wv[words_pair[1]]
  cosine_similarity = np.dot(v1,v2) / (norm(v1) * norm(v2))
  if cosine_similarity > cosine_threshold:
    S_emb.append(words_pair)

# %%
S_emb = set(S_emb)
S_emb
# Out:
# {('vpon', 'tis'),
#  ('ltd', 'acquisition'),
#  ('hughes', 'infamous'),
#  ('recovered', 'harville'),
#  ('client', 'funding'),
#  ('passed', 'entered'),
#  ('filmmaking', 'accuracy'),
#  ('divide', 'inheritance'),
#  ('harville', 'leisure'),
#  ('dixon', 'affectionate'),
#  ('ltd', 'units'),
#  ('measuring', 'height'),
#  ('slapstick', 'originality'),
#  ('boyfriend', 'pregnant'),
#  ('boyfriend', 'connor'),
#  ('nov', 'calif'),
#  ('sore', 'zedekiah'),
#  ('expanding', 'consumer'),
#  ('heareth', 'preach'),
#  ('essence', 'aspects'),
#  ('turtle', 'rabbit'),
#  ('regardless', 'purely'),
#  ('knowest', 'didst'),
#  ('multiple', 'defined'),
#  ('knowest', 'snare'),
#  ('frightening', 'remotely'),
#  ('planning', 'defense'),
#  ('creative', 'scorsese'),
#  ('elinor', 'sincerity'),
#  ('flood', 'pestilence'),
#  ('transaction', 'units'),
#  ('infamous', 'derek'),
#  ('significance', 'integration'),
#  ('functions', 'objective'),
#  ('regardless', 'objective'),
#  ('lacking', 'originality'),
#  ('associate', 'student'),
#  ('analysis', 'objective'),
#  ('programs', 'planning'),
#  ('jacket', 'sticking'),
#  ('climactic', 'staged'),
#  ('functions', 'defined'),
#  ('donnell', 'lou'),
#  ('warren', 'barred'),
#  ('hedge', 'shouted'),
#  ('harville', 'wished'),
#  ('secretary', 'funding'),
#  ('exciting', 'remotely'),
#  ('february', 'treasury'),
#  ('inheritance', 'canaan'),
#  ('boyfriend', 'ann'),
#  ('dixon', 'harville'),
#  ('donnell', 'connor'),
#  ('elliot', 'agreeable'),
#  ('shall', 'behold'),
#  ('moab', 'dwell'),
#  ('inheritance', 'levites'),
#  ('monday', 'treasury'),
#  ('pestilence', 'bands'),
#  ('thrills', 'drama'),
#  ('punish', 'pestilence'),
#  ('treasury', 'assets'),
#  ('programs', 'encourage'),
#  ('purely', 'intellectual'),
#  ('flung', 'threw'),
#  ('filmmaking', 'fascinating'),
#  ('funding', 'representing'),
#  ('snare', 'prevail'),
#  ('levites', 'benjamin'),
#  ('surprisingly', 'nonetheless'),
#  ('cheesy', 'exciting'),
#  ('elinor', 'satisfaction'),
#  ('hedge', 'mud'),
#  ('accurate', 'analysis'),
#  ('prevail', 'secure'),
#  ('significance', 'properties'),
#  ('comedies', 'romantic'),
#  ('sprang', 'gazing'),
#  ('systems', 'experiments'),
#  ('ross', 'scott'),
#  ('elinor', 'harville'),
#  ('manasseh', 'brethren'),
#  ('findings', 'studies'),
#  ('dixon', 'elliot'),
#  ('bands', 'snare'),
#  ('enjoyment', 'leisure'),
#  ('thunder', 'chariot'),
#  ('denying', 'findings'),
#  ('advantages', 'necessity'),
#  ('meal', 'meat'),
#  ('dave', 'alicia'),
#  ('daughters', 'canaan'),
#  ('function', 'accuracy'),
#  ('punish', 'heareth'),
#  ('imports', 'treasury'),
#  ('representative', 'funding'),
#  ('elinor', 'affection'),
#  ('eleazar', 'priest'),
#  ('waving', 'shouted'),
#  ('editing', 'staged'),
#  ('compliment', 'lady'),
#  ('companions', 'cecilia'),
#  ('mamma', 'goddard'),
#  ('alicia', 'hoffman'),
#  ('dropping', 'mud'),
#  ('wished', 'fancied'),
#  ('imports', 'representative'),
#  ('formation', 'analysis'),
#  ('smite', 'snare'),
#  ('demonstrate', 'inherent'),
#  ('leisure', 'obliged'),
#  ('barred', 'del'),
#  ('certainty', 'wished'),
#  ('properties', 'adequate'),
#  ('inheritance', 'fathers'),
#  ('vile', 'vpon'),
#  ('snare', 'knowest'),
#  ('manasseh', 'apostles'),
#  ('particulars', 'difficulties'),
#  ('consumed', 'smite'),
#  ('smite', 'consumed'),
#  ('planning', 'departments'),
#  ('butter', 'ate'),
#  ('fled', 'pursuing'),
#  ('concrete', 'basement'),
#  ('cops', 'investigate'),
#  ('transaction', 'earnings'),
#  ('frightening', 'sentimental'),
#  ('donnell', 'knight'),
#  ('sticking', 'stomach'),
#  ('commandment', 'gladness'),
#  ('function', 'inherent'),
#  ('reform', 'objective'),
#  ('astonishment', 'indignation'),
#  ('tuesday', 'february'),
#  ('departments', 'representing'),
#  ('films', 'originality'),
#  ('tuesday', 'tokyo'),
#  ('functions', 'definition'),
#  ('alicia', 'hilarious'),
#  ('hoffman', 'wilson'),
#  ('dixon', 'acquaintance'),
#  ('mud', 'wet'),
#  ('mud', 'sticking'),
#  ('films', 'comedies'),
#  ('moab', 'benjamin'),
#  ('sale', 'equity'),
#  ('would', 'obliged'),
#  ('cloud', 'pillar'),
#  ('shouldest', 'knowest'),
#  ('necessity', 'resolution'),
#  ('ltd', 'earnings'),
#  ('advised', 'goddard'),
#  ('practices', 'encourage'),
#  ('del', 'dave'),
#  ('economic', 'asian'),
#  ('atonement', 'offering'),
#  ('strengthen', 'smite'),
#  ('attended', 'screening'),
#  ('thee', 'didst'),
#  ('encourage', 'determination'),
#  ('sincerity', 'generous'),
#  ('washed', 'dried'),
#  ('gracious', 'declare'),
#  ('persuaded', 'unwilling'),
#  ('hast', 'thee'),
#  ('attributed', 'january'),
#  ('wet', 'dried'),
#  ('pressures', 'encourage'),
#  ('strengthen', 'prevail'),
#  ('function', 'definition'),
#  ('doubted', 'marrying'),
#  ('climactic', 'final'),
#  ('sister', 'dixon'),
#  ('hoffman', 'dave'),
#  ('del', 'barred'),
#  ('creative', 'accurate'),
#  ('growth', 'levels'),
#  ('slapstick', 'gags'),
#  ('heareth', 'snare'),
#  ('asian', 'integration'),
#  ('hoffman', 'winner'),
#  ('frightening', 'thrills'),
#  ('wished', 'goddard'),
#  ('heathen', 'moab'),
#  ('lane', 'calif'),
#  ('hast', 'shouldest'),
#  ('emma', 'elinor'),
#  ('measuring', 'curve'),
#  ('status', 'integration'),
#  ('elinor', 'cecilia'),
#  ('dixon', 'lady'),
#  ('knowest', 'gracious'),
#  ('heareth', 'void'),
#  ('atlanta', 'district'),
#  ('funds', 'treasury'),
#  ('pestilence', 'moab'),
#  ('offended', 'pardon'),
#  ('curtain', 'inches'),
#  ('arriving', 'arrived'),
#  ('hast', 'knowest'),
#  ('pardon', 'giue'),
#  ('inherent', 'integration'),
#  ('aspects', 'inherent'),
#  ('elinor', 'resolution'),
#  ('apostles', 'preached'),
#  ('suspension', 'calif'),
#  ('hatred', 'foe'),
#  ('elinor', 'astonishment'),
#  ('poem', 'poetic'),
#  ('creative', 'focused'),
#  ('assets', 'treasury'),
#  ('seed', 'canaan'),
#  ('demonstrate', 'integration'),
#  ('persuade', 'obliged'),
#  ('generic', 'gags'),
#  ('objective', 'defined'),
#  ('bit', 'nicely'),
#  ('darted', 'rabbit'),
#  ('inheritance', 'firstborn'),
#  ('embarrassment', 'cecilia'),
#  ('scarcely', 'fancied'),
#  ('babylon', 'kingdoms'),
#  ('pestilence', 'snare'),
#  ('personality', 'aspects'),
#  ('dave', 'donnell'),
#  ('emma', 'embarrassment'),
#  ('imports', 'ministry'),
#  ('client', 'lawyers'),
#  ('encourage', 'unwilling'),
#  ('mud', 'ate'),
#  ('tabernacle', 'pillar'),
#  ('hilarious', 'delivering'),
#  ('analysis', 'proportion'),
#  ('exploration', 'defined'),
#  ('ltd', 'planned'),
#  ('sincerity', 'charity'),
#  ('creative', 'essence'),
#  ('transaction', 'acquisition'),
#  ('dave', 'hoffman'),
#  ('divide', 'multiply'),
#  ('mud', 'dropping'),
#  ('accuracy', 'objective'),
#  ('randalls', 'acquaintance'),
#  ('emma', 'randalls'),
#  ('manasseh', 'firstborn'),
#  ('expanding', 'integration'),
#  ('particulars', 'harville'),
#  ('earnings', 'units'),
#  ('assets', 'equity'),
#  ('generic', 'delivering'),
#  ('heareth', 'shall'),
#  ('sale', 'assets'),
#  ('regardless', 'value'),
#  ('gracious', 'preach'),
#  ('nov', 'oct'),
#  ('function', 'distribution'),
#  ('purely', 'filmmaking'),
#  ('functions', 'aspects'),
#  ('levites', 'singers'),
#  ('purely', 'demonstrate'),
#  ('wherewith', 'consumed'),
#  ('colours', 'shades'),
#  ('generic', 'thrills'),
#  ('significance', 'objective'),
#  ('dried', 'vine'),
#  ('construction', 'consumer'),
#  ('light', 'lamp'),
#  ('appoint', 'levites'),
#  ('agreeable', 'persuaded'),
#  ('alicia', 'dave'),
#  ('creative', 'fascinating'),
#  ('compliment', 'affectionate'),
#  ('levites', 'commandment'),
#  ('buster', 'mud'),
#  ('function', 'functions'),
#  ('inheritance', 'dwell'),
#  ('moab', 'smite'),
#  ('investigate', 'fbi'),
#  ('practices', 'sale'),
#  ('heathen', 'kingdoms'),
#  ('opinion', 'motives'),
#  ('alicia', 'infamous'),
#  ('talents', 'talent'),
#  ('elliot', 'emma'),
#  ('persuade', 'persuaded'),
#  ('wished', 'acquaintance'),
#  ('focused', 'inherent'),
#  ('atlanta', 'serving'),
#  ('distribution', 'units'),
#  ('dwell', 'bliss'),
#  ('creative', 'aspects'),
#  ('compliment', 'wished'),
#  ('purse', 'generous'),
#  ('hoffman', 'duvall'),
#  ('leisure', 'harville'),
#  ('whales', 'sperm'),
#  ('donnell', 'alicia'),
#  ('encourage', 'reserve'),
#  ('smite', 'shall'),
#  ('elinor', 'particulars'),
#  ('strengthen', 'doctrine'),
#  ('certainty', 'necessity'),
#  ('pestilence', 'kingdoms'),
#  ('acceptance', 'exploration'),
#  ('persuaded', 'obliged'),
#  ('whalemen', 'sperm'),
#  ('september', 'construction'),
#  ('ice', 'mud'),
#  ('pressures', 'integration'),
#  ('hedge', 'drove'),
#  ('pressures', 'expanding'),
#  ('realistic', 'combined'),
#  ('assets', 'cash'),
#  ('sore', 'moab'),
#  ('institution', 'funding'),
#  ('ross', 'fbi'),
#  ('magnitude', 'distribution'),
#  ('snare', 'hunger'),
#  ('february', 'oct'),
#  ('therein', 'dwell'),
#  ('elliot', 'acquaintance'),
#  ('accurate', 'accuracy'),
#  ('alice', 'turtle'),
#  ('properties', 'phase'),
#  ('properties', 'units'),
#  ('planning', 'eliminate'),
#  ('manasseh', 'children'),
#  ('associate', 'albert'),
#  ('difficulties', 'resolve'),
#  ('experiments', 'phase'),
#  ('pestilence', 'whither'),
#  ('compliment', 'admired'),
#  ('phase', 'reaction'),
#  ('boyfriend', 'derek'),
#  ('cruise', 'tom'),
#  ('associate', 'studied'),
#  ('gloom', 'cloud'),
#  ('broadway', 'newest'),
#  ('riches', 'treasures'),
#  ('shouted', 'amazement'),
#  ('scott', 'matt'),
#  ('smite', 'zedekiah'),
#  ('client', 'fbi'),
#  ('mud', 'ice'),
#  ('purely', 'suggests'),
#  ('thrills', 'gags'),
#  ('pestilence', 'beasts'),
#  ('manasseh', 'benjamin'),
#  ('definition', 'defined'),
#  ('sprang', 'shouted'),
#  ('satisfaction', 'acquaintance'),
#  ('analysis', 'patterns'),
#  ('infamous', 'dave'),
#  ('status', 'focused'),
#  ('hoffman', 'lloyd'),
#  ('eleazar', 'moab'),
#  ('transaction', 'funding'),
#  ('accuracy', 'definition'),
#  ('dave', 'porter'),
#  ('originality', 'accuracy'),
#  ('wherewith', 'commandment'),
#  ('particulars', 'necessity'),
#  ('quaid', 'fbi'),
#  ('necessity', 'secure'),
#  ('moab', 'kingdoms'),
#  ('ltd', 'sale'),
#  ('bursal', 'wheeler'),
#  ('calif', 'barred'),
#  ('void', 'bliss'),
#  ('practices', 'assets'),
#  ('marrying', 'persuaded'),
#  ('leisure', 'wished'),
#  ('appoint', 'heareth'),
#  ('propaganda', 'moscow'),
#  ('quaid', 'dave'),
#  ('whales', 'whalemen'),
#  ('ice', 'lake'),
#  ('associated', 'viewed'),
#  ('wished', 'harville'),
#  ('knight', 'connor'),
#  ('flung', 'darted'),
#  ('emma', 'wished'),
#  ('emma', 'would'),
#  ('accurate', 'purely'),
#  ('originality', 'mildly'),
#  ('cheesy', 'scary'),
#  ('pressures', 'formation'),
#  ('twists', 'tedious'),
#  ('knowest', 'thee'),
#  ('sale', 'units'),
#  ('canaan', 'firstborn'),
#  ('persuaded', 'acquaintance'),
#  ('affectionate', 'sincerity'),
#  ('scott', 'dave'),
#  ('panel', 'departments'),
#  ('therein', 'heathen'),
#  ('departments', 'planning'),
#  ('consumer', 'assets'),
#  ('practices', 'reserve'),
#  ('snare', 'consumed'),
#  ('emma', 'acquaintance'),
#  ('elinor', 'goddard'),
#  ('attributed', 'consumer'),
#  ('children', 'fathers'),
#  ('poem', 'poems'),
#  ('moab', 'fled'),
#  ('hoffman', 'matt'),
#  ('digital', 'editing'),
#  ('levites', 'brethren'),
#  ('infamous', 'matt'),
#  ('exploration', 'eliminate'),
#  ('basket', 'pan'),
#  ('hedge', 'waving'),
#  ('management', 'eliminate'),
#  ('recovery', 'resolution'),
#  ('hughes', 'albert'),
#  ('funding', 'department'),
#  ('sprang', 'darted'),
#  ('fathers', 'canaan'),
#  ('amazement', 'gazing'),
#  ('dried', 'dry'),
#  ('editing', 'digital'),
#  ('randalls', 'leisure'),
#  ('defense', 'lawyers'),
#  ('originality', 'generic'),
#  ('tuesday', 'oct'),
#  ('frightening', 'spectacle'),
#  ('wilson', 'albert'),
#  ('purely', 'fascinating'),
#  ('inheritance', 'portion'),
#  ('associated', 'inherent'),
#  ('consumer', 'earnings'),
#  ('moab', 'bands'),
#  ('affection', 'cecilia'),
#  ('dealing', 'motives'),
#  ('monday', 'tuesday'),
#  ('dave', 'scott'),
#  ('finest', 'astonishing'),
#  ('whither', 'canaan'),
#  ('kingdoms', 'moab'),
#  ('departments', 'defense'),
#  ('experiments', 'properties'),
#  ('doctrine', 'knowledge'),
#  ('frightening', 'scary'),
#  ('funding', 'eliminate'),
#  ('elinor', 'wished'),
#  ('filmmaking', 'fiction'),
#  ('essence', 'fascinating'),
#  ('ltd', 'construction'),
#  ('significance', 'accuracy'),
#  ('chariot', 'pillar'),
#  ('sore', 'fled'),
#  ('encourage', 'eliminate'),
#  ('earnings', 'assets'),
#  ('exploration', 'aspects'),
#  ('agreeable', 'acquaintance'),
#  ('levites', 'inheritance'),
#  ('essence', 'poetic'),
#  ('exalted', 'kingdoms'),
#  ('ate', 'meal'),
#  ('shopping', 'santa'),
#  ('departments', 'employment'),
#  ('temper', 'affection'),
#  ('filmmaking', 'originality'),
#  ('elliot', 'randalls'),
#  ('orange', 'cotton'),
#  ('personally', 'motives'),
#  ('dixon', 'elinor'),
#  ('function', 'objective'),
#  ('programs', 'demonstrate'),
#  ('strengthen', 'wages'),
#  ('vile', 'giue'),
#  ('particulars', 'wished'),
#  ('infamous', 'albert'),
#  ('elliot', 'lady'),
#  ('experiments', 'sections'),
#  ('slapstick', 'mildly'),
#  ('aspects', 'defined'),
#  ('management', 'consumer'),
#  ('thankfully', 'nicely'),
#  ('manasseh', 'canaan'),
#  ('court', 'supreme'),
#  ('dixon', 'goddard'),
#  ('yeargin', 'teaching'),
#  ('assets', 'units'),
#  ('funding', 'lawyers'),
#  ('purely', 'ultimately'),
#  ('experiment', 'properties'),
#  ('sincerity', 'embarrassment'),
#  ('heir', 'firstborn'),
#  ('wounded', 'fled'),
#  ('funding', 'equity'),
#  ('realistic', 'frightening'),
#  ('construction', 'units'),
#  ('shouldest', 'smite'),
#  ('status', 'inherent'),
#  ('punish', 'strengthen'),
#  ('formation', 'eliminate'),
#  ('demonstrate', 'objective'),
#  ('strengthen', 'ministry'),
#  ('monday', 'february'),
#  ('remotely', 'thrills'),
#  ('punish', 'appoint'),
#  ('compliment', 'embarrassment'),
#  ('mildly', 'gags'),
#  ('distribution', 'cost'),
#  ('warren', 'calif'),
#  ('manasseh', 'fathers'),
#  ('necessity', 'satisfaction'),
#  ('dave', 'connor'),
#  ('significance', 'aspects'),
#  ('naive', 'personality'),
#  ('donnell', 'dave'),
#  ('monday', 'january'),
#  ('assets', 'acquisition'),
#  ('donnell', 'scott'),
#  ('reform', 'integration'),
#  ('crap', 'disbelief'),
#  ('properties', 'objective'),
#  ('objective', 'integration'),
#  ('tide', 'forests'),
#  ('barred', 'suspension'),
#  ('elinor', 'necessity'),
#  ('span', 'inches'),
#  ('whalemen', 'encountered'),
#  ('alicia', 'clooney'),
#  ('keep', 'kept'),
#  ('randalls', 'persuaded'),
#  ('sprang', 'waving'),
#  ('properties', 'sections'),
#  ('dave', 'nicholson'),
#  ('reform', 'demonstrate'),
#  ('vine', 'dried'),
#  ('accuracy', 'distribution'),
#  ('strengthen', 'appoint'),
#  ('elinor', 'obliged'),
#  ('sprang', 'threw'),
#  ('rarely', 'nonetheless'),
#  ('butter', 'meal'),
#  ('bye', 'cheer'),
#  ('eleazar', 'children'),
#  ('determination', 'resolve'),
#  ('purple', 'gorgeous'),
#  ('programs', 'employment'),
#  ('discovers', 'vincent'),
#  ('elinor', 'difficulties'),
#  ('rarely', 'genuine'),
#  ('safely', 'wished'),
#  ('sentimental', 'genuine'),
#  ('lloyd', 'albert'),
#  ('alicia', 'mildly'),
#  ('systems', 'properties'),
#  ('scott', 'warren'),
#  ('donnell', 'matt'),
#  ('donnell', 'supporting'),
#  ('jokes', 'comedies'),
#  ('mud', 'dirt'),
#  ('sale', 'planned'),
#  ('programs', 'funding'),
#  ('flung', 'waving'),
#  ('multiply', 'dwell'),
#  ('obliged', 'unwilling'),
#  ('practices', 'equity'),
#  ('tabernacle', 'covering'),
#  ('necessity', 'difficulties'),
#  ('analysis', 'properties'),
#  ('pestilence', 'smite'),
#  ('marrying', 'affection'),
#  ('accuracy', 'measuring'),
#  ('ltd', 'companies'),
#  ('answering', 'boldly'),
#  ('scott', 'lloyd'),
#  ('smite', 'moab'),
#  ('purely', 'exploration'),
#  ('cheesy', 'staged'),
#  ('crap', 'mildly'),
#  ('analysis', 'defined'),
#  ('pressures', 'eliminate'),
#  ('sprang', 'amazement'),
#  ('fascinating', 'unique'),
#  ('creative', 'succeeds'),
#  ('boyfriend', 'wilson'),
#  ('sore', 'smite'),
#  ('quaid', 'boyfriend'),
#  ('pestilence', 'sore'),
#  ('preached', 'declare'),
#  ('objective', 'funding'),
#  ('dixon', 'persuaded'),
#  ('reform', 'encourage'),
#  ('fancied', 'scarcely'),
#  ('randalls', 'afterwards'),
#  ('slapstick', 'hilarious'),
#  ('associated', 'distribution'),
#  ('kingdoms', 'bands'),
#  ('calif', 'oct'),
#  ('cops', 'fbi'),
#  ('vile', 'heareth'),
#  ('sister', 'mamma'),
#  ('transaction', 'assets'),
#  ('democracy', 'doctrine'),
#  ('shouldest', 'didst'),
#  ('patterns', 'properties'),
#  ('lady', 'russell'),
#  ('gazing', 'laughter'),
#  ('heathen', 'whither'),
#  ('zedekiah', 'benjamin'),
#  ('transaction', 'sale'),
#  ('properties', 'selected'),
#  ('nicholson', 'dave'),
#  ('gracious', 'boldly'),
#  ('february', 'january'),
#  ('secure', 'bliss'),
#  ('dixon', 'compliment'),
#  ('punish', 'smite'),
#  ('pressures', 'objective'),
#  ('barred', 'warren'),
#  ('slapstick', 'generic'),
#  ('boyfriend', 'lou'),
#  ('expanding', 'studies'),
#  ('multiply', 'multitude'),
#  ('randalls', 'satisfied'),
#  ('boyfriend', 'knight'),
#  ('personality', 'magical'),
#  ('canaan', 'benjamin'),
#  ('children', 'canaan'),
#  ('editing', 'mm'),
#  ('gracious', 'heareth'),
#  ('children', 'benjamin'),
#  ('management', 'expanding'),
#  ('heathen', 'preached'),
#  ('encourage', 'objective'),
#  ('cheesy', 'generic'),
#  ('snare', 'heareth'),
#  ('funds', 'assets'),
#  ('shall', 'dwell'),
#  ('consumed', 'snare'),
#  ('asian', 'tokyo'),
#  ('gloom', 'gazing'),
#  ('gifts', 'atonement'),
#  ('poem', 'shakespeare'),
#  ('elinor', 'embarrassment'),
#  ('digital', 'filmed'),
#  ('transaction', 'eliminate'),
#  ('fathers', 'commandment'),
#  ('elinor', 'recovered'),
#  ('encourage', 'demonstrate'),
#  ('wished', 'obliged'),
#  ('romantic', 'drama'),
#  ('shopping', 'cleaning'),
#  ('moscow', 'nixon'),
#  ('irresistible', 'magical'),
#  ('compliment', 'opinion'),
#  ('connor', 'clooney'),
#  ('september', 'oct'),
#  ('generic', 'sentimental'),
#  ('goddard', 'afterwards'),
#  ('babylon', 'zedekiah'),
#  ('atonement', 'meat'),
#  ('demonstrate', 'eliminate'),
#  ('mud', 'hedge'),
#  ('discovers', 'boyfriend'),
#  ('kingdoms', 'whither'),
#  ('attributed', 'reserve'),
#  ('programs', 'practices'),
#  ('crap', 'generic'),
#  ('february', 'tuesday'),
#  ('objective', 'distribution'),
#  ('personality', 'inherent'),
#  ('dwell', 'canaan'),
#  ('construction', 'september'),
#  ('comedies', 'gags'),
#  ('departments', 'eliminate'),
#  ('defense', 'planning'),
#  ('connor', 'thief'),
#  ('nov', 'monday'),
#  ('gracious', 'offended'),
#  ('patterns', 'integration'),
#  ('purely', 'unique'),
#  ('essence', 'inherent'),
#  ('atlanta', 'lawyers'),
#  ('hoffman', 'warren'),
#  ('astonishment', 'recovered'),
#  ('snare', 'pestilence'),
#  ('twists', 'thrills'),
#  ('exciting', 'staged'),
#  ('departments', 'reserve'),
#  ('snare', 'smite'),
#  ('nov', 'tuesday'),
#  ('phase', 'properties'),
#  ('ltd', 'transaction'),
#  ('eleazar', 'brethren'),
#  ('dirt', 'mud'),
#  ('atonement', 'gladness'),
#  ('creative', 'exploration'),
#  ('begat', 'eleazar'),
#  ('motives', 'opinion'),
#  ('conscious', 'expression'),
#  ('brilliant', 'astonishing'),
#  ('systems', 'distribution'),
#  ('aspects', 'fascinating'),
#  ('pressures', 'consumer'),
#  ('worshipped', 'idol'),
#  ('pressures', 'pressure'),
#  ('gloom', 'spectacle'),
#  ('function', 'properties'),
#  ('formation', 'expanding'),
#  ('alice', 'rabbit'),
#  ('elinor', 'persuaded'),
#  ('cheesy', 'frightening'),
#  ('pressures', 'reform'),
#  ('compliment', 'generous'),
#  ('advantages', 'practices'),
#  ('sister', 'affectionate'),
#  ('shouldest', 'whither'),
#  ('matt', 'albert'),
#  ('punish', 'moab'),
#  ('mildly', 'thrills'),
#  ('advantages', 'objective'),
#  ('demonstrate', 'exploration'),
#  ('tide', 'lake'),
#  ('purely', 'analysis'),
#  ('brethren', 'fathers'),
#  ('dave', 'hilarious'),
#  ('shouldest', 'snare'),
#  ('function', 'defined'),
#  ('randalls', 'necessity'),
#  ('aspects', 'definition'),
#  ('vile', 'atonement'),
#  ('randalls', 'elinor'),
#  ('mamma', 'harville'),
#  ('accuracy', 'mm'),
#  ('dave', 'quaid'),
#  ('forests', 'mississippi'),
#  ('boyfriend', 'wedding'),
#  ('systems', 'objective'),
#  ('exciting', 'originality'),
#  ('depths', 'flowing'),
#  ('canaan', 'seed'),
#  ('gracious', 'giue'),
#  ('determination', 'interference'),
#  ('emma', 'obliged'),
#  ('reed', 'chambers'),
#  ('lo', 'behold'),
#  ('nicholson', 'clooney'),
#  ('departments', 'department'),
#  ('snare', 'strengthen'),
#  ('accuracy', 'properties'),
#  ('cry', 'moab'),
#  ('certainty', 'difficulties'),
#  ('pattern', 'patterns'),
#  ('pregnant', 'boyfriend'),
#  ('atlanta', 'departments'),
#  ('butter', 'dried'),
#  ('wilson', 'lou'),
#  ('inherent', 'resolve'),
#  ('verse', 'poem'),
#  ('pestilence', 'thirst'),
#  ('sale', 'acquired'),
#  ('goddard', 'obliged'),
#  ('emma', 'agreeable'),
#  ('bands', 'moab'),
#  ('significance', 'inherent'),
#  ('cash', 'equity'),
#  ('dave', 'lou'),
#  ('elinor', 'amazement'),
#  ('practices', 'departments'),
#  ('shall', 'smite'),
#  ('alicia', 'boyfriend'),
#  ('warren', 'lloyd'),
#  ('seed', 'multiply'),
#  ('particulars', 'obliged'),
#  ('purely', 'essence'),
#  ('worshipped', 'pillar'),
#  ('tis', 'giue'),
#  ('moral', 'inherent'),
#  ('democracy', 'objective'),
#  ('complain', 'mamma'),
#  ('intellectual', 'status'),
#  ('practices', 'management'),
#  ('warren', 'wilson'),
#  ('atlanta', 'investigate'),
#  ('pardon', 'declare'),
#  ('determination', 'recovery'),
#  ('waving', 'gazing'),
#  ('barred', 'calif'),
#  ('boogie', 'notable'),
#  ('therein', 'kingdoms'),
#  ('crap', 'thrills'),
#  ('eleazar', 'canaan'),
#  ('lady', 'acquaintance'),
#  ('supporting', 'performers'),
#  ('determination', 'objective'),
#  ('technology', 'exploration'),
#  ('harville', 'particulars'),
#  ('punish', 'preached'),
#  ('randalls', 'wished'),
#  ('thrills', 'moments'),
#  ('pestilence', 'heareth'),
#  ('programs', 'pressures'),
#  ('systems', 'units'),
#  ('quaid', 'porter'),
#  ('frightening', 'magical'),
#  ('grateful', 'indignation'),
#  ('moab', 'canaan'),
#  ('marrying', 'motives'),
#  ('generic', 'nicely'),
#  ('astonishment', 'amazement'),
#  ('shouted', 'gazing'),
#  ('pressures', 'economic'),
#  ('creative', 'purely'),
#  ('wherewith', 'heareth'),
#  ('purely', 'accuracy'),
#  ('would', 'wished'),
#  ('practices', 'funding'),
#  ('eleazar', 'begat'),
#  ('segment', 'earnings'),
#  ('programs', 'departments'),
#  ('editing', 'filmed'),
#  ('departments', 'lawyers'),
#  ('ltd', 'assets'),
#  ('manasseh', 'inheritance'),
#  ('findings', 'funding'),
#  ('donnell', 'nicholson'),
#  ('pestilence', 'hunger'),
#  ('sincerity', 'affection'),
#  ('flung', 'gazing'),
#  ('offended', 'recovered'),
#  ('inherent', 'defined'),
#  ('magnitude', 'units'),
#  ('randalls', 'particulars'),
#  ('spielberg', 'scorsese'),
#  ('objective', 'inherent'),
#  ('programs', 'eliminate'),
#  ('analysis', 'definition'),
#  ('pestilence', 'appoint'),
#  ('frightening', 'mildly'),
#  ('determination', 'inherent'),
#  ('demonstrate', 'defined'),
#  ('programs', 'reform'),
#  ('properties', 'distribution'),
#  ('compliment', 'agreeable'),
#  ('exploration', 'objective'),
#  ('calif', 'principal'),
#  ('randalls', 'goddard'),
#  ('transaction', 'reserve'),
#  ('wherewith', 'snare'),
#  ('recall', 'encountered'),
#  ('cheesy', 'thrills'),
#  ('abilities', 'supporting'),
#  ('purely', 'objective'),
#  ('crap', 'villain'),
#  ('forty', 'thirty'),
#  ('manasseh', 'zedekiah'),
#  ('february', 'september'),
#  ('originality', 'thrills'),
#  ('hoffman', 'infamous'),
#  ('pestilence', 'consumed'),
#  ('originality', 'nonetheless'),
#  ('punish', 'kingdoms'),
#  ('associated', 'defined'),
#  ('moral', 'political'),
#  ('sincerity', 'cecilia'),
#  ('objective', 'eliminate'),
#  ('purely', 'defined'),
#  ('surprisingly', 'delivering'),
#  ('particulars', 'persuaded'),
#  ('reed', 'measuring'),
#  ('dave', 'infamous'),
#  ('representing', 'selected'),
#  ('verse', 'poems'),
#  ('ate', 'mud'),
#  ('naive', 'motives'),
#  ('hoffman', 'scott'),
#  ('boyfriend', 'porter'),
#  ('exciting', 'scary'),
#  ('proportion', 'analysis'),
#  ('wet', 'mud'),
#  ('vile', 'snare'),
#  ('phase', 'initial'),
#  ('purely', 'inherent'),
#  ('harville', 'recovered'),
#  ('climactic', 'anti'),
#  ('snare', 'shouldest'),
#  ('sprang', 'dropping'),
#  ('vpon', 'giue'),
#  ('advantages', 'consideration'),
#  ('jacket', 'orange'),
#  ('function', 'af'),
#  ('elinor', 'acquaintance'),
#  ('companions', 'harville'),
#  ('inches', 'measuring'),
#  ('exploration', 'inherent'),
#  ('randalls', 'difficulties'),
#  ('alicia', 'derek'),
#  ('programs', 'funds'),
#  ('provides', 'functions'),
#  ('revolves', 'centers'),
#  ('distribution', 'assets'),
#  ('shouted', 'blew'),
#  ('yeargin', 'reform'),
#  ('formation', 'phase'),
#  ('significance', 'exploration'),
#  ('hilarious', 'mildly'),
#  ('shouldest', 'heathen'),
#  ('properties', 'defined'),
#  ('manasseh', 'moab'),
#  ('inherent', 'definition'),
#  ('indignation', 'gracious'),
#  ('programs', 'reserve'),
#  ('mamma', 'generous'),
#  ('nov', 'acquisition'),
#  ('basis', 'defined'),
#  ('harsh', 'intense'),
#  ('purple', 'colours'),
#  ('randalls', 'astonishment'),
#  ('pressures', 'determination'),
#  ('democracy', 'virtues'),
#  ('dixon', 'marrying'),
#  ('dave', 'clooney'),
#  ('earnings', 'share'),
#  ('elinor', 'satisfied'),
#  ('apostles', 'eleazar'),
#  ('shouted', 'darted'),
#  ('ross', 'wilson'),
#  ('dixon', 'agreeable'),
#  ('protestant', 'churches'),
#  ('exalted', 'heathen'),
#  ('ross', 'investigate'),
#  ('associated', 'multiple'),
#  ('thankfully', 'remotely'),
#  ('pestilence', 'woe'),
#  ('tabernacle', 'levites'),
#  ('heareth', 'atonement'),
#  ('generic', 'mildly'),
#  ('moscow', 'representative'),
#  ('doctrine', 'preach'),
#  ('consideration', 'consequence'),
#  ('certainty', 'interference'),
#  ('prevail', 'snare'),
#  ('attributed', 'earnings'),
#  ('moab', 'cry'),
#  ('slapstick', 'thrills'),
#  ('heareth', 'woe'),
#  ('boyfriend', 'dave'),
#  ('quaid', 'connor'),
#  ('calif', 'santa'),
#  ('nov', 'february'),
#  ('apostles', 'commandment'),
#  ('forests', 'flowing'),
#  ('enjoyment', 'embarrassment'),
#  ('anticipation', 'depression'),
#  ('wherewith', 'shouldest'),
#  ('therein', 'pestilence'),
#  ('intellectual', 'moral'),
#  ('exciting', 'tedious'),
#  ('acquired', 'acquisition'),
#  ('fbi', 'lawyers'),
#  ('dixon', 'suspected'),
#  ('waving', 'darted'),
#  ('advantages', 'difficulties'),
#  ('agreeable', 'sincerity'),
#  ('status', 'asian'),
#  ('soldiers', 'comrades'),
#  ('departments', 'funding'),
#  ('wherewith', 'atonement'),
#  ('meat', 'offering'),
#  ('children', 'inheritance'),
#  ('emma', 'goddard'),
#  ('programs', 'basis'),
#  ('nicholson', 'villain'),
#  ('analysis', 'aspects'),
#  ('properties', 'eliminate'),
#  ('remotely', 'mildly'),
#  ('pestilence', 'bliss'),
#  ('exciting', 'thrills'),
#  ('harville', 'goddard'),
#  ('personality', 'defined'),
#  ('moab', 'zedekiah'),
#  ('acquisition', 'equity'),
#  ('jokes', 'slapstick'),
#  ('scott', 'albert'),
#  ('dave', 'boyfriend'),
#  ('orange', 'purple'),
#  ('eleazar', 'firstborn'),
#  ('tabernacle', 'atonement'),
#  ('twists', 'holes'),
#  ('slapstick', 'mixture'),
#  ('employment', 'reserve'),
#  ('essence', 'magical'),
#  ('eliminate', 'units'),
#  ('harville', 'obliged'),
#  ('wished', 'persuaded'),
#  ('wished', 'satisfied'),
#  ('objective', 'interference'),
#  ('daughters', 'brethren'),
#  ('af', 'curve'),
#  ('punish', 'snare'),
#  ('thankfully', 'twists'),
#  ('remotely', 'magical'),
#  ...}

# %%
S_wn = []
for words_pair in words_pairs:
  lemma_w1 = lemmatizer.lemmatize(words_pair[0])
  lemma_w2 = lemmatizer.lemmatize(words_pair[1])
  synsets_w1 = set(wn.synsets(lemma_w1)) 
  synsets_w2 = set(wn.synsets(lemma_w2))
  if synsets_w1.intersection(synsets_w2):
    S_wn.append(words_pair)

# %%
S_wn = set(S_wn)
S_wn
# Out:
# {('abuse', 'shouted'),
#  ('achieved', 'accomplished'),
#  ('acquired', 'producing'),
#  ('acts', 'bit'),
#  ('acts', 'moves'),
#  ('acts', 'pretend'),
#  ('acts', 'representing'),
#  ('acts', 'work'),
#  ('advanced', 'raising'),
#  ('advancing', 'advanced'),
#  ('advancing', 'encourage'),
#  ('advancing', 'raising'),
#  ('advantages', 'advantage'),
#  ('advised', 'suggests'),
#  ('allowed', 'grant'),
#  ('allowed', 'provides'),
#  ('allowed', 'reserve'),
#  ('always', 'constantly'),
#  ('ample', 'riches'),
#  ('answering', 'resolve'),
#  ('answering', 'serve'),
#  ('answering', 'serving'),
#  ('appoint', 'names'),
#  ('approach', 'attack'),
#  ('arriving', 'arrived'),
#  ('aspects', 'expression'),
#  ('associate', 'associated'),
#  ('associate', 'associates'),
#  ('associate', 'companions'),
#  ('associate', 'comrades'),
#  ('associate', 'familiar'),
#  ('associates', 'associated'),
#  ('associates', 'comrades'),
#  ('assumed', 'acquired'),
#  ('assured', 'promising'),
#  ('assured', 'secure'),
#  ('assured', 'sees'),
#  ('astonishment', 'amazement'),
#  ('ate', 'consumed'),
#  ('ate', 'feeding'),
#  ('atonement', 'satisfaction'),
#  ('attack', 'approach'),
#  ('attended', 'seen'),
#  ('attended', 'sees'),
#  ('attended', 'serve'),
#  ('attended', 'serving'),
#  ('barred', 'stops'),
#  ('basis', 'base'),
#  ('begat', 'fathers'),
#  ('begin', 'starting'),
#  ('belonging', 'belongs'),
#  ('best', 'honest'),
#  ('best', 'secure'),
#  ('best', 'sounds'),
#  ('best', 'well'),
#  ('bit', 'moments'),
#  ('borne', 'assumed'),
#  ('borne', 'carrying'),
#  ('borne', 'delivering'),
#  ('borne', 'endure'),
#  ('borne', 'held'),
#  ('borne', 'stomach'),
#  ('borne', 'supporting'),
#  ('brethren', 'comrades'),
#  ('calm', 'quiet'),
#  ('capture', 'fascinating'),
#  ('carrying', 'expressed'),
#  ('carrying', 'held'),
#  ('carrying', 'persuaded'),
#  ('carrying', 'post'),
#  ('caused', 'causes'),
#  ('caused', 'causing'),
#  ('causes', 'campaign'),
#  ('causes', 'causing'),
#  ('causes', 'drive'),
#  ('causes', 'drives'),
#  ('center', 'centre'),
#  ('center', 'meat'),
#  ('center', 'substance'),
#  ('centers', 'center'),
#  ('centers', 'centre'),
#  ('centers', 'meat'),
#  ('centers', 'substance'),
#  ('centre', 'meat'),
#  ('check', 'assured'),
#  ('check', 'held'),
#  ('check', 'seen'),
#  ('check', 'sees'),
#  ('check', 'stops'),
#  ('children', 'minor'),
#  ('choices', 'pick'),
#  ('clear', 'earnings'),
#  ('clear', 'open'),
#  ('clear', 'passing'),
#  ('companions', 'associates'),
#  ('companions', 'companies'),
#  ('companions', 'comrades'),
#  ('conceive', 'consider'),
#  ('conceive', 'thinking'),
#  ('consequence', 'moments'),
#  ('consider', 'dealing'),
#  ('consider', 'dealt'),
#  ('consider', 'seen'),
#  ('consider', 'sees'),
#  ('consider', 'studied'),
#  ('consider', 'studies'),
#  ('consider', 'thinking'),
#  ('consider', 'viewed'),
#  ('construction', 'expression'),
#  ('construction', 'twists'),
#  ('cops', 'hook'),
#  ('cops', 'nails'),
#  ('crap', 'dirt'),
#  ('crowd', 'crew'),
#  ('dealing', 'covering'),
#  ('dealing', 'share'),
#  ('dealing', 'trading'),
#  ('dealt', 'covering'),
#  ('dealt', 'dealing'),
#  ('dealt', 'share'),
#  ('dealt', 'trading'),
#  ('decides', 'resolve'),
#  ('declare', 'held'),
#  ('deed', 'acts'),
#  ('deemed', 'held'),
#  ('demonstrate', 'marching'),
#  ('departments', 'department'),
#  ('departments', 'sections'),
#  ('device', 'twists'),
#  ('directed', 'placed'),
#  ('directed', 'pointed'),
#  ('discovers', 'findings'),
#  ('discovers', 'names'),
#  ('discovers', 'revealed'),
#  ('discovers', 'seen'),
#  ('discovers', 'sees'),
#  ('dried', 'dry'),
#  ('drive', 'campaign'),
#  ('drive', 'drove'),
#  ('drives', 'campaign'),
#  ('drives', 'drive'),
#  ('drives', 'drove'),
#  ('dropped', 'cast'),
#  ('dropped', 'dropping'),
#  ('dropped', 'shed'),
#  ('dropped', 'threw'),
#  ('dropping', 'cast'),
#  ('dropping', 'shed'),
#  ('dropping', 'threw'),
#  ('effect', 'consequence'),
#  ('effect', 'essence'),
#  ('effect', 'event'),
#  ('employment', 'work'),
#  ('encounter', 'encountered'),
#  ('encounter', 'encounters'),
#  ('encounters', 'encountered'),
#  ('encourage', 'advanced'),
#  ('endure', 'stomach'),
#  ('essence', 'center'),
#  ('essence', 'centers'),
#  ('essence', 'centre'),
#  ('essence', 'meat'),
#  ('essence', 'substance'),
#  ('evening', 'levels'),
#  ('event', 'consequence'),
#  ('exalted', 'thrills'),
#  ('exciting', 'stir'),
#  ('expanding', 'extended'),
#  ('experienced', 'sees'),
#  ('experiment', 'experiments'),
#  ('extended', 'carrying'),
#  ('extended', 'covering'),
#  ('extended', 'offering'),
#  ('familiar', 'associates'),
#  ('familiar', 'companions'),
#  ('familiar', 'comrades'),
#  ('family', 'house'),
#  ('fathers', 'begat'),
#  ('feeling', 'experienced'),
#  ('feeling', 'find'),
#  ('feeling', 'findings'),
#  ('feeling', 'opinion'),
#  ('fill', 'filling'),
#  ('fill', 'satisfied'),
#  ('filled', 'fill'),
#  ('filled', 'filling'),
#  ('filled', 'satisfied'),
#  ('filling', 'satisfied'),
#  ('films', 'filmed'),
#  ('find', 'discovers'),
#  ('find', 'encounter'),
#  ('find', 'encountered'),
#  ('find', 'encounters'),
#  ('find', 'findings'),
#  ('find', 'happening'),
#  ('find', 'recovered'),
#  ('find', 'seen'),
#  ('find', 'sees'),
#  ('findings', 'determination'),
#  ('findings', 'encounter'),
#  ('findings', 'encountered'),
#  ('findings', 'encounters'),
#  ('findings', 'happening'),
#  ('findings', 'recovered'),
#  ('findings', 'sees'),
#  ('flat', 'levels'),
#  ('flat', 'matt'),
#  ('flowing', 'feeding'),
#  ('fly', 'fled'),
#  ('focused', 'center'),
#  ('focused', 'centers'),
#  ('focused', 'centre'),
#  ('follows', 'pursuing'),
#  ('follows', 'succeeds'),
#  ('foot', 'base'),
#  ('forcing', 'drive'),
#  ('forcing', 'drives'),
#  ('forcing', 'drove'),
#  ('forcing', 'pressure'),
#  ('form', 'cast'),
#  ('form', 'patterns'),
#  ('form', 'phase'),
#  ('form', 'work'),
#  ('fortune', 'portion'),
#  ('frequent', 'shopping'),
#  ('function', 'functions'),
#  ('function', 'running'),
#  ('function', 'runs'),
#  ('function', 'serve'),
#  ('function', 'serving'),
#  ('function', 'work'),
#  ('functions', 'serve'),
#  ('functions', 'work'),
#  ('funds', 'funding'),
#  ('gifts', 'given'),
#  ('gifts', 'talent'),
#  ('given', 'devoted'),
#  ('given', 'feeding'),
#  ('given', 'grant'),
#  ('given', 'held'),
#  ('given', 'open'),
#  ('given', 'threw'),
#  ('happening', 'encounter'),
#  ('happening', 'encountered'),
#  ('happening', 'encounters'),
#  ('harsh', 'rough'),
#  ('hook', 'snare'),
#  ('house', 'theater'),
#  ('ice', 'glass'),
#  ('impact', 'touched'),
#  ('imports', 'consequence'),
#  ('imports', 'moments'),
#  ('imports', 'significance'),
#  ('institution', 'introduction'),
#  ('jokes', 'gags'),
#  ('judgment', 'opinion'),
#  ('keep', 'held'),
#  ('keep', 'keeps'),
#  ('keep', 'kept'),
#  ('keep', 'maintain'),
#  ('keeps', 'held'),
#  ('keeps', 'kept'),
#  ('keeps', 'maintain'),
#  ('kept', 'held'),
#  ('killer', 'killers'),
#  ('kingdoms', 'kingdom'),
#  ('lady', 'ladies'),
#  ('larger', 'great'),
#  ('led', 'directed'),
#  ('led', 'extended'),
#  ('led', 'passing'),
#  ('led', 'running'),
#  ('levels', 'degree'),
#  ('light', 'clear'),
#  ('light', 'loose'),
#  ('lips', 'mouth'),
#  ('live', 'dwell'),
#  ('live', 'endure'),
#  ('live', 'existed'),
#  ('live', 'experienced'),
#  ('loose', 'open'),
#  ('lowest', 'small'),
#  ('maintain', 'held'),
#  ('maintain', 'kept'),
#  ('mansion', 'house'),
#  ('marching', 'process'),
#  ('marks', 'check'),
#  ('marks', 'fool'),
#  ('marks', 'print'),
#  ('marrying', 'wedding'),
#  ('measuring', 'value'),
#  ('minds', 'judgment'),
#  ('minor', 'small'),
#  ('minute', 'bit'),
#  ('minute', 'moments'),
#  ('mixed', 'combined'),
#  ('model', 'pattern'),
#  ('model', 'patterns'),
#  ('obliged', 'held'),
#  ('occurs', 'happening'),
#  ('odd', 'curious'),
#  ('opinion', 'judgment'),
#  ('panic', 'terror'),
#  ('particulars', 'details'),
#  ('passed', 'clear'),
#  ('passed', 'eliminate'),
#  ('passed', 'extended'),
#  ('passed', 'given'),
#  ('passed', 'happening'),
#  ('passed', 'led'),
#  ('passed', 'occurs'),
#  ('passed', 'passing'),
#  ('passed', 'running'),
#  ('passed', 'runs'),
#  ('passed', 'top'),
#  ('passing', 'clear'),
#  ('passing', 'eliminate'),
#  ('passing', 'extended'),
#  ('passing', 'given'),
#  ('passing', 'happening'),
#  ('passing', 'occurs'),
#  ('passing', 'running'),
#  ('pattern', 'form'),
#  ('pattern', 'patterns'),
#  ('persuade', 'carrying'),
#  ('persuade', 'persuaded'),
#  ('pick', 'cleaning'),
#  ('pick', 'filling'),
#  ('pick', 'foot'),
#  ('picking', 'cleaning'),
#  ('picking', 'foot'),
#  ('picking', 'pick'),
#  ('planned', 'planning'),
#  ('planning', 'planned'),
#  ('poem', 'poems'),
#  ('pointed', 'levels'),
#  ('pointed', 'placed'),
#  ('points', 'degree'),
#  ('points', 'details'),
#  ('points', 'directed'),
#  ('points', 'levels'),
#  ('points', 'placed'),
#  ('points', 'pointed'),
#  ('points', 'shown'),
#  ('points', 'stops'),
#  ('points', 'tip'),
#  ('portion', 'share'),
#  ('post', 'placed'),
#  ('post', 'station'),
#  ('potential', 'likely'),
#  ('practices', 'pattern'),
#  ('practices', 'patterns'),
#  ('preached', 'preach'),
#  ('pressures', 'forcing'),
#  ('pressures', 'pressure'),
#  ('pretend', 'acts'),
#  ('prevail', 'endure'),
#  ('prevail', 'held'),
#  ('price', 'cost'),
#  ('principal', 'master'),
#  ('problem', 'job'),
#  ('process', 'work'),
#  ('provides', 'offering'),
#  ('provides', 'supply'),
#  ('pushing', 'campaign'),
#  ('pushing', 'crowd'),
#  ('pushing', 'drive'),
#  ('pushing', 'drives'),
#  ('pushing', 'drove'),
#  ('pushing', 'forcing'),
#  ('quietly', 'quiet'),
#  ('raising', 'advanced'),
#  ('raising', 'advancing'),
#  ('raising', 'parent'),
#  ('raising', 'producing'),
#  ('raising', 'stir'),
#  ('rate', 'pace'),
#  ('rate', 'placed'),
#  ('rate', 'value'),
#  ('recall', 'remember'),
#  ('remote', 'outside'),
#  ('reserve', 'held'),
#  ('reserved', 'allowed'),
#  ('reserved', 'held'),
#  ('reserved', 'reserve'),
#  ('resolution', 'resolve'),
#  ('riding', 'drive'),
#  ('riding', 'drives'),
#  ('riding', 'drove'),
#  ('rocky', 'rough'),
#  ('rough', 'harsh'),
#  ('rough', 'rocky'),
#  ('running', 'campaign'),
#  ('running', 'carrying'),
#  ('running', 'endure'),
#  ('running', 'extended'),
#  ('running', 'feeding'),
#  ('running', 'flowing'),
#  ('running', 'functions'),
#  ('running', 'moves'),
#  ('running', 'prevail'),
#  ('running', 'race'),
#  ('running', 'work'),
#  ('runs', 'campaign'),
#  ('runs', 'carrying'),
#  ('runs', 'endure'),
#  ('runs', 'extended'),
#  ('runs', 'feeding'),
#  ('runs', 'flowing'),
#  ('runs', 'function'),
#  ('runs', 'functions'),
#  ('runs', 'led'),
#  ('runs', 'moves'),
#  ('runs', 'passing'),
#  ('runs', 'prevail'),
#  ('runs', 'race'),
#  ('runs', 'running'),
#  ('runs', 'work'),
#  ('sailed', 'sweeping'),
#  ('screening', 'covering'),
#  ('seat', 'behind'),
#  ('second', 'bit'),
#  ('second', 'minute'),
#  ('second', 'moments'),
#  ('sections', 'department'),
#  ('seeking', 'seek'),
#  ('seem', 'appear'),
#  ('seen', 'assured'),
#  ('seen', 'encounter'),
#  ('seen', 'encountered'),
#  ('seen', 'encounters'),
#  ('seen', 'experienced'),
#  ('seen', 'fancied'),
#  ('seen', 'findings'),
#  ('seen', 'sees'),
#  ('seen', 'viewed'),
#  ('sees', 'encounter'),
#  ('sees', 'encountered'),
#  ('sees', 'encounters'),
#  ('sees', 'fancied'),
#  ('segment', 'sections'),
#  ('serve', 'process'),
#  ('serving', 'functions'),
#  ('serving', 'portion'),
#  ('serving', 'process'),
#  ('serving', 'serve'),
#  ('shed', 'cast'),
#  ('shopping', 'frequent'),
#  ('shopping', 'staged'),
#  ('shouted', 'cry'),
#  ('shown', 'demonstrate'),
#  ('shown', 'expressed'),
#  ('shown', 'pointed'),
#  ('sick', 'cast'),
#  ('snare', 'hook'),
#  ('solid', 'strongest'),
#  ('solitary', 'lonely'),
#  ('speak', 'mouth'),
#  ('sprang', 'form'),
#  ('staged', 'representing'),
#  ('state', 'expressed'),
#  ('station', 'placed'),
#  ('stir', 'raising'),
#  ('stir', 'touched'),
#  ('stops', 'barred'),
#  ('stripped', 'cleaning'),
#  ('strongest', 'secure'),
#  ('studies', 'studied'),
#  ('studies', 'work'),
#  ('subject', 'content'),
#  ('subject', 'open'),
#  ('subject', 'studies'),
#  ('substance', 'centre'),
#  ('substance', 'content'),
#  ('substance', 'meat'),
#  ('superior', 'master'),
#  ('supporting', 'confirm'),
#  ('supporting', 'endure'),
#  ('supporting', 'held'),
#  ('supporting', 'stomach'),
#  ('suspension', 'pause'),
#  ('sustain', 'confirm'),
#  ('sustain', 'held'),
#  ('sustain', 'keep'),
#  ('sustain', 'keeps'),
#  ('sustain', 'kept'),
#  ('sustain', 'maintain'),
#  ('sustain', 'supporting'),
#  ('sweeping', 'span'),
#  ('talents', 'gifts'),
#  ('talents', 'talent'),
#  ('teaching', 'commandment'),
#  ('thinking', 'recall'),
#  ('thinking', 'remember'),
#  ('thinking', 'suppose'),
#  ('thirst', 'hunger'),
#  ('threw', 'cast'),
#  ('threw', 'held'),
#  ('threw', 'shed'),
#  ('thrust', 'drive'),
#  ('thrust', 'drives'),
#  ('thrust', 'forcing'),
#  ('thrust', 'threw'),
#  ('top', 'clear'),
#  ('top', 'height'),
#  ('top', 'led'),
#  ('top', 'passing'),
#  ('top', 'tip'),
#  ('touched', 'concerned'),
#  ('trace', 'follows'),
#  ('transaction', 'dealing'),
#  ('treasures', 'value'),
#  ('tricks', 'jokes'),
#  ('turned', 'become'),
#  ('turned', 'twists'),
#  ('turned', 'work'),
#  ('twists', 'curve'),
#  ('viewed', 'sees'),
#  ('wages', 'earnings'),
#  ('wan', 'sick'),
#  ('ways', 'agency'),
#  ('weather', 'endure'),
#  ('wedding', 'marrying'),
#  ('whales', 'giant'),
#  ('wood', 'forests'),
#  ('work', 'employment'),
#  ('work', 'functions'),
#  ('work', 'process'),
#  ('work', 'studies'),
#  ('wounded', 'offended'),
#  ('young', 'newest'),
#  ('youth', 'young')}

# %%
precision = len(S_emb.intersection(S_wn)) / len(S_emb)
recall = len(S_emb.intersection(S_wn)) / len(S_wn)
f1_score = 2 * precision * recall / (precision + recall)

print('Precision: ', precision)
print('Recall: ', recall)
print('F1_score: ', f1_score)
# Out:
# Precision:  0.014977973568281937
# Recall:  0.03195488721804511
# F1_score:  0.02039592081583683

# %% [markdown]
# ### Coverage, precisions and recall errors
# Find the words pairs which do not fit the coverage, precision and recall criteria:
#
# 1.   *coverage errors*: words in the embedding space which are not covered in WordNet
# 2.   *precision errors*: word pairs which are considered synonyms in the embedding space but do not appear in the same synset in WordNet
# 3.   *recall errors*: word pairs which are not considered synonyms in the embedding space in the embedding space, but do appear in the same synset in WordNet

# %% [markdown]
# **Coverage errors**

# %%
vocabulary = set(vocab)

print(vocabulary.difference(wn_lemmas))
# Out:
# {'facts', 'chaldeans', 'heauen', 'permitted', 'payments', 'reporters', 'attacked', 'receives', 'carrying', 'presents', 'ceased', 'associates', 'paintings', 'started', 'susan', 'fowls', 'tunes', 'du', 'viewed', 'discovers', 'spends', 'seas', 'besought', 'founded', 'exceptions', 'manasseh', 'reveals', 'advantages', 'jon', 'rnr', 'studies', 'connor', 'harville', 'introduces', 'ratings', 'knees', 'tones', 'standards', 'began', 'differences', 'expenses', 'dashwood', 'cecilia', 'prophesied', 'files', 'forests', 'fi', 'rhode', 'ere', 'touches', 'backs', 'studios', 'lands', 'cherubims', 'evils', 'sci', 'walks', 'amorites', 'finest', 'worlds', 'followed', 'bodies', 'wrote', 'accounts', 'americans', 'buddies', 'kellynch', 'intervals', 'everybody', 'arrives', 'dwelt', 'waves', 'surprises', 'loue', 'enemies', 'locks', 'enjoying', 'shapes', 'uses', 'taxes', 'creatures', 'sends', 'cubits', 'projects', 'streets', 'deserves', 'arquette', 'lebowski', 'purposes', 'prayed', 'troopers', 'throwing', 'describes', 'beasts', 'ive', 'readers', 'onto', 'forms', 'lifting', 'became', 'sequences', 'prayers', 'remarked', 'villains', 'replied', 'kills', 'skills', 'borders', 'blows', 'wherewith', 'folded', 'tents', 'provided', 'concerning', 'suffers', 'indians', 'associated', 'tongues', 'mtv', 'rocks', 'designs', 'wears', 'gilead', 'martha', 'materials', 'looke', 'sinners', 'subjects', 'sounds', 'shots', 'reigned', 'damme', 'motions', 'per', 'ropes', 'thee', 'stars', 'slipped', 'generated', 'questions', 'willoughby', 'houses', 'bows', 'expecting', 'would', 'reaches', 'mistakes', 'apples', 'depending', 'flaws', 'walked', 'youll', 'kenneth', 'rules', 'happened', 'named', 'wished', 'among', 'neighbours', 'records', 'statements', 'hoping', 'couldnt', 'lovers', 'cuts', 'introduced', 'parties', 'told', 'piedro', 'posts', 'dollars', 'decisions', 'answered', 'flowers', 'edges', 'sequels', 'brought', 'teachers', 'charges', 'answers', 'hartfield', 'memories', 'items', 'personalities', 'trades', 'seized', 'causes', 'heroes', 'took', 'watches', 'centers', 'brains', 'comments', 'melvin', 'wong', 'observations', 'whoever', 'hears', 'smiled', 'travels', 'tis', 'watched', 'gave', 'guessed', 'forsaken', 'confronted', 'gazing', 'principles', 'limits', 'something', 'bought', 'races', 'hopes', 'happens', 'resulting', 'programs', 'giveth', 'captains', 'bulworth', 'displays', 'points', 'met', 'voices', 'meets', 'benwick', 'models', 'swords', 'againe', 'stubb', 'rows', 'ellie', 'kings', 'fathers', 'ephraim', 'candidates', 'alicia', 'units', 'proportions', 'investors', 'relationships', 'didnt', 'jennings', 'features', 'goes', 'fro', 'messengers', 'types', 'syme', 'organizations', 'colleagues', 'guys', 'devils', 'deals', 'comrades', 'singers', 'william', 'helped', 'parents', 'calls', 'added', 'dragged', 'besson', 'seconds', 'ministers', 'angels', 'tables', 'suits', 'critics', 'mel', 'appearances', 'carriages', 'transgressions', 'gains', 'bears', 'neighbors', 'heare', 'deemed', 'ships', 'begun', 'agrees', 'ran', 'ashes', 'children', 'wives', 'linda', 'brothers', 'beverly', 'courses', 'horns', 'pequod', 'takes', 'generations', 'abner', 'believes', 'sammy', 'bills', 'depths', 'instances', 'spake', 'fits', 'exclaimed', 'learns', 'results', 'whenever', 'systems', 'detectives', 'merits', 'lights', 'promised', 'commandments', 'giue', 'knew', 'weeks', 'deeper', 'tests', 'sware', 'whoso', 'pays', 'hong', 'destroying', 'belonged', 'reminds', 'regions', 'writes', 'easier', 'since', 'san', 'themes', 'sailors', 'princes', 'placing', 'methods', 'zedekiah', 'loveit', 'guns', 'eric', 'represents', 'helps', 'lest', 'annie', 'sank', 'dies', 'howbeit', 'drank', 'becomes', 'fu', 'assembled', 'dreams', 'alec', 'fishes', 'adds', 'tarlton', 'hills', 'raises', 'plots', 'refuses', 'didst', 'breaks', 'tends', 'laura', 'hundreds', 'lawyers', 'estimated', 'rang', 'flicks', 'fought', 'plates', 'machines', 'articles', 'dave', 'places', 'maintaining', 'obtained', 'knocked', 'walls', 'haue', 'las', 'toys', 'errors ...

# %% [markdown]
# **Precision errors**

# %%
print(S_emb.difference(S_wn))
# Out:
# {('vpon', 'tis'), ('ltd', 'acquisition'), ('hughes', 'infamous'), ('recovered', 'harville'), ('client', 'funding'), ('passed', 'entered'), ('filmmaking', 'accuracy'), ('divide', 'inheritance'), ('harville', 'leisure'), ('dixon', 'affectionate'), ('ltd', 'units'), ('measuring', 'height'), ('slapstick', 'originality'), ('boyfriend', 'pregnant'), ('boyfriend', 'connor'), ('nov', 'calif'), ('sore', 'zedekiah'), ('expanding', 'consumer'), ('heareth', 'preach'), ('essence', 'aspects'), ('turtle', 'rabbit'), ('regardless', 'purely'), ('knowest', 'didst'), ('multiple', 'defined'), ('knowest', 'snare'), ('frightening', 'remotely'), ('planning', 'defense'), ('creative', 'scorsese'), ('elinor', 'sincerity'), ('flood', 'pestilence'), ('transaction', 'units'), ('infamous', 'derek'), ('significance', 'integration'), ('functions', 'objective'), ('regardless', 'objective'), ('lacking', 'originality'), ('associate', 'student'), ('analysis', 'objective'), ('programs', 'planning'), ('jacket', 'sticking'), ('climactic', 'staged'), ('functions', 'defined'), ('donnell', 'lou'), ('warren', 'barred'), ('hedge', 'shouted'), ('harville', 'wished'), ('secretary', 'funding'), ('exciting', 'remotely'), ('february', 'treasury'), ('inheritance', 'canaan'), ('boyfriend', 'ann'), ('dixon', 'harville'), ('donnell', 'connor'), ('elliot', 'agreeable'), ('shall', 'behold'), ('moab', 'dwell'), ('inheritance', 'levites'), ('pestilence', 'bands'), ('treasury', 'assets'), ('monday', 'treasury'), ('thrills', 'drama'), ('punish', 'pestilence'), ('programs', 'encourage'), ('purely', 'intellectual'), ('flung', 'threw'), ('filmmaking', 'fascinating'), ('funding', 'representing'), ('snare', 'prevail'), ('levites', 'benjamin'), ('surprisingly', 'nonetheless'), ('cheesy', 'exciting'), ('elinor', 'satisfaction'), ('prevail', 'secure'), ('accurate', 'analysis'), ('hedge', 'mud'), ('significance', 'properties'), ('comedies', 'romantic'), ('sprang', 'gazing'), ('systems', 'experiments'), ('ross', 'scott'), ('elinor', 'harville'), ('manasseh', 'brethren'), ('findings', 'studies'), ('dixon', 'elliot'), ('bands', 'snare'), ('enjoyment', 'leisure'), ('thunder', 'chariot'), ('denying', 'findings'), ('advantages', 'necessity'), ('meal', 'meat'), ('dave', 'alicia'), ('daughters', 'canaan'), ('function', 'accuracy'), ('punish', 'heareth'), ('imports', 'treasury'), ('representative', 'funding'), ('elinor', 'affection'), ('eleazar', 'priest'), ('waving', 'shouted'), ('editing', 'staged'), ('compliment', 'lady'), ('companions', 'cecilia'), ('mamma', 'goddard'), ('alicia', 'hoffman'), ('dropping', 'mud'), ('wished', 'fancied'), ('imports', 'representative'), ('formation', 'analysis'), ('smite', 'snare'), ('demonstrate', 'inherent'), ('leisure', 'obliged'), ('barred', 'del'), ('certainty', 'wished'), ('properties', 'adequate'), ('inheritance', 'fathers'), ('vile', 'vpon'), ('snare', 'knowest'), ('manasseh', 'apostles'), ('particulars', 'difficulties'), ('consumed', 'smite'), ('smite', 'consumed'), ('planning', 'departments'), ('butter', 'ate'), ('fled', 'pursuing'), ('concrete', 'basement'), ('cops', 'investigate'), ('transaction', 'earnings'), ('frightening', 'sentimental'), ('donnell', 'knight'), ('sticking', 'stomach'), ('commandment', 'gladness'), ('function', 'inherent'), ('reform', 'objective'), ('astonishment', 'indignation'), ('tuesday', 'february'), ('departments', 'representing'), ('films', 'originality'), ('tuesday', 'tokyo'), ('functions', 'definition'), ('alicia', 'hilarious'), ('hoffman', 'wilson'), ('dixon', 'acquaintance'), ('mud', 'wet'), ('mud', 'sticking'), ('films', 'comedies'), ('moab', 'benjamin'), ('sale', 'equity'), ('would', 'obliged'), ('cloud', 'pillar'), ('shouldest', 'knowest'), ('necessity', 'resolution'), ('ltd', 'earnings'), ('advised', 'goddard'), ('practices', 'encourage'), ('del', 'dave'), ('economic', 'asian'), ('atonement', 'offering'), ('strengthen', 'smite'), ('attended', 'screening'), ('thee', 'didst'), ('encourage', 'determination'), ('sincerity', 'ge ...

# %% [markdown]
# **Recall errors**

# %%
print(S_wn.difference(S_emb))
# Out:
# {('levels', 'degree'), ('borne', 'assumed'), ('forcing', 'drove'), ('riding', 'drive'), ('passed', 'given'), ('ate', 'feeding'), ('model', 'patterns'), ('killer', 'killers'), ('forcing', 'drives'), ('points', 'tip'), ('essence', 'centers'), ('pick', 'foot'), ('principal', 'master'), ('centers', 'meat'), ('state', 'expressed'), ('reserve', 'held'), ('pushing', 'drive'), ('serving', 'portion'), ('check', 'stops'), ('consider', 'dealt'), ('consider', 'sees'), ('directed', 'pointed'), ('flowing', 'feeding'), ('passed', 'occurs'), ('ways', 'agency'), ('talents', 'gifts'), ('allowed', 'grant'), ('choices', 'pick'), ('riding', 'drove'), ('rate', 'value'), ('passing', 'eliminate'), ('focused', 'centre'), ('shed', 'cast'), ('live', 'experienced'), ('persuade', 'carrying'), ('essence', 'substance'), ('points', 'details'), ('stir', 'raising'), ('focused', 'center'), ('points', 'directed'), ('running', 'carrying'), ('minor', 'small'), ('work', 'functions'), ('approach', 'attack'), ('shown', 'demonstrate'), ('causes', 'campaign'), ('house', 'theater'), ('studies', 'work'), ('runs', 'flowing'), ('attended', 'seen'), ('runs', 'carrying'), ('fill', 'filling'), ('marrying', 'wedding'), ('marks', 'check'), ('touched', 'concerned'), ('acts', 'work'), ('model', 'pattern'), ('marks', 'print'), ('second', 'minute'), ('passing', 'given'), ('filling', 'satisfied'), ('remote', 'outside'), ('pressures', 'forcing'), ('larger', 'great'), ('shown', 'expressed'), ('answering', 'resolve'), ('provides', 'supply'), ('acts', 'pretend'), ('young', 'newest'), ('filled', 'satisfied'), ('atonement', 'satisfaction'), ('maintain', 'kept'), ('belonging', 'belongs'), ('familiar', 'companions'), ('quietly', 'quiet'), ('runs', 'extended'), ('passed', 'top'), ('runs', 'work'), ('causes', 'drives'), ('studies', 'studied'), ('sustain', 'supporting'), ('dropping', 'shed'), ('caused', 'causing'), ('demonstrate', 'marching'), ('seen', 'sees'), ('passed', 'extended'), ('borne', 'stomach'), ('tricks', 'jokes'), ('work', 'process'), ('riding', 'drives'), ('supporting', 'stomach'), ('functions', 'work'), ('declare', 'held'), ('wedding', 'marrying'), ('forcing', 'drive'), ('imports', 'moments'), ('thinking', 'recall'), ('attended', 'serving'), ('advancing', 'raising'), ('feeling', 'opinion'), ('runs', 'function'), ('borne', 'endure'), ('films', 'filmed'), ('ate', 'consumed'), ('mixed', 'combined'), ('turned', 'become'), ('recall', 'remember'), ('runs', 'feeding'), ('function', 'serving'), ('problem', 'job'), ('associates', 'associated'), ('stripped', 'cleaning'), ('rate', 'pace'), ('device', 'twists'), ('consider', 'studied'), ('borne', 'held'), ('assured', 'secure'), ('effect', 'essence'), ('sections', 'department'), ('allowed', 'reserve'), ('allowed', 'provides'), ('form', 'work'), ('dealt', 'share'), ('substance', 'centre'), ('encourage', 'advanced'), ('picking', 'foot'), ('consider', 'viewed'), ('discovers', 'sees'), ('companions', 'companies'), ('causes', 'causing'), ('points', 'levels'), ('wounded', 'offended'), ('sustain', 'keeps'), ('minds', 'judgment'), ('raising', 'parent'), ('function', 'work'), ('sees', 'fancied'), ('centers', 'centre'), ('keep', 'keeps'), ('findings', 'recovered'), ('subject', 'content'), ('acquired', 'producing'), ('sees', 'encounters'), ('best', 'honest'), ('keep', 'maintain'), ('borne', 'supporting'), ('particulars', 'details'), ('appoint', 'names'), ('imports', 'significance'), ('happening', 'encounters'), ('causes', 'drive'), ('dealt', 'trading'), ('check', 'seen'), ('evening', 'levels'), ('pretend', 'acts'), ('loose', 'open'), ('find', 'recovered'), ('dropping', 'cast'), ('seen', 'encounters'), ('pushing', 'forcing'), ('youth', 'young'), ('points', 'stops'), ('pattern', 'form'), ('centers', 'substance'), ('thrust', 'drive'), ('assured', 'promising'), ('sustain', 'confirm'), ('passed', 'running'), ('encounter', 'encountered'), ('viewed', 'sees'), ('price', 'cost'), ('seen', 'assured'), ('drives', 'drive'), ('function', 'running'), ('top', 'passin ...

# %% [markdown]
# Experiment with the word similarity threshold used to decide word embedding synonymy (select a sample of different values) and find the optimal one thatmaximizes the F1-score computed above.

# %%
thresholds = np.arange(start=0.25, stop=0.99, step=0.05)

# %%
optim, best_f1_score = 0., 0.
for cosine_threshold in thresholds:
  S_emb = []
  for words_pair in words_pairs:
    v1 = model.wv[words_pair[0]]
    v2 = model.wv[words_pair[1]]
    cosine_similarity = np.dot(v1,v2) / (norm(v1) * norm(v2))
    if cosine_similarity > cosine_threshold:
      S_emb.append(words_pair)
  
  S_emb = set(S_emb)

  precision = len(S_emb.intersection(S_wn)) / (len(S_emb) + 1e-7)
  recall = len(S_emb.intersection(S_wn)) / (len(S_wn) + 1e-7)
  f1_score = 2 * precision * recall / (precision + recall + 1e-7)
  if f1_score > best_f1_score:
    best_f1_score = f1_score
    optim = cosine_threshold
    

print('Optim threshold {} achieved {} F1-score'.format(optim, best_f1_score))
# Out:
# Optim threshold 0.5499999999999999 achieved 0.020395877355827204 F1-score
